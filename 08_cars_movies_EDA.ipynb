# %%
import pandas as pd
import numpy as np

# %%
# read in raw data for cars in movies
raw_2010 = pd.read_csv("output_data/raw/cars in movies/2021_03_06_2010Cars.csv")

# %%
raw_2010
# Out:
#           Release  Year                          Car  \
# 0     Toy Story 3  2010  1998 Chevrolet Corvette C5
# 1     Toy Story 3  2010             Opel Meriva [A]
# 2     Toy Story 3  2010        2005 Opel Zafira [B]
# 3     Toy Story 3  2010           1979 Toyota Truck
# 4      Iron Man 2  2010              2010 Acura ZDX
# ...           ...   ...                          ...
# 2048  Daybreakers  2010        Rhino Buggies Hammer
# 2049  Daybreakers  2010           2004 smart Fortwo
# 2050  Daybreakers  2010         1993 Toyota 4Runner
# 2051  Daybreakers  2010        2006 Toyota Prius II
# 2052  Daybreakers  2010                     Unknown
#
#                                                url Stars
# 0      vehicle_369776-Chevrolet-Corvette-1998.html     3
# 1                  vehicle_974788-Opel-Meriva.html     2
# 2             vehicle_974791-Opel-Zafira-2005.html     2
# 3       vehicle_349573-Toyota-Truck-RN30-1979.html     2
# 4           vehicle_340464-Acura-ZDX-YB1-2010.html     2
# ...                                            ...   ...
# 2048      vehicle_317794-Rhino-Buggies-Hammer.html     3
# 2049     vehicle_317791-smart-Fortwo-450-2004.html     1
# 2050  vehicle_236774-Toyota-4Runner-N130-1993.html     2
# 2051   vehicle_317792-Toyota-Prius-NHW20-2006.html     1
# 2052                           vehicle_236773.html     2
#
# [2053 rows x 5 columns]

# %%
# how many null elements are in each column
raw_2010.isnull().sum()
# Out:
# Release    0
# Year       0
# Car        0
# url        0
# Stars      0
# dtype: int64

# %%
# what sort of junk data do we need to remove from the Car column
raw_2010.loc[raw_2010.Car.str.contains('Movie')]
# Out:
#                  Release  Year                           Car  \
# 190   The Last Airbender  2010               Made for Movie
# 411         TRON: Legacy  2010   Made for Movie Light Cycle
# 412         TRON: Legacy  2010   Made for Movie Light Cycle
# 413         TRON: Legacy  2010  Made for Movie Light Runner
# 982           The A-Team  2010     Made for Movie M8 Buford
# 1123         The Wolfman  2010     Made for Movie Steam Bus
# 1293           Yogi Bear  2010               Made for Movie
#
#                                                   url Stars
# 190                vehicle_364660-Made-for-Movie.html     2
# 411    vehicle_241545-Made-for-Movie-Light-Cycle.html     3
# 412    vehicle_389015-Made-for-Movie-Light-Cycle.html     2
# 413   vehicle_345557-Made-for-Movie-Light-Runner.html     3
# 982      vehicle_271343-Made-for-Movie-M8-Buford.html     3
# 1123     vehicle_312657-Made-for-Movie-Steam-Bus.html     2
# 1293               vehicle_395591-Made-for-Movie.html     4

# %%
raw_2010.loc[raw_2010.Car.str.contains('Unknown')]
# Out:
#                                            Release  Year       Car  \
# 144   Harry Potter and the Deathly Hallows: Part 1  2010  Unknown
# 622                                The Book of Eli  2010  Unknown
# 1063                             The Bounty Hunter  2010  Unknown
# 2052                                   Daybreakers  2010  Unknown
#
#                       url Stars
# 144   vehicle_455543.html     1
# 622   vehicle_332601.html     1
# 1063  vehicle_293920.html     1
# 2052  vehicle_236773.html     2

# %%
raw_2010.loc[raw_2010.Car.str.contains('unknown')]
# Out:
#                               Release  Year                Car  \
# 46         The Twilight Saga: Eclipse  2010           unknown
# 106                         Inception  2010           unknown
# 117                         Inception  2010    Yamaha unknown
# 163                    The Karate Kid  2010  Huanghai unknown
# 171                    The Karate Kid  2010           unknown
# 296                    The Other Guys  2010   2005 UD unknown
# 303                    The Other Guys  2010      Yale unknown
# 443                        Jackass 3D  2010           unknown
# 444                        Jackass 3D  2010           unknown
# 623                   The Book of Eli  2010           unknown
# 768                          The Town  2010    Toyota unknown
# 830                               RED  2010           unknown
# 999                        The A-Team  2010           unknown
# 1395  Wall Street: Money Never Sleeps  2010     unknown Cobra
# 1442                         Kick-Ass  2010      Yale unknown
# 1486                          Cop Out  2010           unknown
# 1487                          Cop Out  2010           unknown
# 1572                 Edge of Darkness  2010  Kenworth unknown
# 1604                 Edge of Darkness  2010           unknown
# 1667                           Legion  2010           unknown
# 1787                    Vampires Suck  2010           unknown
# 1788                    Vampires Suck  2010           unknown
# 1809                     The American  2010           unknown
#
#                                 url Stars
# 46              vehicle_359181.html     1
# 106             vehicle_355636.html     1
# 117     vehicle_1203997-Yamaha.html     1
# 163    vehicle_331629-Huanghai.html     2
# 171             vehicle_372472.html     1
# 296    vehicle_1183239-UD-2005.html     1
# 303       vehicle_1183242-Yale.html     1
# 443            vehicle_1306807.html     1
# 444             vehicle_383686.html     3
# 623             vehicle_310513.html     1
# 768     vehicle_1107200-Toyota.html     1
# 830            vehicle_1188806.html     1
# 999             vehicle_316922.html     2
# 1395     vehicle_1233860-Cobra.html     1
# 1442       vehicle_307349-Yale.html     1
# 1486            vehicle_315195.html     1
# 1487            vehicle_315194.html     1
# 1572  vehicle_1435165-Kenworth.html     1
# 1604           vehicle_1435161.html     1
# 1667            vehicle_478914.html     1
# 1787            vehicle_357414.html     2
# 1788            vehicle_357415.html     1
# 1809            vehicle_347142.html     1

# %%
# how common are some cars at the most frequent versus least
raw_2010.Car.value_counts()
# Out:
# 1999 Ford Crown Victoria              22
# 2001 Ford Crown Victoria              17
# unknown                               15
# 2003 Ford Crown Victoria              13
# 2006 Toyota Prius II                   9
#                                       ..
# 2007 MINI Cooper Clubman               1
# Volvo 760                              1
# 2008 Volkswagen Jetta A5 [Typ 1K]      1
# 1991 Cadillac Sedan DeVille            1
# 1977 Pontiac Catalina                  1
# Name: Car, Length: 1472, dtype: int64

# %%
# check data types
raw_2010.dtypes
# Out:
# Release    object
# Year        int64
# Car        object
# url        object
# Stars      object
# dtype: object

# %%
# how many cars are there for each ratings category
raw_2010.Stars.value_counts()
# Out:
# 1      1372
# 2       443
# 3       185
# Nan      32
# 4        21
# Name: Stars, dtype: int64

# %%
# return a DataFrame without any missing ratings element
clean_2010 = raw_2010.loc[raw_2010.Stars != 'Nan']

# %%
# convert Stars ratings column to integers
clean_2010.Stars = clean_2010.Stars.astype(int)
# Out:
# C:\Users\stuhu\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
# return a new DataFrame that filters for relevant rating (proxy for screentime), and removes...
# irrelevant car elements
new = clean_2010.loc[(clean_2010.Stars >= 3) & (~clean_2010.Car.str.contains('Unknown'))\
                     & (~clean_2010.Car.str.contains('unknown')) & (~clean_2010.Car.str.contains('Movie'))]

# %%
new
# Out:
#                  Release  Year                                Car  \
# 0            Toy Story 3  2010        1998 Chevrolet Corvette C5
# 6             Iron Man 2  2010                 2008 Audi A8 L D3
# 7             Iron Man 2  2010               2010 Audi R8 Spyder
# 24            Iron Man 2  2010      2009 Rolls-Royce Phantom VII
# 30            Iron Man 2  2010        1978 Wolf WR1 Ford Replica
# ...                  ...   ...                                ...
# 2001  Love & Other Drugs  2010  Porsche 911 Carrera Cabrio [993]
# 2013       Morning Glory  2010               2003 Dodge Sprinter
# 2038         Daybreakers  2010                 2008 Chrysler 300
# 2046         Daybreakers  2010    1978 Pontiac Firebird Trans Am
# 2048         Daybreakers  2010              Rhino Buggies Hammer
#
#                                                     url  Stars
# 0           vehicle_369776-Chevrolet-Corvette-1998.html      3
# 6             vehicle_299564-Audi-A8-L-Typ-4E-2008.html      3
# 7        vehicle_239415-Audi-R8-Spyder-Typ-42-2010.html      3
# 24     vehicle_299563-Rolls-Royce-Phantom-VII-2009.html      3
# 30       vehicle_271000-Wolf-WR1-Ford-Replica-1978.html      3
# ...                                                 ...    ...
# 2001  vehicle_384505-Porsche-911-Carrera-Cabrio-993....      4
# 2013         vehicle_380888-Dodge-Sprinter-VA-2003.html      3
# 2038           vehicle_236769-Chrysler-300-LX-2008.html      4
# 2046  vehicle_223185-Pontiac-Firebird-Trans-Am-1978....      3
# 2048           vehicle_317794-Rhino-Buggies-Hammer.html      3
#
# [201 rows x 5 columns]

# %%
# reset the index
new = new.reset_index(drop=True)

# %%
# how many unique vehicles are there
len(new.Car.unique())
# Out:
# 179

# %%
# in order to start working with the Car column, remove whitespaces at both sides of the string elements
for index, row in new.iterrows():
    new.Car[index] = new.Car[index].strip()
# Out:
# <ipython-input-17-7b04d79dfdac>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new.Car[index] = new.Car[index].strip()

# %%
# return a new DataFrame of all duplicate Car rows
dups = new.loc[new.duplicated('Car', keep=False)]

# %%
# sort duplicates by Car column and reset index
dups = dups.sort_values("Car")
dups = dups.reset_index(drop=True)
dups
# Out:
#                             Release  Year  \
# 0                       Crazy Heart  2010
# 1                       Crazy Heart  2010
# 2                   The Book of Eli  2010
# 3                       The Crazies  2010
# 4                            Legion  2010
# 5                  Edge of Darkness  2010
# 6                        Date Night  2010
# 7                     Vampires Suck  2010
# 8                    The Other Guys  2010
# 9                         Inception  2010
# 10                       The A-Team  2010
# 11                         The Town  2010
# 12                 Edge of Darkness  2010
# 13        The Sorcerer's Apprentice  2010
# 14                          Cop Out  2010
# 15                         The Town  2010
# 16       Why Did I Get Married Too?  2010
# 17                   The Other Guys  2010
# 18                The Bounty Hunter  2010
# 19                   The Other Guys  2010
# 20                       The A-Team  2010
# 21                 Edge of Darkness  2010
# 22                           Legion  2010
# 23                             Salt  2010
# 24        The Sorcerer's Apprentice  2010
# 25                        Inception  2010
# 26                The Bounty Hunter  2010
# 27                          Cop Out  2010
# 28  Wall Street: Money Never Sleeps  2010
# 29                  Valentine's Day  2010
# 30                       The A-Team  2010
# 31                       Green Zone  2010
# 32                       Green Zone  2010
# 33                  The Expendables  2010
# 34  Wall Street: Money Never Sleeps  2010
# 35                  The Expendables  2010
#
#                                        Car  \
# 0                  1977 Chevrolet Suburban
# 1                  1977 Chevrolet Suburban
# 2                  1977 Chevrolet Suburban
# 3                 1998 Ford Crown Victoria
# 4                 1998 Ford Crown Victoria
# 5                 1998 Ford Crown Victoria
# 6                 1998 Ford Crown Victoria
# 7                 2000 Ford Crown Victoria
# 8                 2000 Ford Crown Victoria
# 9                 2001 Ford Crown Victoria
# 10                2001 Ford Crown Victoria
# 11                2001 Ford Crown Victoria
# 12                2001 Ford Crown Victoria
# 13                2001 Ford Crown Victoria
# 14                      2006 Dodge Charger
# 15                      2006 Dodge Charger
# 16  2006 Land-Rover Range Rover Series III
# 17  2006 Land-Rover Range Rover Series III
# 18                    2006 Toyota Prius II
# 19                    2006 Toyota Prius II
# 20                 2007 Chevrolet Suburban
# 21                 2007 Chevrolet Suburban
# 22                 2007 Chevrolet Suburban
# 23                 2007 Chevrolet Suburban
# 24            2007 Mercedes-Benz GL [X164]
# 25            2007 Mercedes-Benz GL [X164]
# 26         2007 Mercedes-Benz S 550 [W221]
# 27         2007 Mercedes-Benz S 550 [W221]
# 28                   2010 Toyota Prius III
# 29                   2010 Toyota Prius III
# 30                  AM General HMMWV M1025
# 31                  AM General HMMWV M1025
# 32                         AM General M-35
# 33                         AM General M-35
# 34                   Ducati Desmosedici RR
# 35                   Ducati Desmosedici RR
#
#                                                   url  Stars
# 0    vehicle_355145-Chevrolet-Suburban-C-10-1977.html      4
# 1    vehicle_316184-Chevrolet-Suburban-C-10-1977.html      4
# 2    vehicle_282682-Chevrolet-Suburban-C-10-1977.html      3
# 3    vehicle_250685-Ford-Crown-Victoria-P71-1998.html      3
# 4    vehicle_244041-Ford-Crown-Victoria-P71-1998.html      3
# 5        vehicle_304052-Ford-Crown-Victoria-1998.html      3
# 6        vehicle_318245-Ford-Crown-Victoria-1998.html      3
# 7    vehicle_357390-Ford-Crown-Victoria-P71-2000.html      3
# 8    vehicle_346999-Ford-Crown-Victoria-P71-2000.html      3
# 9        vehicle_310270-Ford-Crown-Victoria-2001.html      3
# 10   vehicle_316918-Ford-Crown-Victoria-P71-2001.html      3
# 11   vehicle_318931-Ford-Crown-Victoria-P71-2001.html      3
# 12   vehicle_254858-Ford-Crown-Victoria-P71-2001.html      4
# 13       vehicle_364805-Ford-Crown-Victoria-2001.html      3
# 14          vehicle_315213-Dodge-Charger-LX-2006.html      3
# 15          vehicle_337161-Dodge-Charger-LX-2006.html      3
# 16  vehicle_522574-Land-Rover-Range-Rover-L322-200...      3
# 17  vehicle_347003-Land-Rover-Range-Rover-L322-200...      3
# 18        vehicle_293899-Toyota-Prius-NHW20-2006.html      3
# 19        vehicle_295635-Toyota-Prius-NHW20-2006.html      4
# 20  vehicle_316910-Chevrolet-Suburban-GMT931-2007....      3
# 21  vehicle_254857-Chevrolet-Suburban-GMT931-2007....      3
# 22  vehicle_307361-Chevrolet-Suburban-GMT931-2007....      3
# 23  vehicle_347205-Chevrolet-Suburban-GMT931-2007....      3
# 24     vehicle_364810-Mercedes-Benz-GL-X164-2007.html      3
# 25     vehicle_319276-Mercedes-Benz-GL-X164-2007.html      3
# 26  vehicle_293919-Mercedes-Benz-S-550-W221-2007.html      3
# 27  vehicle_315218-Mercedes-Benz-S-550-W221-2007.html      3
# 28        vehicle_368590-Toyota-Prius-ZVW30-2010.html      3
# 29        vehicle_316128-Toyota-Prius-ZVW30-2010.html      3
# 30         vehicle_271333-AM-General-HMMWV-M1025.html      3
# 31         vehicle_286919-AM-General-HMMWV-M1025.html      4
# 32           vehicle_286920-AM-General-M-35-G742.html      3
# 33           vehicle_336158-AM-General-M-35-G742.html      3
# 34          vehicle_368601-Ducati-Desmosedici-RR.html      3
# 35          vehicle_331241-Ducati-Desmosedici-RR.html      3

# %%
new.loc[new.Car == '2010 Audi R8 Spyder']
# Out:
#       Release  Year                  Car  \
# 2  Iron Man 2  2010  2010 Audi R8 Spyder
#
#                                               url  Stars
# 2  vehicle_239415-Audi-R8-Spyder-Typ-42-2010.html      3

# %%
dups.loc[dups.Car == '2000 Ford Crown Victoria']
# Out:
#           Release  Year                       Car  \
# 7   Vampires Suck  2010  2000 Ford Crown Victoria
# 8  The Other Guys  2010  2000 Ford Crown Victoria
#
#                                                 url  Stars
# 7  vehicle_357390-Ford-Crown-Victoria-P71-2000.html      3
# 8  vehicle_346999-Ford-Crown-Victoria-P71-2000.html      3

# %%
new
# Out:
#                 Release  Year                               Car  \
# 0           Toy Story 3  2010        1998 Chevrolet Corvette C5
# 1            Iron Man 2  2010                 2008 Audi A8 L D3
# 2            Iron Man 2  2010               2010 Audi R8 Spyder
# 3            Iron Man 2  2010      2009 Rolls-Royce Phantom VII
# 4            Iron Man 2  2010        1978 Wolf WR1 Ford Replica
# ..                  ...   ...                               ...
# 196  Love & Other Drugs  2010  Porsche 911 Carrera Cabrio [993]
# 197       Morning Glory  2010               2003 Dodge Sprinter
# 198         Daybreakers  2010                 2008 Chrysler 300
# 199         Daybreakers  2010    1978 Pontiac Firebird Trans Am
# 200         Daybreakers  2010              Rhino Buggies Hammer
#
#                                                    url  Stars
# 0          vehicle_369776-Chevrolet-Corvette-1998.html      3
# 1            vehicle_299564-Audi-A8-L-Typ-4E-2008.html      3
# 2       vehicle_239415-Audi-R8-Spyder-Typ-42-2010.html      3
# 3     vehicle_299563-Rolls-Royce-Phantom-VII-2009.html      3
# 4       vehicle_271000-Wolf-WR1-Ford-Replica-1978.html      3
# ..                                                 ...    ...
# 196  vehicle_384505-Porsche-911-Carrera-Cabrio-993....      4
# 197         vehicle_380888-Dodge-Sprinter-VA-2003.html      3
# 198           vehicle_236769-Chrysler-300-LX-2008.html      4
# 199  vehicle_223185-Pontiac-Firebird-Trans-Am-1978....      3
# 200           vehicle_317794-Rhino-Buggies-Hammer.html      3
#
# [201 rows x 5 columns]
