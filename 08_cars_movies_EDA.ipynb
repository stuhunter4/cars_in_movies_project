# %%
import pandas as pd
import numpy as np

# %%
# read in raw data for cars in movies
raw_2010 = pd.read_csv("output_data/raw/cars in movies/2021_03_06_2010Cars.csv")
raw_2010
# Out:
#           Release  Year                          Car  \
# 0     Toy Story 3  2010  1998 Chevrolet Corvette C5
# 1     Toy Story 3  2010             Opel Meriva [A]
# 2     Toy Story 3  2010        2005 Opel Zafira [B]
# 3     Toy Story 3  2010           1979 Toyota Truck
# 4      Iron Man 2  2010              2010 Acura ZDX
# ...           ...   ...                          ...
# 2048  Daybreakers  2010        Rhino Buggies Hammer
# 2049  Daybreakers  2010           2004 smart Fortwo
# 2050  Daybreakers  2010         1993 Toyota 4Runner
# 2051  Daybreakers  2010        2006 Toyota Prius II
# 2052  Daybreakers  2010                     Unknown
#
#                                                url Stars
# 0      vehicle_369776-Chevrolet-Corvette-1998.html     3
# 1                  vehicle_974788-Opel-Meriva.html     2
# 2             vehicle_974791-Opel-Zafira-2005.html     2
# 3       vehicle_349573-Toyota-Truck-RN30-1979.html     2
# 4           vehicle_340464-Acura-ZDX-YB1-2010.html     2
# ...                                            ...   ...
# 2048      vehicle_317794-Rhino-Buggies-Hammer.html     3
# 2049     vehicle_317791-smart-Fortwo-450-2004.html     1
# 2050  vehicle_236774-Toyota-4Runner-N130-1993.html     2
# 2051   vehicle_317792-Toyota-Prius-NHW20-2006.html     1
# 2052                           vehicle_236773.html     2
#
# [2053 rows x 5 columns]

# %%
# how many null elements are in each column
raw_2010.isnull().sum()
# Out:
# Release    0
# Year       0
# Car        0
# url        0
# Stars      0
# dtype: int64

# %%
# how common are some cars at the most frequent versus least
raw_2010.Car.value_counts()
# Out:
# 1999 Ford Crown Victoria                22
# 2001 Ford Crown Victoria                17
# unknown                                 15
# 2003 Ford Crown Victoria                13
# 2006 Toyota Prius II                     9
#                                         ..
# 1962 Cadillac Series 62 Convertible      1
# Made for Movie Light Runner              1
# Custom Made                              1
# 2003 GMC TopKick                         1
# 1991 Cadillac Sedan DeVille              1
# Name: Car, Length: 1472, dtype: int64

# %%
# top 20 most movie appearances
raw_2010.Car.value_counts().nlargest(20)
# Out:
# 1999 Ford Crown Victoria                      22
# 2001 Ford Crown Victoria                      17
# unknown                                       15
# 2003 Ford Crown Victoria                      13
# 2006 Toyota Prius II                           9
# 2006 Chevrolet Impala                          9
# 1997 Ford Econoline                            9
# 2007 Chevrolet Suburban                        8
# 2005 Chrysler 300                              8
# 2000 Chevrolet Impala                          8
# 2003 Lincoln Town Car                          8
# 2008 Chevrolet Malibu                          7
# 2006 Ford Crown Victoria                       7
# 1998 Ford Crown Victoria                       7
# 1997 Toyota Camry                              6
# 2007 Nissan Altima                             6
# 1998 Lincoln Town Car                          6
# 2007 Cadillac Escalade                         6
# 1992 Ford Econoline                            6
# 2003 Lincoln Town Car Stretched Limousine      6
# Name: Car, dtype: int64

# %%
# check data types
raw_2010.dtypes
# Out:
# Release    object
# Year        int64
# Car        object
# url        object
# Stars      object
# dtype: object

# %%
# how many cars are there for each ratings category
raw_2010.Stars.value_counts()
# Out:
# 1      1372
# 2       443
# 3       185
# Nan      32
# 4        21
# Name: Stars, dtype: int64

# %%
# return a DataFrame without any missing ratings element
clean_2010 = raw_2010.loc[raw_2010.Stars != 'Nan']

# %%
# convert Stars ratings column to integers
clean_2010.Stars = clean_2010.Stars.astype(int)
# Out:
# C:\Users\stuhu\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
# return a new DataFrame that removes irrelevant car elements
new = clean_2010.loc[(~clean_2010.Car.str.contains('Unknown'))\
                     & (~clean_2010.Car.str.contains('unknown')) & (~clean_2010.Car.str.contains('Movie'))]

# %%
# reset the index and display
new = new.reset_index(drop=True)
new
# Out:
#           Release  Year                          Car  \
# 0     Toy Story 3  2010  1998 Chevrolet Corvette C5
# 1     Toy Story 3  2010             Opel Meriva [A]
# 2     Toy Story 3  2010        2005 Opel Zafira [B]
# 3     Toy Story 3  2010           1979 Toyota Truck
# 4      Iron Man 2  2010              2010 Acura ZDX
# ...           ...   ...                          ...
# 1982  Daybreakers  2010        Rhino Buggies Hammer
# 1983  Daybreakers  2010        Rhino Buggies Hammer
# 1984  Daybreakers  2010           2004 smart Fortwo
# 1985  Daybreakers  2010         1993 Toyota 4Runner
# 1986  Daybreakers  2010        2006 Toyota Prius II
#
#                                                url  Stars
# 0      vehicle_369776-Chevrolet-Corvette-1998.html      3
# 1                  vehicle_974788-Opel-Meriva.html      2
# 2             vehicle_974791-Opel-Zafira-2005.html      2
# 3       vehicle_349573-Toyota-Truck-RN30-1979.html      2
# 4           vehicle_340464-Acura-ZDX-YB1-2010.html      2
# ...                                            ...    ...
# 1982      vehicle_236776-Rhino-Buggies-Hammer.html      2
# 1983      vehicle_317794-Rhino-Buggies-Hammer.html      3
# 1984     vehicle_317791-smart-Fortwo-450-2004.html      1
# 1985  vehicle_236774-Toyota-4Runner-N130-1993.html      2
# 1986   vehicle_317792-Toyota-Prius-NHW20-2006.html      1
#
# [1987 rows x 5 columns]

# %%
# how many unique vehicles are there
len(new.Car.unique())
# Out:
# 1444

# %%
# in order to start working with the Car column, remove whitespaces at both sides of the string elements
for index, row in new.iterrows():
    new.Car[index] = new.Car[index].strip()
# Out:
# <ipython-input-13-7b04d79dfdac>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new.Car[index] = new.Car[index].strip()

# %%
# return a new DataFrame of all duplicate Car rows
dups = new.loc[new.duplicated('Car', keep=False)]

# %%
# sort duplicates by Car column and reset index
# a significant portion of the dataset contain cars that appear in multiple films
dups = dups.sort_values("Car")
dups = dups.reset_index(drop=True)
dups
# Out:
#                        Release  Year                      Car  \
# 0                  Crazy Heart  2010  1964 Chevrolet C-Series
# 1                    Burlesque  2010  1964 Chevrolet C-Series
# 2                  Secretariat  2010        1965 Ford Mustang
# 3                  Secretariat  2010        1965 Ford Mustang
# 4                  Daybreakers  2010        1966 Ford Mustang
# ..                         ...   ...                      ...
# 821         The Social Network  2010                Volvo S40
# 822               The American  2010                Volvo V70
# 823              Morning Glory  2010                Volvo V70
# 824  A Nightmare on Elm Street  2010                Volvo V70
# 825                  Hereafter  2010                Volvo V70
#
#                                              url  Stars
# 0    vehicle_356411-Chevrolet-C-Series-1964.html      1
# 1    vehicle_562475-Chevrolet-C-Series-1964.html      1
# 2          vehicle_371640-Ford-Mustang-1965.html      1
# 3          vehicle_371645-Ford-Mustang-1965.html      1
# 4          vehicle_306723-Ford-Mustang-1966.html      1
# ..                                           ...    ...
# 821                vehicle_346265-Volvo-S40.html      1
# 822                vehicle_335773-Volvo-V70.html      2
# 823               vehicle_1278240-Volvo-V70.html      1
# 824                vehicle_512215-Volvo-V70.html      2
# 825                vehicle_341371-Volvo-V70.html      1
#
# [826 rows x 5 columns]

# %%
# sample car and its appearances
dups.loc[dups.Car == '2000 Ford Crown Victoria']
# Out:
#                Release  Year                       Car  \
# 297      Morning Glory  2010  2000 Ford Crown Victoria
# 298      Vampires Suck  2010  2000 Ford Crown Victoria
# 299  The Bounty Hunter  2010  2000 Ford Crown Victoria
# 300     The Other Guys  2010  2000 Ford Crown Victoria
# 301       TRON: Legacy  2010  2000 Ford Crown Victoria
#
#                                                   url  Stars
# 297  vehicle_380889-Ford-Crown-Victoria-P71-2000.html      2
# 298  vehicle_357390-Ford-Crown-Victoria-P71-2000.html      3
# 299  vehicle_293923-Ford-Crown-Victoria-P71-2000.html      2
# 300  vehicle_346999-Ford-Crown-Victoria-P71-2000.html      3
# 301  vehicle_389013-Ford-Crown-Victoria-P71-2000.html      2

# %%
# read in car sales data to use as a filter for the Car column
sales = pd.read_csv('output_data/Car_Sales_2009-2020_edited.csv')
sales
# Out:
#         Vehicle     2009     2010     2011     2012     2013     2014  \
# 0     Acura ILX      NaN      NaN      NaN  12251.0  20430.0  17854.0
# 1     Acura MDX  31178.0  47210.0  43271.0  50854.0  53040.0  65603.0
# 2     Acura NSX      NaN      NaN      NaN      NaN      NaN      NaN
# 3     Acura RDX  10153.0  14975.0  15196.0  29520.0  44750.0  44865.0
# 4      Acura RL   2043.0   2037.0   1096.0    379.0     39.0      NaN
# ..          ...      ...      ...      ...      ...      ...      ...
# 452   Volvo V70   1816.0    895.0      NaN      NaN      NaN      NaN
# 453  Volvo XC40      NaN      NaN      NaN      NaN      NaN      NaN
# 454  Volvo XC60   9262.0  12030.0  12932.0  19139.0  19766.0  19276.0
# 455  Volvo XC70   5825.0   6626.0   5716.0   5513.0   4882.0   5093.0
# 456  Volvo XC90  10757.0  10119.0  10609.0   9513.0   6845.0   3952.0
#
#         2015     2016     2017     2018     2019     2020
# 0    18531.0  14597.0  11757.0  11273.0  14685.0  13414.0
# 1    58208.0  55495.0  54886.0  51512.0  52019.0  47816.0
# 2        NaN    269.0    581.0    170.0    238.0    128.0
# 3    51026.0  52361.0  51295.0  63580.0  62876.0  52785.0
# 4        NaN      NaN      NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...      ...      ...
# 452      NaN      NaN      NaN      NaN      NaN      NaN
# 453      NaN      NaN      NaN  12420.0  17647.0  23778.0
# 454  26134.0  20452.0  22516.0  32689.0  30578.0  32078.0
# 455   5118.0   5425.0      NaN      NaN      NaN      NaN
# 456  12777.0  32526.0  30996.0  31609.0  35760.0  34251.0
#
# [457 rows x 13 columns]

# %%
# list comprehension to apply lower method to string elements in the Car column...
# ...to better filter the data for vehicles in the car sales dataset
lower_cars = sales.copy()
lower_cars.Vehicle = [car.lower() for car in lower_cars.Vehicle]

# %%
# same operations for the car in movie dataset
lower_car_mov = new.copy()
lower_car_mov.Car = [car.lower() for car in lower_car_mov.Car]

# %%
# create list of cars with sales data
vehicles = lower_cars.Vehicle.unique().tolist()

# %%
# use list comprehension and for loop to create a list of brands from the sales dataset
brand_raw = [vehicle.split()[0] for vehicle in vehicles]
brands = []
for brand in brand_raw:
    if brand not in brands:
        brands.append(brand)

# %%
print(brands)
# Out:
# ['acura', 'alfa', 'audi', 'bmw', 'bentley', 'buick', 'cadillac', 'chevrolet', 'chrysler', 'dodge', 'fiat', 'ford', 'gmc', 'genesis', 'honda', 'hummer', 'hyundai', 'infiniti', 'jaguar', 'jeep', 'kia', 'land', 'lexus', 'lincoln', 'maserati', 'mazda', 'mercedes-benz', 'mercury', 'mini', 'mitsubishi', 'nissan', 'pontiac', 'porsche', 'ram', 'saab', 'saturn', 'scion', 'smart', 'subaru', 'suzuki', 'tesla', 'toyota', 'volkswagen', 'volvo']

# %%
# create empty list to store vehicle strings to remove
remove_veh = []

# loop through list of vehicles to create separate strings for vehicles with two titles
for vehicle in vehicles:
    if '/' in vehicle:
        # find combined terms to distinguish, separate on / delimiter
        veh_split = vehicle.split('/')
        # only first index string has brand attached, join brand to second index string
        veh_second = " ".join([veh_split[0].split(' ')[0], veh_split[1]])
        # attach both vehicle strings to the vehicles list...
        vehicles.append(veh_split[0])
        vehicles.append(veh_second)
        # ...and append original string to a list for deletion later
        remove_veh.append(vehicle)

# loop through remove_vehicle list to delete strings with / delimiter
for vehicle in remove_veh:
    vehicles.remove(vehicle)

# %%
# edit vehicles list using conditionals...
# ...allowing list to catch every car from the sales dataset
for x in range(len(vehicles)):
    if 'bmw' in vehicles[x]:
        vehicles[x] = vehicles[x].replace('-series', '')
    elif 'mercedes-benz' in vehicles[x]:
        vehicles[x] = vehicles[x].replace('-class', '')
    elif 'land rover' in vehicles[x]:
        vehicles[x] = vehicles[x].replace('land rover', 'land-rover')
    elif 'ford' in vehicles[x]:
        vehicles[x] = vehicles[x].replace('series', '')
    else:
        pass

# %%
# append three exceptions that have been left from the code
exceptions = ['scion im', 'scion fr-s', 'scion ia']
vehicles.extend(exceptions)

# %%
print(vehicles)
# Out:
# ['acura ilx', 'acura mdx', 'acura nsx', 'acura rdx', 'acura rl', 'acura rlx', 'acura tl', 'acura tlx', 'acura tsx', 'acura zdx', 'alfa romeo 4c', 'alfa romeo giulia', 'alfa romeo stelvio', 'audi a3', 'audi a3 e-tron', 'audi a4', 'audi a4 allroad', 'audi a4 avant', 'audi a4 sedan', 'audi a5', 'audi a6', 'audi a7', 'audi a8', 'audi q3', 'audi q5', 'audi q7', 'audi q8', 'audi r8', 'audi tt', 'audi etron', 'bmw 1', 'bmw 2', 'bmw 3', 'bmw 4', 'bmw 5', 'bmw 6', 'bmw 7', 'bmw 8', 'bmw x1', 'bmw x2', 'bmw x3', 'bmw x4', 'bmw x5', 'bmw x6', 'bmw x7', 'bmw z4', 'bmw i3', 'bmw i8', 'bentley bentayga', 'bentley continental gt', 'bentley flying spur', 'bentley mulsanne', 'buick cascada', 'buick enclave', 'buick encore', 'buick encore gx', 'buick envision', 'buick lacrosse', 'buick lucerne', 'buick regal', 'buick verano', 'cadillac ats', 'cadillac ct4', 'cadillac ct5', 'cadillac ct6', 'cadillac cts', 'cadillac dts', 'cadillac elr', 'cadillac escalade', 'cadillac srx', 'cadillac sts', 'cadillac xlr', 'cadillac xt4', 'cadillac xt5', 'cadillac xt6', 'cadillac xts', 'chevrolet avalanche', 'chevrolet aveo', 'chevrolet blazer', 'chevrolet bolt', 'chevrolet camaro', 'chevrolet caprice ppv', 'chevrolet captiva sport', 'chevrolet city express', 'chevrolet cobalt', 'chevrolet colorado', 'chevrolet corvette', 'chevrolet cruze', 'chevrolet equinox', 'chevrolet express', 'chevrolet hhr', 'chevrolet impala', 'chevrolet malibu', 'chevrolet ss', 'chevrolet silverado', 'chevrolet sonic', 'chevrolet spark', 'chevrolet suburban', 'chevrolet tahoe', 'chevrolet trailblazer', 'chevrolet traverse', 'chevrolet trax', 'chevrolet uplander', 'chevrolet volt', 'chrysler 200', 'chrysler 300', 'chrysler aspen', 'chrysler pt cruiser', 'chrysler pacifica', 'chrysler sebring', 'chrysler town & country', 'chrysler town and country', 'dodge avenger', 'dodge caliber', 'dodge challenger', 'dodge charger', 'dodge dakota', 'dodge dart', 'dodge durango', 'dodge grand caravan', 'dodge journey', 'dodge nitro', 'dodge ram', 'dodge viper', 'fiat 124 spider', 'fiat 500', 'fiat 500l', 'fiat 500x', 'ford bronco sport', 'ford c-max', 'ford crown victoria', 'ford e-', 'ford ecosport', 'ford edge', 'ford escape', 'ford expedition', 'ford explorer', 'ford explorer police interceptor ', 'ford f-', 'ford fiesta', 'ford flex', 'ford focus', 'ford fusion', 'ford gt', 'ford mustang', 'ford ranger', 'ford taurus', 'ford taurus police interceptor', 'ford taurus x', 'ford transit', 'ford transit connect', 'gmc acadia', 'gmc canyon', 'gmc envoy', 'gmc savana', 'gmc sierra', 'gmc terrain', 'gmc torrent', 'gmc yukon', 'gmc yukon xl', 'genesis g70', 'genesis g80', 'genesis g90', 'genesis gv80', 'honda accord', 'honda cr-v', 'honda cr-z', 'honda civic', 'honda clarity fcv', 'honda crosstour', 'honda element', 'honda fcx', 'honda fit', 'honda hr-v', 'honda insight', 'honda odyssey', 'honda passport', 'honda pilot', 'honda ridgeline', 'honda s2000', 'hummer h2', 'hummer h3', 'hyundai accent', 'hyundai azera', 'hyundai elantra', 'hyundai equus', 'hyundai genesis', 'hyundai ioniq', 'hyundai kona', 'hyundai nexo', 'hyundai palisade', 'hyundai santa fe', 'hyundai sonata', 'hyundai tucson', 'hyundai veloster', 'hyundai venue', 'hyundai veracruz', 'infiniti g', 'infiniti q40', 'infiniti q50', 'infiniti q60', 'infiniti qx30', 'jaguar e-pace', 'jaguar f-pace', 'jaguar f-type', 'jaguar i-pace', 'jaguar xe', 'jaguar xf', 'jaguar xj', 'jaguar xk', 'jeep cherokee', 'jeep commander', 'jeep compass', 'jeep gladiator', 'jeep grand cherokee', 'jeep liberty', 'jeep patriot', 'jeep renegade', 'jeep wrangler', 'kia amanti', 'kia borrego', 'kia cadenza', 'kia forte', 'kia k5', 'kia k900', 'kia niro', 'kia optima', 'kia rio', 'kia rondo', 'kia sedona', 'kia seltos', 'kia sorento', 'kia soul', 'kia spectra', 'kia sportage', 'kia stinger', 'kia telluride', 'land-rover defender', 'land-rover discovery sport', 'land-rover lr2', 'land-rover range rover', 'land-rover range rover evoque', 'land-rover range rover sport', 'land-rover  ...

# %%
# use list comprehension and for loop to create a list of models from the sales dataset
#model_raw = [vehicle.split()[-1] for vehicle in vehicles]
#models = []
#for model in model_raw:
    #if model not in models:
        #models.append(model)

# %%
# handle models that share a row of data by splitting and appending to models list, then removing
#remove_models = []

#for model in models:
    #if '/' in model:
        #print (f'Splitting and Extending {model}')
        #models.extend(model.split('/'))
        #remove_models.append(model)
        
#for model in remove_models:
    #print (f'Removing {model}')
    #models.remove(model)

# %%
# join the list of brands with a | delimiter, creating a RegEx pattern to pass through str.contains() next
#brand_var = "|".join(brands)
#print(brand_var)
# same process for models
#model_var = "|".join(models)
#print(model_var)

# %%
# join the list of vehicles using a | delimiter, creating a RegEx pattern to pass through str.contains() next cell
vehicle_var = "|".join(vehicles)

# %%
# create DataFrame where only the cars from our car sales data are included
cars_filtered = lower_car_mov.loc[lower_car_mov.Car.str.contains(vehicle_var)]
cars_filtered
# Out:
#           Release  Year                         Car  \
# 0     Toy Story 3  2010  1998 chevrolet corvette c5
# 4      Iron Man 2  2010              2010 acura zdx
# 6      Iron Man 2  2010           2008 audi a8 l d3
# 7      Iron Man 2  2010         2010 audi r8 spyder
# 8      Iron Man 2  2010                 bmw 3 [e90]
# ...           ...   ...                         ...
# 1974  Daybreakers  2010          1986 dodge ram van
# 1977  Daybreakers  2010           1966 ford mustang
# 1984  Daybreakers  2010           2004 smart fortwo
# 1985  Daybreakers  2010         1993 toyota 4runner
# 1986  Daybreakers  2010        2006 toyota prius ii
#
#                                                  url  Stars
# 0        vehicle_369776-Chevrolet-Corvette-1998.html      3
# 4             vehicle_340464-Acura-ZDX-YB1-2010.html      2
# 6          vehicle_299564-Audi-A8-L-Typ-4E-2008.html      3
# 7     vehicle_239415-Audi-R8-Spyder-Typ-42-2010.html      3
# 8                      vehicle_339991-BMW-3-E90.html      1
# ...                                              ...    ...
# 1974          vehicle_236772-Dodge-Ram-Van-1986.html      2
# 1977           vehicle_306723-Ford-Mustang-1966.html      1
# 1984       vehicle_317791-smart-Fortwo-450-2004.html      1
# 1985    vehicle_236774-Toyota-4Runner-N130-1993.html      2
# 1986     vehicle_317792-Toyota-Prius-NHW20-2006.html      1
#
# [1155 rows x 5 columns]

# %%
# compare to DataFrame with the remaining vehicles, to search for data leaking
cars_remainder = lower_car_mov.loc[~lower_car_mov.Car.str.contains(vehicle_var)]
cars_remainder
# Out:
#           Release  Year                                    Car  \
# 1     Toy Story 3  2010                        opel meriva [a]
# 2     Toy Story 3  2010                   2005 opel zafira [b]
# 3     Toy Story 3  2010                      1979 toyota truck
# 5      Iron Man 2  2010  2007 aston martin v8 vantage roadster
# 10     Iron Man 2  2010                     2001 dodge caravan
# ...           ...   ...                                    ...
# 1979  Daybreakers  2010                    1970 mercury cougar
# 1980  Daybreakers  2010               1997 mitsubishi diamante
# 1981  Daybreakers  2010         1978 pontiac firebird trans am
# 1982  Daybreakers  2010                   rhino buggies hammer
# 1983  Daybreakers  2010                   rhino buggies hammer
#
#                                                     url  Stars
# 1                       vehicle_974788-Opel-Meriva.html      2
# 2                  vehicle_974791-Opel-Zafira-2005.html      2
# 3            vehicle_349573-Toyota-Truck-RN30-1979.html      2
# 5     vehicle_339997-Aston-Martin-V8-Vantage-Roadste...      1
# 10            vehicle_285456-Dodge-Caravan-RS-2001.html      1
# ...                                                 ...    ...
# 1979            vehicle_317790-Mercury-Cougar-1970.html      1
# 1980  vehicle_318489-Mitsubishi-Diamante-F38A-1997.html      1
# 1981  vehicle_223185-Pontiac-Firebird-Trans-Am-1978....      3
# 1982           vehicle_236776-Rhino-Buggies-Hammer.html      2
# 1983           vehicle_317794-Rhino-Buggies-Hammer.html      3
#
# [832 rows x 5 columns]

# %%
# export both datasets for quick comparisons in excel, given their manageable size
#cars_filtered.to_csv("cars_filtered.csv", index=False, header=True)
#cars_remainder.to_csv("cars_remainder.csv", index=False, header=True)

# %%
# read in film data
movies = pd.read_csv('output_data/Top100_Movies_2010-2021.csv')

# %%
# create a DataFrame of only films from the top 2010 grossing films
df10 = movies.loc[movies.Year == 2010]
df10
# Out:
#     Rank                      Release         Gross Theaters   Total Gross  \
# 0      1                       Avatar  $466,141,929     3461  $749,766,139
# 1      2                  Toy Story 3  $415,004,880     4028  $415,004,880
# 2      3          Alice in Wonderland  $334,191,110     3739  $334,191,110
# 3      4                   Iron Man 2  $312,433,331     4390  $312,433,331
# 4      5   The Twilight Saga: Eclipse  $300,531,751     4468  $300,531,751
# ..   ...                          ...           ...      ...           ...
# 95    96  Scott Pilgrim vs. the World   $31,524,275     2820   $31,524,275
# 96    97            Charlie St. Cloud   $31,162,545     2725   $31,162,545
# 97    98           Love & Other Drugs   $31,099,481     2458   $32,367,005
# 98    99                Morning Glory   $30,727,814     2544   $31,011,732
# 99   100                  Daybreakers   $30,101,577     2523   $30,101,577
#
#    Release Date                          Distributor  Year
# 0        Dec 18                Twentieth Century Fox  2010
# 1        Jun 18  Walt Disney Studios Motion Pictures  2010
# 2         Mar 5  Walt Disney Studios Motion Pictures  2010
# 3         May 7                   Paramount Pictures  2010
# 4        Jun 30                 Summit Entertainment  2010
# ..          ...                                  ...   ...
# 95       Aug 13                   Universal Pictures  2010
# 96       Jul 30                   Universal Pictures  2010
# 97       Nov 24                Twentieth Century Fox  2010
# 98       Nov 10                   Paramount Pictures  2010
# 99        Jan 8                            Lionsgate  2010
#
# [100 rows x 8 columns]

# %%
# create a DataFrame that merges the car and movie data
car_mov = pd.merge(cars_filtered, df10, how="left", on="Release")
car_mov
# Out:
#           Release  Year_x                         Car  \
# 0     Toy Story 3    2010  1998 chevrolet corvette c5
# 1      Iron Man 2    2010              2010 acura zdx
# 2      Iron Man 2    2010           2008 audi a8 l d3
# 3      Iron Man 2    2010         2010 audi r8 spyder
# 4      Iron Man 2    2010                 bmw 3 [e90]
# ...           ...     ...                         ...
# 1150  Daybreakers    2010          1986 dodge ram van
# 1151  Daybreakers    2010           1966 ford mustang
# 1152  Daybreakers    2010           2004 smart fortwo
# 1153  Daybreakers    2010         1993 toyota 4runner
# 1154  Daybreakers    2010        2006 toyota prius ii
#
#                                                  url  Stars  Rank  \
# 0        vehicle_369776-Chevrolet-Corvette-1998.html      3     2
# 1             vehicle_340464-Acura-ZDX-YB1-2010.html      2     4
# 2          vehicle_299564-Audi-A8-L-Typ-4E-2008.html      3     4
# 3     vehicle_239415-Audi-R8-Spyder-Typ-42-2010.html      3     4
# 4                      vehicle_339991-BMW-3-E90.html      1     4
# ...                                              ...    ...   ...
# 1150          vehicle_236772-Dodge-Ram-Van-1986.html      2   100
# 1151           vehicle_306723-Ford-Mustang-1966.html      1   100
# 1152       vehicle_317791-smart-Fortwo-450-2004.html      1   100
# 1153    vehicle_236774-Toyota-4Runner-N130-1993.html      2   100
# 1154     vehicle_317792-Toyota-Prius-NHW20-2006.html      1   100
#
#              Gross Theaters   Total Gross Release Date  \
# 0     $415,004,880     4028  $415,004,880       Jun 18
# 1     $312,433,331     4390  $312,433,331        May 7
# 2     $312,433,331     4390  $312,433,331        May 7
# 3     $312,433,331     4390  $312,433,331        May 7
# 4     $312,433,331     4390  $312,433,331        May 7
# ...            ...      ...           ...          ...
# 1150   $30,101,577     2523   $30,101,577        Jan 8
# 1151   $30,101,577     2523   $30,101,577        Jan 8
# 1152   $30,101,577     2523   $30,101,577        Jan 8
# 1153   $30,101,577     2523   $30,101,577        Jan 8
# 1154   $30,101,577     2523   $30,101,577        Jan 8
#
#                               Distributor  Year_y
# 0     Walt Disney Studios Motion Pictures    2010
# 1                      Paramount Pictures    2010
# 2                      Paramount Pictures    2010
# 3                      Paramount Pictures    2010
# 4                      Paramount Pictures    2010
# ...                                   ...     ...
# 1150                            Lionsgate    2010
# 1151                            Lionsgate    2010
# 1152                            Lionsgate    2010
# 1153                            Lionsgate    2010
# 1154                            Lionsgate    2010
#
# [1155 rows x 12 columns]

# %%
# display data for cars made in 2009 or 2010 with a strong screen presence
car_mov.loc[(car_mov.Car.str.contains('2009|2010')) & (car_mov.Stars >= 3)]
# Out:
#                               Release  Year_x  \
# 3                          Iron Man 2    2010
# 20         The Twilight Saga: Eclipse    2010
# 29                          Inception    2010
# 67                          Grown Ups    2010
# 251                   Valentine's Day    2010
# 260                   Valentine's Day    2010
# 288                          Due Date    2010
# 293                          Due Date    2010
# 502                    Little Fockers    2010
# 561                        The A-Team    2010
# 582                  It's Complicated    2010
# 727                            Takers    2010
# 752                 Letters to Juliet    2010
# 762                Life as We Know It    2010
# 795   Wall Street: Money Never Sleeps    2010
# 815                          Kick-Ass    2010
# 1047                        Marmaduke    2010
#
#                                           Car  \
# 3                         2010 audi r8 spyder
# 20                            2010 volvo xc60
# 29                       2009 hyundai genesis
# 67                    2009 chevrolet suburban
# 251                 2010 ford transit connect
# 260                     2010 toyota prius iii
# 288    2010 land-rover range rover series iii
# 293                       2010 subaru impreza
# 502                     2010 chevrolet malibu
# 561        2010 mercedes-benz e-klasse [w212]
# 582   2009 porsche 911 carrera s cabrio [997]
# 727    2009 land-rover range rover series iii
# 752                           2009 fiat 500 c
# 762               2009 volkswagen routan [rt]
# 795                     2010 toyota prius iii
# 815                         2009 ford mustang
# 1047                  2009 mini cooper cabrio
#
#                                                     url  Stars  Rank  \
# 3        vehicle_239415-Audi-R8-Spyder-Typ-42-2010.html      3     4
# 20                  vehicle_359180-Volvo-XC60-2010.html      3     5
# 29          vehicle_315034-Hyundai-Genesis-BH-2009.html      3     6
# 67    vehicle_351089-Chevrolet-Suburban-GMT931-2009....      3    13
# 251       vehicle_316137-Ford-Transit-Connect-2010.html      3    22
# 260         vehicle_316128-Toyota-Prius-ZVW30-2010.html      3    22
# 288   vehicle_325355-Land-Rover-Range-Rover-L322-201...      3    26
# 293          vehicle_325351-Subaru-Impreza-GH-2010.html      4    26
# 502           vehicle_386490-Chevrolet-Malibu-2010.html      3    37
# 561   vehicle_316899-Mercedes-Benz-E-Klasse-W212-201...      3    42
# 582   vehicle_304056-Porsche-911-Carrera-S-Cabrio-99...      3    45
# 727   vehicle_330848-Land-Rover-Range-Rover-L322-200...      3    60
# 752             vehicle_327012-Fiat-500-C-312-2009.html      3    63
# 762       vehicle_369815-Volkswagen-Routan-RT-2009.html      3    64
# 795         vehicle_368590-Toyota-Prius-ZVW30-2010.html      3    65
# 815          vehicle_307353-Ford-Mustang-S197-2009.html      3    70
# 1047    vehicle_343525-MINI-Cooper-Cabrio-R57-2009.html      3    91
#
#              Gross Theaters   Total Gross Release Date  \
# 3     $312,433,331     4390  $312,433,331        May 7
# 20    $300,531,751     4468  $300,531,751       Jun 30
# 29    $292,558,188     3792  $292,576,195       Jul 16
# 67    $162,001,186     3534  $162,001,186       Jun 25
# 251   $110,485,654     3665  $110,485,654       Feb 12
# 260   $110,485,654     3665  $110,485,654       Feb 12
# 288    $98,935,039     3365  $100,539,043        Nov 5
# 293    $98,935,039     3365  $100,539,043        Nov 5
# 502    $84,557,425     3675  $148,438,600       Dec 22
# 561    $77,222,099     3544   $77,222,099       Jun 11
# 582    $72,359,500     2955  $112,735,375       Dec 25
# 727    $57,744,720     2206   $57,744,720       Aug 27
# 752    $53,032,453     2975   $53,032,453       May 14
# 762    $52,727,343     3150   $53,374,681        Oct 8
# 795    $52,474,616     3597   $52,474,616       Sep 24
# 815    $48,071,303     3065   $48,071,303       Apr 16
# 1047   $33,644,788     3213   $33,644,788        Jun 4
#
#                             Distributor  Year_y
# 3                    Paramount Pictures    2010
# 20                 Summit Entertainment    2010
# 29                         Warner Bros.    2010
# 67    Sony Pictures Entertainment (SPE)    2010
# 251                        Warner Bros.    2010
# 260                        Warner Bros.    2010
# 288                        Warner Bros.    2010
# 293                        Warner Bros.    2010
# 502                  Universal Pictures    2010
# 561               Twentieth Century Fox    2010
# 582                  Universal Pictures    2010
# 727                         Screen Gems    2010
# 752                Summit Entertainment    2010
# 762                        Warner Bros.    2010
# 795               Twentieth Century Fox    2010
# 815                           Lionsgate    2010
# 1047              Twentieth Century Fox    2010

# %%
# create a clean DataFrame that only keeps relevant columns
clean_car_mov = car_mov[['Release', 'Car', 'Stars', 'Rank', 'Gross', 'Year_y']]
# rename the column for Year_y
clean_car_mov.rename(columns = {'Year_y':'Year'}, inplace = True)
# Out:
# C:\Users\stuhu\anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
# create a list of years, as strings, to search for cars made in the decade prior to our analysis range
#yrs = np.arange(2000, 2011, 1).tolist()
#years = [str(x) for x in yrs]
#print(years)

# %%
# display cars made in the years 2000 through 2010
#all_years = "|".join(years)
#clean_car_mov.loc[clean_car_mov.Car.str.contains(all_years)][["Car","Release","Rank","Gross"]].sort_values(by='Car')

# %%
# look at the cars made in 2009 or 2010
clean_car_mov.loc[clean_car_mov.Car.str.contains('2009|2010') & (clean_car_mov.Stars >= 3)]
# Out:
#                               Release  \
# 3                          Iron Man 2
# 20         The Twilight Saga: Eclipse
# 29                          Inception
# 67                          Grown Ups
# 251                   Valentine's Day
# 260                   Valentine's Day
# 288                          Due Date
# 293                          Due Date
# 502                    Little Fockers
# 561                        The A-Team
# 582                  It's Complicated
# 727                            Takers
# 752                 Letters to Juliet
# 762                Life as We Know It
# 795   Wall Street: Money Never Sleeps
# 815                          Kick-Ass
# 1047                        Marmaduke
#
#                                           Car  Stars  Rank         Gross  Year
# 3                         2010 audi r8 spyder      3     4  $312,433,331  2010
# 20                            2010 volvo xc60      3     5  $300,531,751  2010
# 29                       2009 hyundai genesis      3     6  $292,558,188  2010
# 67                    2009 chevrolet suburban      3    13  $162,001,186  2010
# 251                 2010 ford transit connect      3    22  $110,485,654  2010
# 260                     2010 toyota prius iii      3    22  $110,485,654  2010
# 288    2010 land-rover range rover series iii      3    26   $98,935,039  2010
# 293                       2010 subaru impreza      4    26   $98,935,039  2010
# 502                     2010 chevrolet malibu      3    37   $84,557,425  2010
# 561        2010 mercedes-benz e-klasse [w212]      3    42   $77,222,099  2010
# 582   2009 porsche 911 carrera s cabrio [997]      3    45   $72,359,500  2010
# 727    2009 land-rover range rover series iii      3    60   $57,744,720  2010
# 752                           2009 fiat 500 c      3    63   $53,032,453  2010
# 762               2009 volkswagen routan [rt]      3    64   $52,727,343  2010
# 795                     2010 toyota prius iii      3    65   $52,474,616  2010
# 815                         2009 ford mustang      3    70   $48,071,303  2010
# 1047                  2009 mini cooper cabrio      3    91   $33,644,788  2010
