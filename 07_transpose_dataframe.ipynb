# %%
import pandas as pd

# %%
data = pd.read_csv("output_data/Car_Sales_2009-2020_edited.csv")

# %%
data
# Out:
#         Vehicle     2009     2010     2011     2012     2013     2014  \
# 0     Acura ILX      NaN      NaN      NaN  12251.0  20430.0  17854.0
# 1     Acura MDX  31178.0  47210.0  43271.0  50854.0  53040.0  65603.0
# 2     Acura NSX      NaN      NaN      NaN      NaN      NaN      NaN
# 3     Acura RDX  10153.0  14975.0  15196.0  29520.0  44750.0  44865.0
# 4      Acura RL   2043.0   2037.0   1096.0    379.0     39.0      NaN
# ..          ...      ...      ...      ...      ...      ...      ...
# 452   Volvo V70   1816.0    895.0      NaN      NaN      NaN      NaN
# 453  Volvo XC40      NaN      NaN      NaN      NaN      NaN      NaN
# 454  Volvo XC60   9262.0  12030.0  12932.0  19139.0  19766.0  19276.0
# 455  Volvo XC70   5825.0   6626.0   5716.0   5513.0   4882.0   5093.0
# 456  Volvo XC90  10757.0  10119.0  10609.0   9513.0   6845.0   3952.0
#
#         2015     2016     2017     2018     2019     2020
# 0    18531.0  14597.0  11757.0  11273.0  14685.0  13414.0
# ...

# %%
# set the index
data = data.set_index("Vehicle")

# %%
# remove index heading
data.rename_axis(None, inplace=True)
data
# Out:
#                2009     2010     2011     2012     2013     2014     2015  \
# Acura ILX       NaN      NaN      NaN  12251.0  20430.0  17854.0  18531.0
# Acura MDX   31178.0  47210.0  43271.0  50854.0  53040.0  65603.0  58208.0
# Acura NSX       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Acura RDX   10153.0  14975.0  15196.0  29520.0  44750.0  44865.0  51026.0
# Acura RL     2043.0   2037.0   1096.0    379.0     39.0      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...      ...
# Volvo V70    1816.0    895.0      NaN      NaN      NaN      NaN      NaN
# Volvo XC40      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Volvo XC60   9262.0  12030.0  12932.0  19139.0  19766.0  19276.0  26134.0
# Volvo XC70   5825.0   6626.0   5716.0   5513.0   4882.0   5093.0   5118.0
# Volvo XC90  10757.0  10119.0  10609.0   9513.0   6845.0   3952.0  12777.0
#
#                2016     2017     2018     2019     2020
# ...

# %%
# return the transpose of the DataFrame
new_data = data.transpose()

# %%
# reset index
new_data = new_data.reset_index()

# %%
# rename Vehicle column to Years
new_data.rename(columns = {'index':'Years'}, inplace = True)

# %%
new_data
# Out:
#    Years  Acura ILX  Acura MDX  Acura NSX  Acura RDX  Acura RL  Acura RLX  \
# 0   2009        NaN    31178.0        NaN    10153.0    2043.0        NaN
# 1   2010        NaN    47210.0        NaN    14975.0    2037.0        NaN
# 2   2011        NaN    43271.0        NaN    15196.0    1096.0        NaN
# 3   2012    12251.0    50854.0        NaN    29520.0     379.0        NaN
# 4   2013    20430.0    53040.0        NaN    44750.0      39.0     5014.0
# 5   2014    17854.0    65603.0        NaN    44865.0       NaN     3413.0
# 6   2015    18531.0    58208.0        NaN    51026.0       NaN     2195.0
# 7   2016    14597.0    55495.0      269.0    52361.0       NaN     1478.0
# 8   2017    11757.0    54886.0      581.0    51295.0       NaN     1237.0
# 9   2018    11273.0    51512.0      170.0    63580.0       NaN     1931.0
# 10  2019    14685.0    52019.0      238.0    62876.0       NaN     1019.0
# 11  2020    13414.0    47816.0      128.0    52785.0       NaN     1054.0
#
# ...

# %%
new_data.to_csv("output_data/test.csv", index=False, header=True)
