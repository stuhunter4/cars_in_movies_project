# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Clean up the car in movies raw dataset for 2010

# %%
old_year = 2019
new_year = 2020

# %%
# read in raw data for cars in movies
raw_2010 = pd.read_csv("output_data/raw/cars in movies/2021_03_14_2020Cars.csv")
raw_2010
# Out:
#                 Release  Year                            Car  \
# 0     Bad Boys for Life  2020  2007 BAE Systems Caiman CMTV
# 1     Bad Boys for Life  2020              2006 BMW 3 [E90]
# 2     Bad Boys for Life  2020              2004 BMW 5 [E60]
# 3     Bad Boys for Life  2020                  BMW M6 [E63]
# 4     Bad Boys for Life  2020            2003 Buick Century
# ...                 ...   ...                            ...
# 1417           Vanguard  2020                2007 Volvo S60
# 1418           Vanguard  2020               2015 Volvo XC90
# 1419           Vanguard  2020         2013 WaterCar Panther
# 1420           Vanguard  2020   2012 Wright New Routemaster
# 1421           Vanguard  2020            2003 Yamaha YZF-R6
#
#                                                     url Stars
# 0     vehicle_1368488-BAE-Systems-Caiman-CMTV-2007.html     2
# 1                   vehicle_1368485-BMW-3-E90-2006.html     1
# 2                   vehicle_1368481-BMW-5-E60-2004.html     2
# 3                       vehicle_1368482-BMW-M6-E63.html     1
# 4               vehicle_1368473-Buick-Century-2003.html     1
# ...                                                 ...   ...
# 1417                vehicle_1447514-Volvo-S60-2007.html     2
# 1418               vehicle_1447734-Volvo-XC90-2015.html     3
# 1419         vehicle_1447595-WaterCar-Panther-2013.html     3
# 1420   vehicle_1447645-Wright-New-Routemaster-2012.html     1
# 1421            vehicle_1447616-Yamaha-YZF-R6-2003.html     3
#
# [1422 rows x 5 columns]

# %%
# how many null elements are in each column
raw_2010.isnull().sum()
# Out:
# Release    0
# Year       0
# Car        0
# url        0
# Stars      0
# dtype: int64

# %%
# how common are some cars at the most frequent versus least
raw_2010.Car.value_counts()
# Out:
# unknown                      30
# Ford Crown Victoria           7
# 1992 Ford Econoline           6
# Unknown                       6
# 2015 Ford Transit             5
#                              ..
# 2019 Lamborghini Urus         1
# Fahd APC                      1
# Grumman-Olson Route Star      1
# 2006 Peugeot 206              1
# 2017 Honda CR-V               1
# Name: Car, Length: 1172, dtype: int64

# %%
# top 20 most movie appearances
raw_2010.Car.value_counts().nlargest(20)
# Out:
# unknown                                  30
# Ford Crown Victoria                       7
# 1992 Ford Econoline                       6
# Unknown                                   6
# 2015 Ford Transit                         5
# 2013 Ford Police Interceptor Utility      5
# 2006 Ford Crown Victoria                  5
# 1965 Ford Mustang                         5
# 1980 Chevrolet Caprice Classic            5
# 2015 Cadillac Escalade ESV                4
# 1995 Ford Crown Victoria                  4
# 1983 Ford LTD Crown Victoria              4
# 2013 Ford Police Interceptor              4
# 2007 Chevrolet Tahoe                      4
# 2017 Nissan Rogue                         4
# 2016 Nissan Sentra                        4
# Mercedes-Benz SL [R107]                   4
# Ford F-Series                             4
# 2015 Chevrolet Suburban                   4
# 2018 Mercedes-Benz S-Klasse [W222]        3
# Name: Car, dtype: int64

# %%
# check data types
raw_2010.dtypes
# Out:
# Release    object
# Year        int64
# Car        object
# url        object
# Stars      object
# dtype: object

# %%
# how many cars are there for each ratings category
raw_2010.Stars.value_counts()
# Out:
# 1      982
# 2      289
# 3      121
# 4       24
# Nan      5
# 5        1
# Name: Stars, dtype: int64

# %%
# return a DataFrame without any missing ratings element
clean_2010 = raw_2010.loc[raw_2010.Stars != 'Nan']

# %%
# convert Stars ratings column to integers
clean_2010.Stars = clean_2010.Stars.astype(int)
# Out:
# C:\Users\stuhu\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
# return a new DataFrame that removes irrelevant car elements
new = clean_2010.loc[(~clean_2010.Car.str.contains('Unknown'))\
                     & (~clean_2010.Car.str.contains('unknown')) & (~clean_2010.Car.str.contains('Movie'))]

# %%
# reset the index and display
new = new.reset_index(drop=True)
new
# Out:
#                 Release  Year                            Car  \
# 0     Bad Boys for Life  2020  2007 BAE Systems Caiman CMTV
# 1     Bad Boys for Life  2020              2006 BMW 3 [E90]
# 2     Bad Boys for Life  2020              2004 BMW 5 [E60]
# 3     Bad Boys for Life  2020                  BMW M6 [E63]
# 4     Bad Boys for Life  2020            2003 Buick Century
# ...                 ...   ...                            ...
# 1357           Vanguard  2020                2007 Volvo S60
# 1358           Vanguard  2020               2015 Volvo XC90
# 1359           Vanguard  2020         2013 WaterCar Panther
# 1360           Vanguard  2020   2012 Wright New Routemaster
# 1361           Vanguard  2020            2003 Yamaha YZF-R6
#
#                                                     url  Stars
# 0     vehicle_1368488-BAE-Systems-Caiman-CMTV-2007.html      2
# 1                   vehicle_1368485-BMW-3-E90-2006.html      1
# 2                   vehicle_1368481-BMW-5-E60-2004.html      2
# 3                       vehicle_1368482-BMW-M6-E63.html      1
# 4               vehicle_1368473-Buick-Century-2003.html      1
# ...                                                 ...    ...
# 1357                vehicle_1447514-Volvo-S60-2007.html      2
# 1358               vehicle_1447734-Volvo-XC90-2015.html      3
# 1359         vehicle_1447595-WaterCar-Panther-2013.html      3
# 1360   vehicle_1447645-Wright-New-Routemaster-2012.html      1
# 1361            vehicle_1447616-Yamaha-YZF-R6-2003.html      3
#
# [1362 rows x 5 columns]

# %%
# how many unique vehicles are there
len(new.Car.unique())
# Out:
# 1147

# %%
# in order to start working with the Car column, remove whitespaces at both sides of the string elements
for index, row in new.iterrows():
    new.Car[index] = new.Car[index].strip()
# Out:
# <ipython-input-14-7b04d79dfdac>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new.Car[index] = new.Car[index].strip()

# %% [markdown]
# ### Use car sales data to further filter cars in movies

# %%
# read in car sales data to use as a filter for the Car column
sales = pd.read_csv('output_data/Car_Sales_2009-2020_edited.csv')
sales
# Out:
#         Vehicle     2009     2010     2011     2012     2013     2014  \
# 0     Acura ILX      NaN      NaN      NaN  12251.0  20430.0  17854.0
# 1     Acura MDX  31178.0  47210.0  43271.0  50854.0  53040.0  65603.0
# 2     Acura NSX      NaN      NaN      NaN      NaN      NaN      NaN
# 3     Acura RDX  10153.0  14975.0  15196.0  29520.0  44750.0  44865.0
# 4      Acura RL   2043.0   2037.0   1096.0    379.0     39.0      NaN
# ..          ...      ...      ...      ...      ...      ...      ...
# 452   Volvo V70   1816.0    895.0      NaN      NaN      NaN      NaN
# 453  Volvo XC40      NaN      NaN      NaN      NaN      NaN      NaN
# 454  Volvo XC60   9262.0  12030.0  12932.0  19139.0  19766.0  19276.0
# 455  Volvo XC70   5825.0   6626.0   5716.0   5513.0   4882.0   5093.0
# 456  Volvo XC90  10757.0  10119.0  10609.0   9513.0   6845.0   3952.0
#
#         2015     2016     2017     2018     2019     2020
# 0    18531.0  14597.0  11757.0  11273.0  14685.0  13414.0
# 1    58208.0  55495.0  54886.0  51512.0  52019.0  47816.0
# 2        NaN    269.0    581.0    170.0    238.0    128.0
# 3    51026.0  52361.0  51295.0  63580.0  62876.0  52785.0
# 4        NaN      NaN      NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...      ...      ...
# 452      NaN      NaN      NaN      NaN      NaN      NaN
# 453      NaN      NaN      NaN  12420.0  17647.0  23778.0
# 454  26134.0  20452.0  22516.0  32689.0  30578.0  32078.0
# 455   5118.0   5425.0      NaN      NaN      NaN      NaN
# 456  12777.0  32526.0  30996.0  31609.0  35760.0  34251.0
#
# [457 rows x 13 columns]

# %%
# list comprehension to apply lower method to string elements in the Car column...
# ...to better filter the data for vehicles in the car sales dataset
lower_cars = sales.copy()
lower_cars.Vehicle = [car.lower() for car in lower_cars.Vehicle]

# %%
# same operations for the car in movie dataset
lower_car_mov = new.copy()
lower_car_mov.Car = [car.lower() for car in lower_car_mov.Car]

# %%
# create list of cars with sales data
vehicles = lower_cars.Vehicle.unique().tolist()
vehicles_og = lower_cars.Vehicle.unique().tolist()

# %%
print(vehicles)
# Out:
# ['acura ilx', 'acura mdx', 'acura nsx', 'acura rdx', 'acura rl', 'acura rlx', 'acura tl', 'acura tlx', 'acura tsx', 'acura zdx', 'alfa romeo 4c', 'alfa romeo giulia', 'alfa romeo stelvio', 'audi a3', 'audi a3 e-tron', 'audi a4', 'audi a4 allroad', 'audi a4 avant', 'audi a4 sedan', 'audi a5', 'audi a6', 'audi a7', 'audi a8', 'audi q3', 'audi q5', 'audi q7', 'audi q8', 'audi r8', 'audi tt', 'audi etron', 'bmw 1-series', 'bmw 2-series', 'bmw 3-series', 'bmw 4-series', 'bmw 5-series', 'bmw 6-series', 'bmw 7-series', 'bmw 8-series', 'bmw x1', 'bmw x2', 'bmw x3', 'bmw x4', 'bmw x5', 'bmw x6', 'bmw x7', 'bmw z4', 'bmw i3', 'bmw i8', 'bentley bentayga', 'bentley continental gt', 'bentley flying spur', 'bentley mulsanne', 'buick cascada', 'buick enclave', 'buick encore', 'buick encore gx', 'buick envision', 'buick lacrosse', 'buick lucerne', 'buick regal', 'buick verano', 'cadillac ats', 'cadillac ct4', 'cadillac ct5', 'cadillac ct6', 'cadillac cts', 'cadillac dts', 'cadillac elr', 'cadillac escalade', 'cadillac srx', 'cadillac sts', 'cadillac xlr', 'cadillac xt4', 'cadillac xt5', 'cadillac xt6', 'cadillac xts', 'chevrolet avalanche', 'chevrolet aveo', 'chevrolet blazer', 'chevrolet bolt', 'chevrolet camaro', 'chevrolet caprice ppv', 'chevrolet captiva sport', 'chevrolet city express', 'chevrolet cobalt', 'chevrolet colorado', 'chevrolet corvette', 'chevrolet cruze', 'chevrolet equinox', 'chevrolet express', 'chevrolet hhr', 'chevrolet impala', 'chevrolet malibu', 'chevrolet ss', 'chevrolet silverado', 'chevrolet sonic', 'chevrolet spark', 'chevrolet suburban', 'chevrolet tahoe', 'chevrolet trailblazer', 'chevrolet traverse', 'chevrolet trax', 'chevrolet uplander', 'chevrolet volt', 'chrysler 200', 'chrysler 300', 'chrysler aspen', 'chrysler pt cruiser', 'chrysler pacifica', 'chrysler sebring', 'chrysler town & country', 'chrysler town and country', 'dodge avenger', 'dodge caliber', 'dodge challenger', 'dodge charger', 'dodge dakota', 'dodge dart', 'dodge durango', 'dodge grand caravan', 'dodge journey', 'dodge nitro', 'dodge ram', 'dodge viper', 'fiat 124 spider', 'fiat 500', 'fiat 500l', 'fiat 500x', 'ford bronco sport', 'ford c-max', 'ford crown victoria', 'ford e-series', 'ford ecosport', 'ford edge', 'ford escape', 'ford expedition', 'ford explorer', 'ford explorer police interceptor ', 'ford f-series', 'ford fiesta', 'ford flex', 'ford focus', 'ford fusion', 'ford gt', 'ford mustang', 'ford ranger', 'ford taurus', 'ford taurus police interceptor', 'ford taurus x', 'ford transit', 'ford transit connect', 'gmc acadia', 'gmc canyon', 'gmc envoy', 'gmc savana', 'gmc sierra', 'gmc terrain', 'gmc torrent', 'gmc yukon', 'gmc yukon xl', 'genesis g70', 'genesis g80', 'genesis g90', 'genesis gv80', 'honda accord', 'honda cr-v', 'honda cr-z', 'honda civic', 'honda clarity fcv', 'honda crosstour', 'honda element', 'honda fcx', 'honda fit', 'honda hr-v', 'honda insight', 'honda odyssey', 'honda passport', 'honda pilot', 'honda ridgeline', 'honda s2000', 'hummer h2', 'hummer h3', 'hyundai accent', 'hyundai azera', 'hyundai elantra', 'hyundai equus', 'hyundai genesis', 'hyundai ioniq', 'hyundai kona', 'hyundai nexo', 'hyundai palisade', 'hyundai santa fe', 'hyundai sonata', 'hyundai tucson', 'hyundai veloster', 'hyundai venue', 'hyundai veracruz', 'infiniti g', 'infiniti q40', 'infiniti q50', 'infiniti q60', 'infiniti q70/m', 'infiniti qx30', 'infiniti ex/qx50', 'infiniti qx60/jx', 'infiniti qx70/fx', 'infiniti qx80/qx56', 'jaguar e-pace', 'jaguar f-pace', 'jaguar f-type', 'jaguar i-pace', 'jaguar xe', 'jaguar xf', 'jaguar xj', 'jaguar xk', 'jeep cherokee', 'jeep commander', 'jeep compass', 'jeep gladiator', 'jeep grand cherokee', 'jeep liberty', 'jeep patriot', 'jeep renegade', 'jeep wrangler', 'kia amanti', 'kia borrego', 'kia cadenza', 'kia forte', 'kia k5', 'kia k900', 'kia niro', 'kia optima', 'kia rio', 'kia rondo', 'kia sedona', 'kia seltos', 'kia sorento', 'kia soul', 'kia spectra', 'kia sportage', 'kia stinger', 'kia telluride', 'land  ...

# %%
# create empty dictionary to fill with removed vehicle strings, as a reference
vehicle_refs = {}

# %%
# create empty list to store vehicle strings to remove
remove_veh = []

# loop through list of vehicles to create separate strings for vehicles with two titles
for vehicle in vehicles:
    if '/' in vehicle:
        # find combined terms to distinguish, separate on / delimiter
        veh_split = vehicle.split('/')
        # only first index string has brand attached, join brand to second index string
        veh_second = " ".join([veh_split[0].split(' ')[0], veh_split[1]])
        # attach both vehicle strings to the vehicles list...
        vehicles.append(veh_split[0])
        vehicles.append(veh_second)
        
        # create key.value in reference dictionary
        vehicle_refs[veh_split[0]] = vehicle
        vehicle_refs[veh_second] = vehicle
        
        # ...and append original string to a list for deletion later
        remove_veh.append(vehicle)

# loop through remove_vehicle list to delete strings with / delimiter
for vehicle in remove_veh:
    vehicles.remove(vehicle)

# %%
# edit vehicles list using conditionals...
# ...allowing list to catch every car from the sales dataset
for x in range(len(vehicles)):
    if 'bmw' in vehicles[x]:
        y = vehicles[x]
        vehicles[x] = vehicles[x].replace('-series', '')
        if y != vehicles[x]:
            vehicle_refs[vehicles[x]] = y
    elif 'mercedes-benz' in vehicles[x]:
        y = vehicles[x]
        vehicles[x] = vehicles[x].replace('-class', '')
        if y != vehicles[x]:
            vehicle_refs[vehicles[x]] = y
    elif 'land rover' in vehicles[x]:
        y = vehicles[x]
        vehicles[x] = vehicles[x].replace('land rover', 'land-rover')
        if y != vehicles[x]:
            vehicle_refs[vehicles[x]] = y
    elif 'ford' in vehicles[x]:
        y = vehicles[x]
        vehicles[x] = vehicles[x].replace('series', '')
        if y != vehicles[x]:
            vehicle_refs[vehicles[x]] = y
    else:
        pass

# %%
# append four exceptions that have been left from the code
exceptions = ['scion im', 'scion fr-s', 'scion ia', 'land-rover l4']
vehicles.extend(exceptions)

vehicle_refs['scion im'] = 'toyota corolla im/auris/scion im'
vehicle_refs['scion fr-s'] = 'toyota 86/scion fr-s'
vehicle_refs['scion ia'] = 'toyota yaris ia/scion ia'
vehicle_refs['land-rover l4'] = 'land rover discovery / lr4'

# %%
print(vehicles)
# Out:
# ['acura ilx', 'acura mdx', 'acura nsx', 'acura rdx', 'acura rl', 'acura rlx', 'acura tl', 'acura tlx', 'acura tsx', 'acura zdx', 'alfa romeo 4c', 'alfa romeo giulia', 'alfa romeo stelvio', 'audi a3', 'audi a3 e-tron', 'audi a4', 'audi a4 allroad', 'audi a4 avant', 'audi a4 sedan', 'audi a5', 'audi a6', 'audi a7', 'audi a8', 'audi q3', 'audi q5', 'audi q7', 'audi q8', 'audi r8', 'audi tt', 'audi etron', 'bmw 1', 'bmw 2', 'bmw 3', 'bmw 4', 'bmw 5', 'bmw 6', 'bmw 7', 'bmw 8', 'bmw x1', 'bmw x2', 'bmw x3', 'bmw x4', 'bmw x5', 'bmw x6', 'bmw x7', 'bmw z4', 'bmw i3', 'bmw i8', 'bentley bentayga', 'bentley continental gt', 'bentley flying spur', 'bentley mulsanne', 'buick cascada', 'buick enclave', 'buick encore', 'buick encore gx', 'buick envision', 'buick lacrosse', 'buick lucerne', 'buick regal', 'buick verano', 'cadillac ats', 'cadillac ct4', 'cadillac ct5', 'cadillac ct6', 'cadillac cts', 'cadillac dts', 'cadillac elr', 'cadillac escalade', 'cadillac srx', 'cadillac sts', 'cadillac xlr', 'cadillac xt4', 'cadillac xt5', 'cadillac xt6', 'cadillac xts', 'chevrolet avalanche', 'chevrolet aveo', 'chevrolet blazer', 'chevrolet bolt', 'chevrolet camaro', 'chevrolet caprice ppv', 'chevrolet captiva sport', 'chevrolet city express', 'chevrolet cobalt', 'chevrolet colorado', 'chevrolet corvette', 'chevrolet cruze', 'chevrolet equinox', 'chevrolet express', 'chevrolet hhr', 'chevrolet impala', 'chevrolet malibu', 'chevrolet ss', 'chevrolet silverado', 'chevrolet sonic', 'chevrolet spark', 'chevrolet suburban', 'chevrolet tahoe', 'chevrolet trailblazer', 'chevrolet traverse', 'chevrolet trax', 'chevrolet uplander', 'chevrolet volt', 'chrysler 200', 'chrysler 300', 'chrysler aspen', 'chrysler pt cruiser', 'chrysler pacifica', 'chrysler sebring', 'chrysler town & country', 'chrysler town and country', 'dodge avenger', 'dodge caliber', 'dodge challenger', 'dodge charger', 'dodge dakota', 'dodge dart', 'dodge durango', 'dodge grand caravan', 'dodge journey', 'dodge nitro', 'dodge ram', 'dodge viper', 'fiat 124 spider', 'fiat 500', 'fiat 500l', 'fiat 500x', 'ford bronco sport', 'ford c-max', 'ford crown victoria', 'ford e-', 'ford ecosport', 'ford edge', 'ford escape', 'ford expedition', 'ford explorer', 'ford explorer police interceptor ', 'ford f-', 'ford fiesta', 'ford flex', 'ford focus', 'ford fusion', 'ford gt', 'ford mustang', 'ford ranger', 'ford taurus', 'ford taurus police interceptor', 'ford taurus x', 'ford transit', 'ford transit connect', 'gmc acadia', 'gmc canyon', 'gmc envoy', 'gmc savana', 'gmc sierra', 'gmc terrain', 'gmc torrent', 'gmc yukon', 'gmc yukon xl', 'genesis g70', 'genesis g80', 'genesis g90', 'genesis gv80', 'honda accord', 'honda cr-v', 'honda cr-z', 'honda civic', 'honda clarity fcv', 'honda crosstour', 'honda element', 'honda fcx', 'honda fit', 'honda hr-v', 'honda insight', 'honda odyssey', 'honda passport', 'honda pilot', 'honda ridgeline', 'honda s2000', 'hummer h2', 'hummer h3', 'hyundai accent', 'hyundai azera', 'hyundai elantra', 'hyundai equus', 'hyundai genesis', 'hyundai ioniq', 'hyundai kona', 'hyundai nexo', 'hyundai palisade', 'hyundai santa fe', 'hyundai sonata', 'hyundai tucson', 'hyundai veloster', 'hyundai venue', 'hyundai veracruz', 'infiniti g', 'infiniti q40', 'infiniti q50', 'infiniti q60', 'infiniti qx30', 'jaguar e-pace', 'jaguar f-pace', 'jaguar f-type', 'jaguar i-pace', 'jaguar xe', 'jaguar xf', 'jaguar xj', 'jaguar xk', 'jeep cherokee', 'jeep commander', 'jeep compass', 'jeep gladiator', 'jeep grand cherokee', 'jeep liberty', 'jeep patriot', 'jeep renegade', 'jeep wrangler', 'kia amanti', 'kia borrego', 'kia cadenza', 'kia forte', 'kia k5', 'kia k900', 'kia niro', 'kia optima', 'kia rio', 'kia rondo', 'kia sedona', 'kia seltos', 'kia sorento', 'kia soul', 'kia spectra', 'kia sportage', 'kia stinger', 'kia telluride', 'land-rover defender', 'land-rover discovery sport', 'land-rover lr2', 'land-rover range rover', 'land-rover range rover evoque', 'land-rover range rover sport', 'land-rover  ...

# %%
# display dictionary of vehicle references
vehicle_refs
# Out:
# {'infiniti q70': 'infiniti q70/m',
#  'infiniti m': 'infiniti q70/m',
#  'infiniti ex': 'infiniti ex/qx50',
#  'infiniti qx50': 'infiniti ex/qx50',
#  'infiniti qx60': 'infiniti qx60/jx',
#  'infiniti jx': 'infiniti qx60/jx',
#  'infiniti qx70': 'infiniti qx70/fx',
#  'infiniti fx': 'infiniti qx70/fx',
#  'infiniti qx80': 'infiniti qx80/qx56',
#  'infiniti qx56': 'infiniti qx80/qx56',
#  'land rover discovery ': 'land rover discovery / lr4',
#  'land  lr4': 'land rover discovery / lr4',
#  'lexus es': 'lexus es/es350',
#  'lexus es350': 'lexus es/es350',
#  'lexus gx': 'lexus gx/gx460',
#  'lexus gx460': 'lexus gx/gx460',
#  'lexus hs': 'lexus hs/hs250h',
#  'lexus hs250h': 'lexus hs/hs250h',
#  'lexus lx': 'lexus lx/lx570',
#  'lexus lx570': 'lexus lx/lx570',
#  'lincoln mkx': 'lincoln mkx/nautilus',
#  'lincoln nautilus': 'lincoln mkx/nautilus',
#  'mercedes-benz gl-class': 'mercedes-benz gl-class/gls-class',
#  'mercedes-benz gls-class': 'mercedes-benz gl-class/gls-class',
#  'mercedes-benz gle-class': 'mercedes-benz gle-class/m-class',
#  'mercedes-benz m-class': 'mercedes-benz gle-class/m-class',
#  'mercedes-benz metris': 'mercedes-benz metris/vito',
#  'mercedes-benz vito': 'mercedes-benz metris/vito',
#  'mercedes-benz slk-class': 'mercedes-benz slk-class/slc-class',
#  'mercedes-benz slc-class': 'mercedes-benz slk-class/slc-class',
#  'mitsubishi eclipse': 'mitsubishi eclipse/spyder',
#  'mitsubishi spyder': 'mitsubishi eclipse/spyder',
#  'nissan 370z': 'nissan 370z/350z',
#  'nissan 350z': 'nissan 370z/350z',
#  'subaru impreza': 'subaru impreza/wrx/wrx sti',
#  'subaru wrx': 'subaru impreza/wrx/wrx sti',
#  'subaru xv crosstrek': 'subaru xv crosstrek/crosstrek',
#  'subaru crosstrek': 'subaru xv crosstrek/crosstrek',
#  'suzuki forenza': 'suzuki forenza/reno',
#  'suzuki reno': 'suzuki forenza/reno',
#  'suzuki sx4': 'suzuki sx4/aerio',
#  'suzuki aerio': 'suzuki sx4/aerio',
#  'toyota 86': 'toyota 86/scion fr-s',
#  'toyota scion fr-s': 'toyota 86/scion fr-s',
#  'toyota corolla': 'toyota corolla/matrix',
#  'toyota matrix': 'toyota corolla/matrix',
#  'toyota corolla im': 'toyota corolla im/auris/scion im',
#  'toyota auris': 'toyota corolla im/auris/scion im',
#  'toyota yaris ia': 'toyota yaris ia/scion ia',
#  'toyota scion ia': 'toyota yaris ia/scion ia',
#  'volkswagen golf': 'volkswagen golf/gti/r/sportwagen alltrack',
#  'volkswagen gti': 'volkswagen golf/gti/r/sportwagen alltrack',
#  'volvo s60': 'volvo s60/v60',
#  'volvo v60': 'volvo s60/v60',
#  'volvo s90': 'volvo s90/v90',
#  'volvo v90': 'volvo s90/v90',
#  'bmw 1': 'bmw 1-series',
#  'bmw 2': 'bmw 2-series',
#  'bmw 3': 'bmw 3-series',
#  'bmw 4': 'bmw 4-series',
#  'bmw 5': 'bmw 5-series',
#  'bmw 6': 'bmw 6-series',
#  'bmw 7': 'bmw 7-series',
#  'bmw 8': 'bmw 8-series',
#  'ford e-': 'ford e-series',
#  'ford f-': 'ford f-series',
#  'land-rover defender': 'land rover defender',
#  'land-rover discovery sport': 'land rover discovery sport',
#  'land-rover lr2': 'land rover lr2',
#  'land-rover range rover': 'land rover range rover',
#  'land-rover range rover evoque': 'land rover range rover evoque',
#  'land-rover range rover sport': 'land rover range rover sport',
#  'land-rover range rover velar': 'land rover range rover velar',
#  'mercedes-benz a': 'mercedes-benz a-class',
#  'mercedes-benz b': 'mercedes-benz b-class',
#  'mercedes-benz c': 'mercedes-benz c-class',
#  'mercedes-benz cl': 'mercedes-benz cl-class',
#  'mercedes-benz cla': 'mercedes-benz cla-class',
#  'mercedes-benz clk': 'mercedes-benz clk-class',
#  'mercedes-benz cls': 'mercedes-benz cls-class',
#  'mercedes-benz e': 'mercedes-benz e-class',
#  'mercedes-benz g': 'mercedes-benz g-class',
#  'mercedes-benz gla': 'mercedes-benz gla-class',
#  'mercedes-benz glc': 'mercedes-benz glc-class',
#  'mercedes-benz glk': 'mercedes-benz glk-class',
#  'mercedes-benz r': 'mercedes-benz r-class',
#  'mercedes-benz s': 'mercedes-benz s-class',
#  'mercedes-benz sl': 'mercedes-benz sl-class',
#  'land-rover discovery ': 'land rover discovery ',
#  'mercedes-benz gl': 'mercedes-benz gl-class',
#  'mercedes-benz gls': 'mercedes-benz gls-class',
#  'mercedes-benz gle': 'mercedes-benz gle-class',
#  'mercedes-benz m': 'mercedes-benz m-class',
#  'mercedes-benz slk': 'mercedes-benz slk-class',
#  'mercedes-benz slc': 'mercedes-benz slc-class',
#  'scion im': 'toyota corolla im/auris/scion im',
#  'scion fr-s': 'toyota 86/scion fr-s',
#  'scion ia': 'toyota yaris ia/scion ia',
#  'land-rover l4': 'land rover discovery / lr4'}

# %%
# join the list of vehicles using a | delimiter, creating a RegEx pattern to pass through str.contains() next cell
vehicle_var = "|".join(vehicles)

# %%
# create DataFrame where only the cars from our car sales data are included
cars_filtered = lower_car_mov.loc[lower_car_mov.Car.str.contains(vehicle_var)]
cars_filtered
# Out:
#                 Release  Year                                  Car  \
# 1     Bad Boys for Life  2020                     2006 bmw 3 [e90]
# 2     Bad Boys for Life  2020                     2004 bmw 5 [e60]
# 6     Bad Boys for Life  2020                   2018 buick enclave
# 9     Bad Boys for Life  2020           2003 cadillac escalade esv
# 12    Bad Boys for Life  2020  2014 chevrolet corvette stingray c7
# ...                 ...   ...                                  ...
# 1342           Vanguard  2020                   2008 nissan armada
# 1350           Vanguard  2020                  2002 toyota corolla
# 1351           Vanguard  2020               2008 toyota fj cruiser
# 1357           Vanguard  2020                       2007 volvo s60
# 1358           Vanguard  2020                      2015 volvo xc90
#
#                                                     url  Stars
# 1                   vehicle_1368485-BMW-3-E90-2006.html      1
# 2                   vehicle_1368481-BMW-5-E60-2004.html      2
# 6        vehicle_1337754-Buick-Enclave-GMT960-2018.html      1
# 9     vehicle_1368474-Cadillac-Escalade-ESV-GMT830-2...      1
# 12    vehicle_1368503-Chevrolet-Corvette-Stingray-20...      1
# ...                                                 ...    ...
# 1342       vehicle_1447698-Nissan-Armada-TA60-2008.html      2
# 1350      vehicle_1447718-Toyota-Corolla-E120-2002.html      1
# 1351  vehicle_1447724-Toyota-FJ-Cruiser-GSJ15W-2008....      1
# 1357                vehicle_1447514-Volvo-S60-2007.html      2
# 1358               vehicle_1447734-Volvo-XC90-2015.html      3
#
# [731 rows x 5 columns]

# %%
# export both datasets for quick comparisons in excel, given their manageable size
#cars_filtered.to_csv("cars_filtered.csv", index=False, header=True)
#cars_remainder.to_csv("cars_remainder.csv", index=False, header=True)

# %%
# create list from the Car column
cars_list = cars_filtered.Car.tolist()

# %%
# create a dummy list to fill with 'vehicles' data
vehicles_list = np.arange(0, len(cars_filtered), 1).tolist()

# %%
# reconstruct dummy list to contain the reference string for each Car element
for vehicle in vehicles:
    for x in range(len(cars_list)):
        if vehicle in cars_list[x]:
            vehicles_list[x] = vehicle

# %%
# remove column url
cars_filtered = cars_filtered.drop(['url'], axis = 1)

cars_filtered['Vehicle'] = vehicles_list
cars_filtered
# Out:
#                 Release  Year                                  Car  Stars  \
# 1     Bad Boys for Life  2020                     2006 bmw 3 [e90]      1
# 2     Bad Boys for Life  2020                     2004 bmw 5 [e60]      2
# 6     Bad Boys for Life  2020                   2018 buick enclave      1
# 9     Bad Boys for Life  2020           2003 cadillac escalade esv      1
# 12    Bad Boys for Life  2020  2014 chevrolet corvette stingray c7      1
# ...                 ...   ...                                  ...    ...
# 1342           Vanguard  2020                   2008 nissan armada      2
# 1350           Vanguard  2020                  2002 toyota corolla      1
# 1351           Vanguard  2020               2008 toyota fj cruiser      1
# 1357           Vanguard  2020                       2007 volvo s60      2
# 1358           Vanguard  2020                      2015 volvo xc90      3
#
#                  Vehicle
# 1                  bmw 3
# 2                  bmw 5
# 6          buick enclave
# 9      cadillac escalade
# 12    chevrolet corvette
# ...                  ...
# 1342       nissan armada
# 1350      toyota corolla
# 1351   toyota fj cruiser
# 1357           volvo s60
# 1358          volvo xc90
#
# [731 rows x 5 columns]

# %%
# create column of original string labels to reference in a later merge
cars_filtered['Vehicle Original'] = cars_filtered.Vehicle

for key, value in vehicle_refs.items():
    for index,row in cars_filtered.iterrows():
        if key == cars_filtered.Vehicle[index]:
            cars_filtered['Vehicle Original'][index] = value
# Out:
# <ipython-input-33-4c688b3d7741>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars_filtered['Vehicle Original'][index] = value

# %%
cars_filtered
# Out:
#                 Release  Year                                  Car  Stars  \
# 1     Bad Boys for Life  2020                     2006 bmw 3 [e90]      1
# 2     Bad Boys for Life  2020                     2004 bmw 5 [e60]      2
# 6     Bad Boys for Life  2020                   2018 buick enclave      1
# 9     Bad Boys for Life  2020           2003 cadillac escalade esv      1
# 12    Bad Boys for Life  2020  2014 chevrolet corvette stingray c7      1
# ...                 ...   ...                                  ...    ...
# 1342           Vanguard  2020                   2008 nissan armada      2
# 1350           Vanguard  2020                  2002 toyota corolla      1
# 1351           Vanguard  2020               2008 toyota fj cruiser      1
# 1357           Vanguard  2020                       2007 volvo s60      2
# 1358           Vanguard  2020                      2015 volvo xc90      3
#
#                  Vehicle       Vehicle Original
# 1                  bmw 3           bmw 3-series
# 2                  bmw 5           bmw 5-series
# 6          buick enclave          buick enclave
# 9      cadillac escalade      cadillac escalade
# 12    chevrolet corvette     chevrolet corvette
# ...                  ...                    ...
# 1342       nissan armada          nissan armada
# 1350      toyota corolla  toyota corolla/matrix
# 1351   toyota fj cruiser      toyota fj cruiser
# 1357           volvo s60          volvo s60/v60
# 1358          volvo xc90             volvo xc90
#
# [731 rows x 6 columns]

# %%
# read in film data
movies = pd.read_csv('output_data/Top100_Movies_2010-2021.csv')

# %%
# create a DataFrame of only films from the top 2010 grossing films
df10 = movies.loc[movies.Year == new_year]
df10
# Out:
#       Rank                                        Release         Gross  \
# 1000     1                              Bad Boys for Life  $204,417,855
# 1001     2                                           1917  $157,901,466
# 1002     3                             Sonic the Hedgehog  $146,066,470
# 1003     4                        Jumanji: The Next Level  $124,736,710
# 1004     5  Star Wars: Episode IX - The Rise of Skywalker  $124,496,308
# ...    ...                                            ...           ...
# 1095    96                                Cut Throat City      $845,837
# 1096    97                     The Goonies2020 Re-release      $825,000
# 1097    98                            Sarileru Neekevvaru      $821,000
# 1098    99                                       Vanguard      $793,525
# 1099   100                                       Shortcut      $793,084
#
#      Theaters   Total Gross Release Date                          Distributor  \
# 1000     3775  $206,305,244       Jan 17    Sony Pictures Entertainment (SPE)
# 1001     3987  $159,227,644       Dec 25                   Universal Pictures
# 1002     4198  $148,974,665       Feb 14                   Paramount Pictures
# 1003     4227  $320,314,960       Dec 13    Sony Pictures Entertainment (SPE)
# 1004     4406  $515,202,542       Dec 20  Walt Disney Studios Motion Pictures
# ...       ...           ...          ...                                  ...
# 1095      389      $855,894       Aug 21            Well Go USA Entertainment
# 1096      457      $825,000       Jul 10                         Warner Bros.
# 1097      300      $821,000       Jan 10                    Great India Films
# 1098     1375      $793,525       Nov 20                    Gravitas Ventures
# 1099      725      $793,084       Sep 25                    Gravitas Ventures
#
#       Year
# 1000  2020
# 1001  2020
# 1002  2020
# 1003  2020
# 1004  2020
# ...    ...
# 1095  2020
# 1096  2020
# 1097  2020
# 1098  2020
# 1099  2020
#
# [100 rows x 8 columns]

# %%
# create a DataFrame that merges the car and movie data
car_mov = pd.merge(cars_filtered, df10, how="left", on="Release")
car_mov
# Out:
#                Release  Year_x                                  Car  Stars  \
# 0    Bad Boys for Life    2020                     2006 bmw 3 [e90]      1
# 1    Bad Boys for Life    2020                     2004 bmw 5 [e60]      2
# 2    Bad Boys for Life    2020                   2018 buick enclave      1
# 3    Bad Boys for Life    2020           2003 cadillac escalade esv      1
# 4    Bad Boys for Life    2020  2014 chevrolet corvette stingray c7      1
# ..                 ...     ...                                  ...    ...
# 726           Vanguard    2020                   2008 nissan armada      2
# 727           Vanguard    2020                  2002 toyota corolla      1
# 728           Vanguard    2020               2008 toyota fj cruiser      1
# 729           Vanguard    2020                       2007 volvo s60      2
# 730           Vanguard    2020                      2015 volvo xc90      3
#
#                 Vehicle       Vehicle Original  Rank         Gross Theaters  \
# 0                 bmw 3           bmw 3-series     1  $204,417,855     3775
# 1                 bmw 5           bmw 5-series     1  $204,417,855     3775
# 2         buick enclave          buick enclave     1  $204,417,855     3775
# 3     cadillac escalade      cadillac escalade     1  $204,417,855     3775
# 4    chevrolet corvette     chevrolet corvette     1  $204,417,855     3775
# ..                  ...                    ...   ...           ...      ...
# 726       nissan armada          nissan armada    99      $793,525     1375
# 727      toyota corolla  toyota corolla/matrix    99      $793,525     1375
# 728   toyota fj cruiser      toyota fj cruiser    99      $793,525     1375
# 729           volvo s60          volvo s60/v60    99      $793,525     1375
# 730          volvo xc90             volvo xc90    99      $793,525     1375
#
#       Total Gross Release Date                        Distributor  Year_y
# 0    $206,305,244       Jan 17  Sony Pictures Entertainment (SPE)    2020
# 1    $206,305,244       Jan 17  Sony Pictures Entertainment (SPE)    2020
# 2    $206,305,244       Jan 17  Sony Pictures Entertainment (SPE)    2020
# 3    $206,305,244       Jan 17  Sony Pictures Entertainment (SPE)    2020
# 4    $206,305,244       Jan 17  Sony Pictures Entertainment (SPE)    2020
# ..            ...          ...                                ...     ...
# 726      $793,525       Nov 20                  Gravitas Ventures    2020
# 727      $793,525       Nov 20                  Gravitas Ventures    2020
# 728      $793,525       Nov 20                  Gravitas Ventures    2020
# 729      $793,525       Nov 20                  Gravitas Ventures    2020
# 730      $793,525       Nov 20                  Gravitas Ventures    2020
#
# [731 rows x 13 columns]

# %%
# create a clean DataFrame that only keeps relevant columns
clean_car_mov = car_mov[['Release', 'Car', 'Stars', 'Vehicle', 'Vehicle Original', 'Rank', 'Gross', 'Distributor', 'Year_y']]
# rename the column for Year_y
clean_car_mov.rename(columns = {'Year_y':'Year'}, inplace = True)
# Out:
# C:\Users\stuhu\anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
clean_car_mov
# Out:
#                Release                                  Car  Stars  \
# 0    Bad Boys for Life                     2006 bmw 3 [e90]      1
# 1    Bad Boys for Life                     2004 bmw 5 [e60]      2
# 2    Bad Boys for Life                   2018 buick enclave      1
# 3    Bad Boys for Life           2003 cadillac escalade esv      1
# 4    Bad Boys for Life  2014 chevrolet corvette stingray c7      1
# ..                 ...                                  ...    ...
# 726           Vanguard                   2008 nissan armada      2
# 727           Vanguard                  2002 toyota corolla      1
# 728           Vanguard               2008 toyota fj cruiser      1
# 729           Vanguard                       2007 volvo s60      2
# 730           Vanguard                      2015 volvo xc90      3
#
#                 Vehicle       Vehicle Original  Rank         Gross  \
# 0                 bmw 3           bmw 3-series     1  $204,417,855
# 1                 bmw 5           bmw 5-series     1  $204,417,855
# 2         buick enclave          buick enclave     1  $204,417,855
# 3     cadillac escalade      cadillac escalade     1  $204,417,855
# 4    chevrolet corvette     chevrolet corvette     1  $204,417,855
# ..                  ...                    ...   ...           ...
# 726       nissan armada          nissan armada    99      $793,525
# 727      toyota corolla  toyota corolla/matrix    99      $793,525
# 728   toyota fj cruiser      toyota fj cruiser    99      $793,525
# 729           volvo s60          volvo s60/v60    99      $793,525
# 730          volvo xc90             volvo xc90    99      $793,525
#
#                            Distributor  Year
# 0    Sony Pictures Entertainment (SPE)  2020
# 1    Sony Pictures Entertainment (SPE)  2020
# 2    Sony Pictures Entertainment (SPE)  2020
# 3    Sony Pictures Entertainment (SPE)  2020
# 4    Sony Pictures Entertainment (SPE)  2020
# ..                                 ...   ...
# 726                  Gravitas Ventures  2020
# 727                  Gravitas Ventures  2020
# 728                  Gravitas Ventures  2020
# 729                  Gravitas Ventures  2020
# 730                  Gravitas Ventures  2020
#
# [731 rows x 9 columns]

# %%
# create lists/columns for the various counts of Vehicle appearances
appear_high = [clean_car_mov.loc[(clean_car_mov.Stars >= 3) & (clean_car_mov.Vehicle == x)].Vehicle.count() for x in vehicles_list]
appear_low = [clean_car_mov.loc[(clean_car_mov.Stars < 3) & (clean_car_mov.Vehicle == x)].Vehicle.count() for x in vehicles_list]
appear_total = [clean_car_mov.loc[clean_car_mov.Vehicle == x].Vehicle.count() for x in vehicles_list]

clean_car_mov['Strong Appearance'] = appear_high
clean_car_mov['Weak Appearance'] = appear_low
clean_car_mov['Total Appearance'] = appear_total
clean_car_mov
# Out:
# <ipython-input-40-76aaf7db8ef7>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_car_mov['Strong Appearance'] = appear_high
# <ipython-input-40-76aaf7db8ef7>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_car_mov['Weak Appearance'] = appear_low
# <ipython-input-40-76aaf7db8ef7>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_car_mov['Total Appearance'] = appear_total
#                Release                                  Car  Stars  \
# 0    Bad Boys for Life                     2006 bmw 3 [e90]      1
# 1    Bad Boys for Life                     2004 bmw 5 [e60]      2
# 2    Bad Boys for Life                   2018 buick enclave      1
# 3    Bad Boys for Life           2003 cadillac escalade esv      1
# 4    Bad Boys for Life  2014 chevrolet corvette stingray c7      1
# ..                 ...                                  ...    ...
# 726           Vanguard                   2008 nissan armada      2
# 727           Vanguard                  2002 toyota corolla      1
# 728           Vanguard               2008 toyota fj cruiser      1
# 729           Vanguard                       2007 volvo s60      2
# 730           Vanguard                      2015 volvo xc90      3
#
#                 Vehicle       Vehicle Original  Rank         Gross  \
# 0                 bmw 3           bmw 3-series     1  $204,417,855
# 1                 bmw 5           bmw 5-series     1  $204,417,855
# 2         buick enclave          buick enclave     1  $204,417,855
# 3     cadillac escalade      cadillac escalade     1  $204,417,855
# 4    chevrolet corvette     chevrolet corvette     1  $204,417,855
# ..                  ...                    ...   ...           ...
# 726       nissan armada          nissan armada    99      $793,525
# 727      toyota corolla  toyota corolla/matrix    99      $793,525
# 728   toyota fj cruiser      toyota fj cruiser    99      $793,525
# 729           volvo s60          volvo s60/v60    99      $793,525
# 730          volvo xc90             volvo xc90    99      $793,525
#
#                            Distributor  Year  Strong Appearance  \
# 0    Sony Pictures Entertainment (SPE)  2020                  1
# 1    Sony Pictures Entertainment (SPE)  2020                  3
# 2    Sony Pictures Entertainment (SPE)  2020                  0
# 3    Sony Pictures Entertainment (SPE)  2020                  1
# 4    Sony Pictures Entertainment (SPE)  2020                  0
# ..                                 ...   ...                ...
# 726                  Gravitas Ventures  2020                  0
# 727                  Gravitas Ventures  2020                  0
# 728                  Gravitas Ventures  2020                  0
# 729                  Gravitas Ventures  2020                  0
# 730                  Gravitas Ventures  2020                  1
#
#      Weak Appearance  Total Appearance
# 0                 11                12
# 1                  8                11
# 2                  1                 1
# 3                 11                12
# 4                  8                 8
# ..               ...               ...
# 726                2                 2
# 727               15                15
# 728                1                 1
# 729                4                 4
# 730                1                 2
#
# [731 rows x 12 columns]

# %%
# create list/column for the Releases where the Vehicle had the strongest appearance
best_ranks = []
highest_star = []
for vehicle in vehicles_list:
    best_star = clean_car_mov.loc[clean_car_mov.Vehicle == vehicle].Stars.max()
    highest_star.append(best_star)
    
    best_rank = clean_car_mov.loc[(clean_car_mov.Vehicle == vehicle) & (clean_car_mov.Stars == best_star)]['Rank'].tolist()
    best_rank.sort()
    best_ranks.append(best_rank[0])
    
clean_car_mov['Best Rank'] = best_ranks
clean_car_mov['Highest Star'] = highest_star

# %%
# create empty dataframe to append to
clean_car_columns = clean_car_mov.columns.tolist()
final_df = pd.DataFrame(columns = clean_car_columns)
final_df
# Out:
# Empty DataFrame
# Columns: [Release, Car, Stars, Vehicle, Vehicle Original, Rank, Gross, Distributor, Year, Strong Appearance, Weak Appearance, Total Appearance, Best Rank, Highest Star]
# Index: []

# %%
len(clean_car_mov.Vehicle.unique())
# Out:
# 207

# %%
# creat list of unique cars, sorted
unique_cars = clean_car_mov.Vehicle.unique()
unique_cars.sort()

# append each unique car's data to the empty DataFrame
for vehicle in unique_cars:
    unique_df = clean_car_mov.loc[(clean_car_mov.Vehicle == vehicle)\
                                  & (clean_car_mov.Rank == clean_car_mov['Best Rank'])\
                                  & (clean_car_mov.Stars == clean_car_mov['Highest Star'])]
    final_df = final_df.append(unique_df)

# %%
final_df
# Out:
#                      Release                                  Car Stars  \
# 262               Uncut Gems                       2016 acura rdx     1
# 218            The Gentlemen  2016 alfa romeo giulia quadrifoglio     1
# 616                The Lodge                         2006 audi a3     3
# 166               Knives Out                      2006 audi a4 b7     1
# 280              Like a Boss                      2012 audi a7 c7     1
# ..                       ...                                  ...   ...
# 649            The Assistant           volvo v70 xc cross country     1
# 615                   Fatale                      2019 volvo xc40     1
# 465                Bombshell                      2014 volvo xc60     2
# 107  Jumanji: The Next Level                      2010 volvo xc70     1
# 730                 Vanguard                      2015 volvo xc90     3
#
#                Vehicle   Vehicle Original Rank         Gross  \
# 262          acura rdx          acura rdx   21   $25,789,956
# 218  alfa romeo giulia  alfa romeo giulia   16   $36,471,397
# 616            audi a3            audi a3   75    $1,724,781
# 166            audi a4            audi a4   12   $49,651,655
# 280            audi a7            audi a7   23   $22,169,514
# ..                 ...                ...  ...           ...
# 649          volvo v70          volvo v70   84    $1,100,313
# 615         volvo xc40         volvo xc40   68    $2,388,133
# 465         volvo xc60         volvo xc60   34   $13,644,923
# 107         volvo xc70         volvo xc70    4  $124,736,710
# 730         volvo xc90         volvo xc90   99      $793,525
#
#                            Distributor  Year Strong Appearance  \
# 262                                A24  2020                 0
# 218                  STX Entertainment  2020                 0
# 616                               Neon  2020                 1
# 166                          Lionsgate  2020                 0
# 280                 Paramount Pictures  2020                 0
# ..                                 ...   ...               ...
# 649              Bleecker Street Media  2020                 0
# 615                          Lionsgate  2020                 0
# 465                          Lionsgate  2020                 0
# 107  Sony Pictures Entertainment (SPE)  2020                 0
# 730                  Gravitas Ventures  2020                 1
#
#     Weak Appearance Total Appearance Best Rank Highest Star
# 262               2                2        21            1
# 218               1                1        16            1
# 616               1                2        75            3
# 166               1                1        12            1
# 280               1                1        23            1
# ..              ...              ...       ...          ...
# 649               1                1        84            1
# 615               1                1        68            1
# 465               1                1        34            2
# 107               1                1         4            1
# 730               1                2        99            3
#
# [212 rows x 14 columns]

# %%
# dropping duplicate values
final_df.drop_duplicates(subset ="Vehicle", keep='first', inplace=True)

# %%
# reset the index
final_df = final_df.reset_index(drop=True)
final_df
# Out:
#                      Release                                  Car Stars  \
# 0                 Uncut Gems                       2016 acura rdx     1
# 1              The Gentlemen  2016 alfa romeo giulia quadrifoglio     1
# 2                  The Lodge                         2006 audi a3     3
# 3                 Knives Out                      2006 audi a4 b7     1
# 4                Like a Boss                      2012 audi a7 c7     1
# ..                       ...                                  ...   ...
# 202            The Assistant           volvo v70 xc cross country     1
# 203                   Fatale                      2019 volvo xc40     1
# 204                Bombshell                      2014 volvo xc60     2
# 205  Jumanji: The Next Level                      2010 volvo xc70     1
# 206                 Vanguard                      2015 volvo xc90     3
#
#                Vehicle   Vehicle Original Rank         Gross  \
# 0            acura rdx          acura rdx   21   $25,789,956
# 1    alfa romeo giulia  alfa romeo giulia   16   $36,471,397
# 2              audi a3            audi a3   75    $1,724,781
# 3              audi a4            audi a4   12   $49,651,655
# 4              audi a7            audi a7   23   $22,169,514
# ..                 ...                ...  ...           ...
# 202          volvo v70          volvo v70   84    $1,100,313
# 203         volvo xc40         volvo xc40   68    $2,388,133
# 204         volvo xc60         volvo xc60   34   $13,644,923
# 205         volvo xc70         volvo xc70    4  $124,736,710
# 206         volvo xc90         volvo xc90   99      $793,525
#
#                            Distributor  Year Strong Appearance  \
# 0                                  A24  2020                 0
# 1                    STX Entertainment  2020                 0
# 2                                 Neon  2020                 1
# 3                            Lionsgate  2020                 0
# 4                   Paramount Pictures  2020                 0
# ..                                 ...   ...               ...
# 202              Bleecker Street Media  2020                 0
# 203                          Lionsgate  2020                 0
# 204                          Lionsgate  2020                 0
# 205  Sony Pictures Entertainment (SPE)  2020                 0
# 206                  Gravitas Ventures  2020                 1
#
#     Weak Appearance Total Appearance Best Rank Highest Star
# 0                 2                2        21            1
# 1                 1                1        16            1
# 2                 1                2        75            3
# 3                 1                1        12            1
# 4                 1                1        23            1
# ..              ...              ...       ...          ...
# 202               1                1        84            1
# 203               1                1        68            1
# 204               1                1        34            2
# 205               1                1         4            1
# 206               1                2        99            3
#
# [207 rows x 14 columns]

# %%
# export for review
final_df.to_csv(f"final_df_{new_year}.csv", index=False, header=True)

# %%
# create DataFrame from copy of sales data
car_sales_2010 = lower_cars[['Vehicle', f'{old_year}', f'{new_year}']]
car_sales_2010
# Out:
#         Vehicle     2019     2020
# 0     acura ilx  14685.0  13414.0
# 1     acura mdx  52019.0  47816.0
# 2     acura nsx    238.0    128.0
# 3     acura rdx  62876.0  52785.0
# 4      acura rl      NaN      NaN
# ..          ...      ...      ...
# 452   volvo v70      NaN      NaN
# 453  volvo xc40  17647.0  23778.0
# 454  volvo xc60  30578.0  32078.0
# 455  volvo xc70      NaN      NaN
# 456  volvo xc90  35760.0  34251.0
#
# [457 rows x 3 columns]

# %%
# dropping the rows having NaN values
car_sales_2010 = car_sales_2010.dropna()

# %%
# create a % Change column
car_sales_2010['% Change'] = (car_sales_2010[f'{new_year}'] - car_sales_2010[f'{old_year}']) / car_sales_2010[f'{old_year}']
# Out:
# <ipython-input-51-c8c7399f49d4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales_2010['% Change'] = (car_sales_2010[f'{new_year}'] - car_sales_2010[f'{old_year}']) / car_sales_2010[f'{old_year}']

# %%
# create a column that indicates either a positive or negative annual change in sales
change = car_sales_2010['% Change'].tolist()

change_list = []

for n in range(len(change)):
    if change[n] > 0:
        change_list.append('Positive')
    else:
        change_list.append('Negative')

car_sales_2010['Change'] = change_list
# Out:
# <ipython-input-52-6d088ce4957d>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales_2010['Change'] = change_list

# %%
# reset index for car_sales_2010
car_sales_2010 = car_sales_2010.reset_index(drop=True)

# %%
# create list of cars from the car in movies Vehicle Original column
veh_2010 = final_df['Vehicle Original'].unique().tolist()

# %%
# create a dummy list to fill with 'vehicles' data, for car sales
carsales_list = [0] * len(car_sales_2010)

# %%
# reconstruct dummy list to contain the reference string for each Vehicle element
for vehicle in veh_2010:
    for x in range(len(car_sales_2010)):
        if vehicle in car_sales_2010.Vehicle[x]:
            carsales_list[x] = vehicle

# %%
# add column with vehicle reference strings to use for merging DataFrames
car_sales_2010['Movie Presence'] = carsales_list

# %%
car_sales_2010
# Out:
#            Vehicle     2019     2020  % Change    Change Movie Presence
# 0        acura ilx  14685.0  13414.0 -0.086551  Negative              0
# 1        acura mdx  52019.0  47816.0 -0.080797  Negative              0
# 2        acura nsx    238.0    128.0 -0.462185  Negative              0
# 3        acura rdx  62876.0  52785.0 -0.160490  Negative      acura rdx
# 4        acura rlx   1019.0   1054.0  0.034347  Positive              0
# ..             ...      ...      ...       ...       ...            ...
# 287  volvo s60/v60  20190.0  16828.0 -0.166518  Negative  volvo s60/v60
# 288  volvo s90/v90   4052.0   3194.0 -0.211747  Negative              0
# 289     volvo xc40  17647.0  23778.0  0.347424  Positive     volvo xc40
# 290     volvo xc60  30578.0  32078.0  0.049055  Positive     volvo xc60
# 291     volvo xc90  35760.0  34251.0 -0.042198  Negative     volvo xc90
#
# [292 rows x 6 columns]

# %%
# rename columns for merging
car_sales_2010.rename(columns = {'Vehicle': 'Vehicle Original', f'{new_year}': 'Sales'}, inplace = True)

# create a DataFrame that merges the clean cars in movie data with the car sales calculations
car_mov_sales = pd.merge(car_sales_2010, final_df, how="left", on="Vehicle Original")

# %%
# remove unnecessary columns
car_mov_sales = car_mov_sales.drop([f'{old_year}'], axis = 1)
# refill Year with the appropriate value
car_mov_sales.Year = f'{new_year}'
car_mov_sales
# Out:
#     Vehicle Original    Sales  % Change    Change Movie Presence     Release  \
# 0          acura ilx  13414.0 -0.086551  Negative              0         NaN
# 1          acura mdx  47816.0 -0.080797  Negative              0         NaN
# 2          acura nsx    128.0 -0.462185  Negative              0         NaN
# 3          acura rdx  52785.0 -0.160490  Negative      acura rdx  Uncut Gems
# 4          acura rlx   1054.0  0.034347  Positive              0         NaN
# ..               ...      ...       ...       ...            ...         ...
# 288    volvo s60/v60  16828.0 -0.166518  Negative  volvo s60/v60    Vanguard
# 289    volvo s90/v90   3194.0 -0.211747  Negative              0         NaN
# 290       volvo xc40  23778.0  0.347424  Positive     volvo xc40      Fatale
# 291       volvo xc60  32078.0  0.049055  Positive     volvo xc60   Bombshell
# 292       volvo xc90  34251.0 -0.042198  Negative     volvo xc90    Vanguard
#
#                  Car Stars     Vehicle Rank        Gross        Distributor  \
# 0                NaN   NaN         NaN  NaN          NaN                NaN
# 1                NaN   NaN         NaN  NaN          NaN                NaN
# 2                NaN   NaN         NaN  NaN          NaN                NaN
# 3     2016 acura rdx     1   acura rdx   21  $25,789,956                A24
# 4                NaN   NaN         NaN  NaN          NaN                NaN
# ..               ...   ...         ...  ...          ...                ...
# 288   2007 volvo s60     2   volvo s60   99     $793,525  Gravitas Ventures
# 289              NaN   NaN         NaN  NaN          NaN                NaN
# 290  2019 volvo xc40     1  volvo xc40   68   $2,388,133          Lionsgate
# 291  2014 volvo xc60     2  volvo xc60   34  $13,644,923          Lionsgate
# 292  2015 volvo xc90     3  volvo xc90   99     $793,525  Gravitas Ventures
#
#      Year Strong Appearance Weak Appearance Total Appearance Best Rank  \
# 0    2020               NaN             NaN              NaN       NaN
# 1    2020               NaN             NaN              NaN       NaN
# 2    2020               NaN             NaN              NaN       NaN
# 3    2020                 0               2                2        21
# 4    2020               NaN             NaN              NaN       NaN
# ..    ...               ...             ...              ...       ...
# 288  2020                 0               4                4        99
# 289  2020               NaN             NaN              NaN       NaN
# 290  2020                 0               1                1        68
# 291  2020                 0               1                1        34
# 292  2020                 1               1                2        99
#
#     Highest Star
# 0            NaN
# 1            NaN
# 2            NaN
# 3              1
# 4            NaN
# ..           ...
# 288            2
# 289          NaN
# 290            1
# 291            2
# 292            3
#
# [293 rows x 18 columns]

# %%
# export for review
car_mov_sales.to_csv(f"output_data/raw/final/car_mov_sales_{new_year}.csv", index=False, header=True)

# %% [markdown]
# ### Basic visualizations created

# %%
# generate a pie plot showing the distribution of positive to negative change in sales volume
sales_count = car_mov_sales.Change.value_counts()
sales_list = sales_count.keys()
sales_plot = sales_count.plot(kind='pie', y=sales_list, autopct="%1.1f%%", figsize=(6,6))
plt.title(f'Positive vs Negative % Annual Change, for Total Cars {new_year}')
plt.show()

# %%
# create two DataFrames: one with the cars in films, and one with cars not in films (i.e. Vehicle ref = 0)
cars_2010_movie = car_mov_sales.loc[~car_mov_sales.Release.isnull()]
cars_2010_no_movie = car_mov_sales.loc[car_mov_sales.Release.isnull()]

# %%
cars_2010_movie
# Out:
#       Vehicle Original     Sales  % Change    Change     Movie Presence  \
# 3            acura rdx   52785.0 -0.160490  Negative          acura rdx
# 7    alfa romeo giulia    8204.0 -0.057553  Negative  alfa romeo giulia
# 9              audi a3    9938.0 -0.046074  Negative            audi a3
# 10             audi a4   18342.0 -0.306147  Negative            audi a4
# 13             audi a7    2859.0 -0.423007  Negative            audi a7
# ..                 ...       ...       ...       ...                ...
# 286  volkswagen tiguan  100687.0 -0.084356  Negative  volkswagen tiguan
# 288      volvo s60/v60   16828.0 -0.166518  Negative      volvo s60/v60
# 290         volvo xc40   23778.0  0.347424  Positive         volvo xc40
# 291         volvo xc60   32078.0  0.049055  Positive         volvo xc60
# 292         volvo xc90   34251.0 -0.042198  Negative         volvo xc90
#
#                Release                                  Car Stars  \
# 3           Uncut Gems                       2016 acura rdx     1
# 7        The Gentlemen  2016 alfa romeo giulia quadrifoglio     1
# 9            The Lodge                         2006 audi a3     3
# 10          Knives Out                      2006 audi a4 b7     1
# 13         Like a Boss                      2012 audi a7 c7     1
# ..                 ...                                  ...   ...
# 286  The Invisible Man  2017 volkswagen tiguan ii [typ ad1]     1
# 288           Vanguard                       2007 volvo s60     2
# 290             Fatale                      2019 volvo xc40     1
# 291          Bombshell                      2014 volvo xc60     2
# 292           Vanguard                      2015 volvo xc90     3
#
#                Vehicle Rank        Gross         Distributor  Year  \
# 3            acura rdx   21  $25,789,956                 A24  2020
# 7    alfa romeo giulia   16  $36,471,397   STX Entertainment  2020
# 9              audi a3   75   $1,724,781                Neon  2020
# 10             audi a4   12  $49,651,655           Lionsgate  2020
# 13             audi a7   23  $22,169,514  Paramount Pictures  2020
# ..                 ...  ...          ...                 ...   ...
# 286  volkswagen tiguan    9  $64,914,050  Universal Pictures  2020
# 288          volvo s60   99     $793,525   Gravitas Ventures  2020
# 290         volvo xc40   68   $2,388,133           Lionsgate  2020
# 291         volvo xc60   34  $13,644,923           Lionsgate  2020
# 292         volvo xc90   99     $793,525   Gravitas Ventures  2020
#
#     Strong Appearance Weak Appearance Total Appearance Best Rank Highest Star
# 3                   0               2                2        21            1
# 7                   0               1                1        16            1
# 9                   1               1                2        75            3
# 10                  0               1                1        12            1
# 13                  0               1                1        23            1
# ..                ...             ...              ...       ...          ...
# 286                 0               3                3         9            1
# 288                 0               4                4        99            2
# 290                 0               1                1        68            1
# 291                 0               1                1        34            2
# 292                 1               1                2        99            3
#
# [155 rows x 18 columns]

# %%
cars_2010_no_movie
# Out:
#        Vehicle Original    Sales  % Change    Change Movie Presence Release  \
# 0             acura ilx  13414.0 -0.086551  Negative              0     NaN
# 1             acura mdx  47816.0 -0.080797  Negative              0     NaN
# 2             acura nsx    128.0 -0.462185  Negative              0     NaN
# 4             acura rlx   1054.0  0.034347  Positive              0     NaN
# 5             acura tlx  21785.0 -0.179411  Negative              0     NaN
# ..                  ...      ...       ...       ...            ...     ...
# 279   volkswagen arteon   3602.0  0.470804  Positive              0     NaN
# 280    volkswagen atlas  76283.0 -0.064104  Negative              0     NaN
# 282       volkswagen cc     17.0 -0.706897  Negative              0     NaN
# 287  volkswagen touareg      3.0 -0.981250  Negative              0     NaN
# 289       volvo s90/v90   3194.0 -0.211747  Negative              0     NaN
#
#      Car Stars Vehicle Rank Gross Distributor  Year Strong Appearance  \
# 0    NaN   NaN     NaN  NaN   NaN         NaN  2020               NaN
# 1    NaN   NaN     NaN  NaN   NaN         NaN  2020               NaN
# 2    NaN   NaN     NaN  NaN   NaN         NaN  2020               NaN
# 4    NaN   NaN     NaN  NaN   NaN         NaN  2020               NaN
# 5    NaN   NaN     NaN  NaN   NaN         NaN  2020               NaN
# ..   ...   ...     ...  ...   ...         ...   ...               ...
# 279  NaN   NaN     NaN  NaN   NaN         NaN  2020               NaN
# 280  NaN   NaN     NaN  NaN   NaN         NaN  2020               NaN
# 282  NaN   NaN     NaN  NaN   NaN         NaN  2020               NaN
# 287  NaN   NaN     NaN  NaN   NaN         NaN  2020               NaN
# 289  NaN   NaN     NaN  NaN   NaN         NaN  2020               NaN
#
#     Weak Appearance Total Appearance Best Rank Highest Star
# 0               NaN              NaN       NaN          NaN
# 1               NaN              NaN       NaN          NaN
# 2               NaN              NaN       NaN          NaN
# 4               NaN              NaN       NaN          NaN
# 5               NaN              NaN       NaN          NaN
# ..              ...              ...       ...          ...
# 279             NaN              NaN       NaN          NaN
# 280             NaN              NaN       NaN          NaN
# 282             NaN              NaN       NaN          NaN
# 287             NaN              NaN       NaN          NaN
# 289             NaN              NaN       NaN          NaN
#
# [138 rows x 18 columns]

# %%
# generate a pie plot showing the distribution of positive to negative change in sales volume
sales_count = cars_2010_movie.Change.value_counts()
sales_list = sales_count.keys()
sales_plot = sales_count.plot(kind='pie', y=sales_list, autopct="%1.1f%%", figsize=(6,6))
plt.title(f'Positive vs Negative % Annual Change, for Total Cars in Films {new_year}')
plt.show()

# %%
# generate a pie plot showing the distribution of positive to negative change in sales volume
sales_count = cars_2010_no_movie.Change.value_counts()
sales_list = sales_count.keys()
sales_plot = sales_count.plot(kind='pie', y=sales_list, autopct="%1.1f%%", figsize=(6,6))
plt.title(f'Positive vs Negative % Annual Change, for Total Cars not in Films {new_year}')
plt.show()
