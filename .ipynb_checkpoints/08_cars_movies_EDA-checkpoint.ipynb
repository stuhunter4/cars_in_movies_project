# %%
import pandas as pd
import numpy as np

# %%
# read in raw data for cars in movies
raw_2010 = pd.read_csv("output_data/raw/cars in movies/2021_03_06_2010Cars.csv")
raw_2010

# %%
# how many null elements are in each column
raw_2010.isnull().sum()

# %%
# what sort of junk data do we need to remove from the Car column
raw_2010.loc[raw_2010.Car.str.contains('Movie')]

# %%
raw_2010.loc[raw_2010.Car.str.contains('Unknown')]
# Out:
#                                            Release  Year       Car  \
# 144   Harry Potter and the Deathly Hallows: Part 1  2010  Unknown
# 622                                The Book of Eli  2010  Unknown
# 1063                             The Bounty Hunter  2010  Unknown
# 2052                                   Daybreakers  2010  Unknown
#
#                       url Stars
# 144   vehicle_455543.html     1
# 622   vehicle_332601.html     1
# 1063  vehicle_293920.html     1
# 2052  vehicle_236773.html     2

# %%
raw_2010.loc[raw_2010.Car.str.contains('unknown')]
# Out:
#                               Release  Year                Car  \
# 46         The Twilight Saga: Eclipse  2010           unknown
# 106                         Inception  2010           unknown
# 117                         Inception  2010    Yamaha unknown
# 163                    The Karate Kid  2010  Huanghai unknown
# 171                    The Karate Kid  2010           unknown
# 296                    The Other Guys  2010   2005 UD unknown
# 303                    The Other Guys  2010      Yale unknown
# 443                        Jackass 3D  2010           unknown
# 444                        Jackass 3D  2010           unknown
# 623                   The Book of Eli  2010           unknown
# 768                          The Town  2010    Toyota unknown
# 830                               RED  2010           unknown
# 999                        The A-Team  2010           unknown
# 1395  Wall Street: Money Never Sleeps  2010     unknown Cobra
# 1442                         Kick-Ass  2010      Yale unknown
# 1486                          Cop Out  2010           unknown
# 1487                          Cop Out  2010           unknown
# 1572                 Edge of Darkness  2010  Kenworth unknown
# 1604                 Edge of Darkness  2010           unknown
# 1667                           Legion  2010           unknown
# 1787                    Vampires Suck  2010           unknown
# 1788                    Vampires Suck  2010           unknown
# 1809                     The American  2010           unknown
#
#                                 url Stars
# 46              vehicle_359181.html     1
# 106             vehicle_355636.html     1
# 117     vehicle_1203997-Yamaha.html     1
# 163    vehicle_331629-Huanghai.html     2
# 171             vehicle_372472.html     1
# 296    vehicle_1183239-UD-2005.html     1
# 303       vehicle_1183242-Yale.html     1
# 443            vehicle_1306807.html     1
# 444             vehicle_383686.html     3
# 623             vehicle_310513.html     1
# 768     vehicle_1107200-Toyota.html     1
# 830            vehicle_1188806.html     1
# 999             vehicle_316922.html     2
# 1395     vehicle_1233860-Cobra.html     1
# 1442       vehicle_307349-Yale.html     1
# 1486            vehicle_315195.html     1
# 1487            vehicle_315194.html     1
# 1572  vehicle_1435165-Kenworth.html     1
# 1604           vehicle_1435161.html     1
# 1667            vehicle_478914.html     1
# 1787            vehicle_357414.html     2
# 1788            vehicle_357415.html     1
# 1809            vehicle_347142.html     1

# %%
# how common are some cars at the most frequent versus least
raw_2010.Car.value_counts()
# Out:
# 1999 Ford Crown Victoria       22
# 2001 Ford Crown Victoria       17
# unknown                        15
# 2003 Ford Crown Victoria       13
# 2006 Chevrolet Impala           9
#                                ..
# 2000 Hyundai Accent             1
# 2003 Mercury Grand Marquis      1
# 2005 Toyota Yaris               1
# 2004 Škoda Octavia              1
# 1982 Ford F-350                 1
# Name: Car, Length: 1472, dtype: int64

# %%
# top 20 most movie appearances
raw_2010.Car.value_counts().nlargest(20)
# Out:
# 1999 Ford Crown Victoria                      22
# 2001 Ford Crown Victoria                      17
# unknown                                       15
# 2003 Ford Crown Victoria                      13
# 2006 Chevrolet Impala                          9
# 1997 Ford Econoline                            9
# 2006 Toyota Prius II                           9
# 2005 Chrysler 300                              8
# 2007 Chevrolet Suburban                        8
# 2003 Lincoln Town Car                          8
# 2000 Chevrolet Impala                          8
# 2008 Chevrolet Malibu                          7
# 2006 Ford Crown Victoria                       7
# 1998 Ford Crown Victoria                       7
# 2007 Cadillac Escalade                         6
# 2007 Chevrolet Tahoe                           6
# 2003 Lincoln Town Car Stretched Limousine      6
# 2006 Dodge Charger                             6
# 1992 Ford Econoline                            6
# 1997 Toyota Camry                              6
# Name: Car, dtype: int64

# %%
# check data types
raw_2010.dtypes
# Out:
# Release    object
# Year        int64
# Car        object
# url        object
# Stars      object
# dtype: object

# %%
# how many cars are there for each ratings category
raw_2010.Stars.value_counts()
# Out:
# 1      1372
# 2       443
# 3       185
# Nan      32
# 4        21
# Name: Stars, dtype: int64

# %%
# return a DataFrame without any missing ratings element
clean_2010 = raw_2010.loc[raw_2010.Stars != 'Nan']

# %%
# convert Stars ratings column to integers
clean_2010.Stars = clean_2010.Stars.astype(int)
# Out:
# C:\Users\stuhu\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
# return a new DataFrame that removes irrelevant car elements
new = clean_2010.loc[(~clean_2010.Car.str.contains('Unknown'))\
                     & (~clean_2010.Car.str.contains('unknown')) & (~clean_2010.Car.str.contains('Movie'))]

# %%
# reset the index and display
new = new.reset_index(drop=True)
new
# Out:
#           Release  Year                          Car  \
# 0     Toy Story 3  2010  1998 Chevrolet Corvette C5
# 1     Toy Story 3  2010             Opel Meriva [A]
# 2     Toy Story 3  2010        2005 Opel Zafira [B]
# 3     Toy Story 3  2010           1979 Toyota Truck
# 4      Iron Man 2  2010              2010 Acura ZDX
# ...           ...   ...                          ...
# 1982  Daybreakers  2010        Rhino Buggies Hammer
# 1983  Daybreakers  2010        Rhino Buggies Hammer
# 1984  Daybreakers  2010           2004 smart Fortwo
# 1985  Daybreakers  2010         1993 Toyota 4Runner
# 1986  Daybreakers  2010        2006 Toyota Prius II
#
#                                                url  Stars
# 0      vehicle_369776-Chevrolet-Corvette-1998.html      3
# 1                  vehicle_974788-Opel-Meriva.html      2
# 2             vehicle_974791-Opel-Zafira-2005.html      2
# 3       vehicle_349573-Toyota-Truck-RN30-1979.html      2
# 4           vehicle_340464-Acura-ZDX-YB1-2010.html      2
# ...                                            ...    ...
# 1982      vehicle_236776-Rhino-Buggies-Hammer.html      2
# 1983      vehicle_317794-Rhino-Buggies-Hammer.html      3
# 1984     vehicle_317791-smart-Fortwo-450-2004.html      1
# 1985  vehicle_236774-Toyota-4Runner-N130-1993.html      2
# 1986   vehicle_317792-Toyota-Prius-NHW20-2006.html      1
#
# [1987 rows x 5 columns]

# %%
# how many unique vehicles are there
len(new.Car.unique())
# Out:
# 1444

# %%
# in order to start working with the Car column, remove whitespaces at both sides of the string elements
for index, row in new.iterrows():
    new.Car[index] = new.Car[index].strip()
# Out:
# <ipython-input-16-7b04d79dfdac>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new.Car[index] = new.Car[index].strip()

# %%
# return a new DataFrame of all duplicate Car rows
dups = new.loc[new.duplicated('Car', keep=False)]

# %%
# sort duplicates by Car column and reset index
# a significant portion of the dataset contain cars that appear in multiple films
dups = dups.sort_values("Car")
dups = dups.reset_index(drop=True)
dups
# Out:
#                        Release  Year                      Car  \
# 0                  Crazy Heart  2010  1964 Chevrolet C-Series
# 1                    Burlesque  2010  1964 Chevrolet C-Series
# 2                  Secretariat  2010        1965 Ford Mustang
# 3                  Secretariat  2010        1965 Ford Mustang
# 4                  Daybreakers  2010        1966 Ford Mustang
# ..                         ...   ...                      ...
# 821         The Social Network  2010                Volvo S40
# 822               The American  2010                Volvo V70
# 823              Morning Glory  2010                Volvo V70
# 824  A Nightmare on Elm Street  2010                Volvo V70
# 825                  Hereafter  2010                Volvo V70
#
#                                              url  Stars
# 0    vehicle_356411-Chevrolet-C-Series-1964.html      1
# 1    vehicle_562475-Chevrolet-C-Series-1964.html      1
# 2          vehicle_371640-Ford-Mustang-1965.html      1
# 3          vehicle_371645-Ford-Mustang-1965.html      1
# 4          vehicle_306723-Ford-Mustang-1966.html      1
# ..                                           ...    ...
# 821                vehicle_346265-Volvo-S40.html      1
# 822                vehicle_335773-Volvo-V70.html      2
# 823               vehicle_1278240-Volvo-V70.html      1
# 824                vehicle_512215-Volvo-V70.html      2
# 825                vehicle_341371-Volvo-V70.html      1
#
# [826 rows x 5 columns]

# %%
# sample car and its appearances
dups.loc[dups.Car == '2000 Ford Crown Victoria']
# Out:
#                Release  Year                       Car  \
# 297      Morning Glory  2010  2000 Ford Crown Victoria
# 298      Vampires Suck  2010  2000 Ford Crown Victoria
# 299  The Bounty Hunter  2010  2000 Ford Crown Victoria
# 300     The Other Guys  2010  2000 Ford Crown Victoria
# 301       TRON: Legacy  2010  2000 Ford Crown Victoria
#
#                                                   url  Stars
# 297  vehicle_380889-Ford-Crown-Victoria-P71-2000.html      2
# 298  vehicle_357390-Ford-Crown-Victoria-P71-2000.html      3
# 299  vehicle_293923-Ford-Crown-Victoria-P71-2000.html      2
# 300  vehicle_346999-Ford-Crown-Victoria-P71-2000.html      3
# 301  vehicle_389013-Ford-Crown-Victoria-P71-2000.html      2

# %%
# read in car sales data to use as a filter for the Car column
sales = pd.read_csv('output_data/Car_Sales_2009-2020_edited.csv')
sales
# Out:
#         Vehicle     2009     2010     2011     2012     2013     2014  \
# 0     Acura ILX      NaN      NaN      NaN  12251.0  20430.0  17854.0
# 1     Acura MDX  31178.0  47210.0  43271.0  50854.0  53040.0  65603.0
# 2     Acura NSX      NaN      NaN      NaN      NaN      NaN      NaN
# 3     Acura RDX  10153.0  14975.0  15196.0  29520.0  44750.0  44865.0
# 4      Acura RL   2043.0   2037.0   1096.0    379.0     39.0      NaN
# ..          ...      ...      ...      ...      ...      ...      ...
# 452   Volvo V70   1816.0    895.0      NaN      NaN      NaN      NaN
# 453  Volvo XC40      NaN      NaN      NaN      NaN      NaN      NaN
# 454  Volvo XC60   9262.0  12030.0  12932.0  19139.0  19766.0  19276.0
# 455  Volvo XC70   5825.0   6626.0   5716.0   5513.0   4882.0   5093.0
# 456  Volvo XC90  10757.0  10119.0  10609.0   9513.0   6845.0   3952.0
#
#         2015     2016     2017     2018     2019     2020
# 0    18531.0  14597.0  11757.0  11273.0  14685.0  13414.0
# 1    58208.0  55495.0  54886.0  51512.0  52019.0  47816.0
# 2        NaN    269.0    581.0    170.0    238.0    128.0
# 3    51026.0  52361.0  51295.0  63580.0  62876.0  52785.0
# 4        NaN      NaN      NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...      ...      ...
# 452      NaN      NaN      NaN      NaN      NaN      NaN
# 453      NaN      NaN      NaN  12420.0  17647.0  23778.0
# 454  26134.0  20452.0  22516.0  32689.0  30578.0  32078.0
# 455   5118.0   5425.0      NaN      NaN      NaN      NaN
# 456  12777.0  32526.0  30996.0  31609.0  35760.0  34251.0
#
# [457 rows x 13 columns]

# %%
# list comprehension to apply lower method to string elements in the Car column...
# ...to better filter the data for vehicles in the car sales dataset
lower_cars = sales.copy()
lower_cars.Vehicle = [car.lower() for car in lower_cars.Vehicle]

# %%
# same operations for the car in movie dataset
lower_car_mov = new.copy()
lower_car_mov.Car = [car.lower() for car in lower_car_mov.Car]

# %%
# create list of cars with sales data
vehicles = lower_cars.Vehicle.unique().tolist()

# %%
# use list comprehension and for loop to create a list of brands from the sales dataset
brand_raw = [vehicle.split()[0] for vehicle in vehicles]
brands = []
for brand in brand_raw:
    if brand not in brands:
        brands.append(brand)

# %%
print(brands)
# Out:
# ['acura', 'alfa', 'audi', 'bmw', 'bentley', 'buick', 'cadillac', 'chevrolet', 'chrysler', 'dodge', 'fiat', 'ford', 'gmc', 'genesis', 'honda', 'hummer', 'hyundai', 'infiniti', 'jaguar', 'jeep', 'kia', 'land', 'lexus', 'lincoln', 'maserati', 'mazda', 'mercedes-benz', 'mercury', 'mini', 'mitsubishi', 'nissan', 'pontiac', 'porsche', 'ram', 'saab', 'saturn', 'scion', 'smart', 'subaru', 'suzuki', 'tesla', 'toyota', 'volkswagen', 'volvo']

# %%
# use list comprehension and for loop to create a list of models from the sales dataset
model_raw = [vehicle.split()[-1] for vehicle in vehicles]
models = []
for model in model_raw:
    if model not in models:
        models.append(model)

# %%
print(models)
# Out:
# ['ilx', 'mdx', 'nsx', 'rdx', 'rl', 'rlx', 'tl', 'tlx', 'tsx', 'zdx', '4c', 'giulia', 'stelvio', 'a3', 'e-tron', 'a4', 'allroad', 'avant', 'sedan', 'a5', 'a6', 'a7', 'a8', 'q3', 'q5', 'q7', 'q8', 'r8', 'tt', 'etron', '1-series', '2-series', '3-series', '4-series', '5-series', '6-series', '7-series', '8-series', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'z4', 'i3', 'i8', 'bentayga', 'gt', 'spur', 'mulsanne', 'cascada', 'enclave', 'encore', 'gx', 'envision', 'lacrosse', 'lucerne', 'regal', 'verano', 'ats', 'ct4', 'ct5', 'ct6', 'cts', 'dts', 'elr', 'escalade', 'srx', 'sts', 'xlr', 'xt4', 'xt5', 'xt6', 'xts', 'avalanche', 'aveo', 'blazer', 'bolt', 'camaro', 'ppv', 'sport', 'express', 'cobalt', 'colorado', 'corvette', 'cruze', 'equinox', 'hhr', 'impala', 'malibu', 'ss', 'silverado', 'sonic', 'spark', 'suburban', 'tahoe', 'trailblazer', 'traverse', 'trax', 'uplander', 'volt', '200', '300', 'aspen', 'cruiser', 'pacifica', 'sebring', 'country', 'avenger', 'caliber', 'challenger', 'charger', 'dakota', 'dart', 'durango', 'caravan', 'journey', 'nitro', 'ram', 'viper', 'spider', '500', '500l', '500x', 'c-max', 'victoria', 'e-series', 'ecosport', 'edge', 'escape', 'expedition', 'explorer', 'interceptor', 'f-series', 'fiesta', 'flex', 'focus', 'fusion', 'mustang', 'ranger', 'taurus', 'x', 'transit', 'connect', 'acadia', 'canyon', 'envoy', 'savana', 'sierra', 'terrain', 'torrent', 'yukon', 'xl', 'g70', 'g80', 'g90', 'gv80', 'accord', 'cr-v', 'cr-z', 'civic', 'fcv', 'crosstour', 'element', 'fcx', 'fit', 'hr-v', 'insight', 'odyssey', 'passport', 'pilot', 'ridgeline', 's2000', 'h2', 'h3', 'accent', 'azera', 'elantra', 'equus', 'genesis', 'ioniq', 'kona', 'nexo', 'palisade', 'fe', 'sonata', 'tucson', 'veloster', 'venue', 'veracruz', 'g', 'q40', 'q50', 'q60', 'q70/m', 'qx30', 'ex/qx50', 'qx60/jx', 'qx70/fx', 'qx80/qx56', 'e-pace', 'f-pace', 'f-type', 'i-pace', 'xe', 'xf', 'xj', 'xk', 'cherokee', 'commander', 'compass', 'gladiator', 'liberty', 'patriot', 'renegade', 'wrangler', 'amanti', 'borrego', 'cadenza', 'forte', 'k5', 'k900', 'niro', 'optima', 'rio', 'rondo', 'sedona', 'seltos', 'sorento', 'soul', 'spectra', 'sportage', 'stinger', 'telluride', 'defender', 'lr4', 'lr2', 'rover', 'evoque', 'velar', 'ct', 'ct200h', 'es/es350', 'gs', 'gx/gx460', 'hs/hs250h', 'is', 'lc', 'lfa', 'ls', 'lx/lx570', 'nx', 'rc', 'rx', 'sc430', 'ux', 'aviator', 'continental', 'mkc', 'mks', 'mkt', 'mkx/nautilus', 'mkz', 'navigator', 'car', 'ghibli', 'granturismo', 'levante', 'quattroporte', '2', '3', '5', '6', 'b-series', 'cx-3', 'cx-30', 'cx-5', 'cx-7', 'cx-9', 'miata', 'rx-8', 'tribute', 'a-class', 'b-class', 'c-class', 'cl-class', 'cla-class', 'clk-class', 'cls-class', 'e-class', 'g-class', 'gl-class/gls-class', 'gla-class', 'glb', 'glc-class', 'gle-class/m-class', 'glk-class', 'metris/vito', 'r-class', 's-class', 'sl-class', 'slk-class/slc-class', 'amg', 'sprinter', 'marquis', 'mariner', 'milan', 'mountaineer', 'sable', 'cooper', 'clubman', 'convertible', 'coupe', '2-door', '4-door', 'roadster', 'countryman', 'paceman', 'eclipse/spyder', 'cross', 'endeavor', 'galant', 'lancer', 'mirage', 'outlander', 'phev', 'raider', 'i-miev', '370z/350z', 'altima', 'armada', 'cube', 'frontier', 'gt-r', 'juke', 'kicks', 'leaf', 'maxima', 'murano', 'nv', 'nv200', 'pathfinder', 'quest', 'rogue', 'sentra', 'titan', 'versa', 'xterra', 'g3', 'g5', 'g6', 'g8', 'prix', 'solstice', 'vibe', '718', '911', 'spyder', 'boxster', 'cayenne', 'cayman', 'macan', 'panamera', 'taycan', 'van', 'pickup', 'promaster', 'city', '9-3', '9-4x', '9-5', '9-7x', 'astra', 'aura', 'outlook', 'sky', 'vue', 'iq', 'tc', 'xb', 'xd', 'fortwo', 'ascent', 'brz', 'forester', 'sti', 'legacy', 'outback', 'tribeca', 'crosstrek/crosstrek', 'equator', 'forenza/reno', 'vitara', 'kizashi', 'sx4/aerio', 'xl7', 's', 'y', '4runner', 'fr-s', 'avalon', 'c-hr', 'camry', 'corolla/matrix', 'im', 'highlander', 'mirai', 'prius', 'rav4', 'sequoia', 'sienna', 'supra', 'tacoma', 'tundra', 'venza', 'hatchback', 'ia', 'arteon', 'atlas', 'beet ...

# %%
# handle models that share a row of data by splitting and appending to models list, then removing
remove_models = []

for model in models:
    if '/' in model:
        print (f'Splitting and Extending {model}')
        models.extend(model.split('/'))
        remove_models.append(model)
        
for model in remove_models:
    print (f'Removing {model}')
    models.remove(model)
# Out:
# Splitting and Extending q70/m
# Splitting and Extending ex/qx50
# Splitting and Extending qx60/jx
# Splitting and Extending qx70/fx
# Splitting and Extending qx80/qx56
# Splitting and Extending es/es350
# Splitting and Extending gx/gx460
# Splitting and Extending hs/hs250h
# Splitting and Extending lx/lx570
# Splitting and Extending mkx/nautilus
# Splitting and Extending gl-class/gls-class
# Splitting and Extending gle-class/m-class
# Splitting and Extending metris/vito
# Splitting and Extending slk-class/slc-class
# Splitting and Extending eclipse/spyder
# Splitting and Extending 370z/350z
# Splitting and Extending crosstrek/crosstrek
# Splitting and Extending forenza/reno
# Splitting and Extending sx4/aerio
# Splitting and Extending corolla/matrix
# Splitting and Extending s60/v60
# Splitting and Extending s90/v90
# Removing q70/m
# Removing ex/qx50
# Removing qx60/jx
# Removing qx70/fx
# Removing qx80/qx56
# Removing es/es350
# Removing gx/gx460
# Removing hs/hs250h
# Removing lx/lx570
# Removing mkx/nautilus
# Removing gl-class/gls-class
# Removing gle-class/m-class
# Removing metris/vito
# Removing slk-class/slc-class
# Removing eclipse/spyder
# Removing 370z/350z
# Removing crosstrek/crosstrek
# Removing forenza/reno
# Removing sx4/aerio
# Removing corolla/matrix
# Removing s60/v60
# Removing s90/v90

# %%
print(models)
# Out:
# ['ilx', 'mdx', 'nsx', 'rdx', 'rl', 'rlx', 'tl', 'tlx', 'tsx', 'zdx', '4c', 'giulia', 'stelvio', 'a3', 'e-tron', 'a4', 'allroad', 'avant', 'sedan', 'a5', 'a6', 'a7', 'a8', 'q3', 'q5', 'q7', 'q8', 'r8', 'tt', 'etron', '1-series', '2-series', '3-series', '4-series', '5-series', '6-series', '7-series', '8-series', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'z4', 'i3', 'i8', 'bentayga', 'gt', 'spur', 'mulsanne', 'cascada', 'enclave', 'encore', 'gx', 'envision', 'lacrosse', 'lucerne', 'regal', 'verano', 'ats', 'ct4', 'ct5', 'ct6', 'cts', 'dts', 'elr', 'escalade', 'srx', 'sts', 'xlr', 'xt4', 'xt5', 'xt6', 'xts', 'avalanche', 'aveo', 'blazer', 'bolt', 'camaro', 'ppv', 'sport', 'express', 'cobalt', 'colorado', 'corvette', 'cruze', 'equinox', 'hhr', 'impala', 'malibu', 'ss', 'silverado', 'sonic', 'spark', 'suburban', 'tahoe', 'trailblazer', 'traverse', 'trax', 'uplander', 'volt', '200', '300', 'aspen', 'cruiser', 'pacifica', 'sebring', 'country', 'avenger', 'caliber', 'challenger', 'charger', 'dakota', 'dart', 'durango', 'caravan', 'journey', 'nitro', 'ram', 'viper', 'spider', '500', '500l', '500x', 'c-max', 'victoria', 'e-series', 'ecosport', 'edge', 'escape', 'expedition', 'explorer', 'interceptor', 'f-series', 'fiesta', 'flex', 'focus', 'fusion', 'mustang', 'ranger', 'taurus', 'x', 'transit', 'connect', 'acadia', 'canyon', 'envoy', 'savana', 'sierra', 'terrain', 'torrent', 'yukon', 'xl', 'g70', 'g80', 'g90', 'gv80', 'accord', 'cr-v', 'cr-z', 'civic', 'fcv', 'crosstour', 'element', 'fcx', 'fit', 'hr-v', 'insight', 'odyssey', 'passport', 'pilot', 'ridgeline', 's2000', 'h2', 'h3', 'accent', 'azera', 'elantra', 'equus', 'genesis', 'ioniq', 'kona', 'nexo', 'palisade', 'fe', 'sonata', 'tucson', 'veloster', 'venue', 'veracruz', 'g', 'q40', 'q50', 'q60', 'qx30', 'e-pace', 'f-pace', 'f-type', 'i-pace', 'xe', 'xf', 'xj', 'xk', 'cherokee', 'commander', 'compass', 'gladiator', 'liberty', 'patriot', 'renegade', 'wrangler', 'amanti', 'borrego', 'cadenza', 'forte', 'k5', 'k900', 'niro', 'optima', 'rio', 'rondo', 'sedona', 'seltos', 'sorento', 'soul', 'spectra', 'sportage', 'stinger', 'telluride', 'defender', 'lr4', 'lr2', 'rover', 'evoque', 'velar', 'ct', 'ct200h', 'gs', 'is', 'lc', 'lfa', 'ls', 'nx', 'rc', 'rx', 'sc430', 'ux', 'aviator', 'continental', 'mkc', 'mks', 'mkt', 'mkz', 'navigator', 'car', 'ghibli', 'granturismo', 'levante', 'quattroporte', '2', '3', '5', '6', 'b-series', 'cx-3', 'cx-30', 'cx-5', 'cx-7', 'cx-9', 'miata', 'rx-8', 'tribute', 'a-class', 'b-class', 'c-class', 'cl-class', 'cla-class', 'clk-class', 'cls-class', 'e-class', 'g-class', 'gla-class', 'glb', 'glc-class', 'glk-class', 'r-class', 's-class', 'sl-class', 'amg', 'sprinter', 'marquis', 'mariner', 'milan', 'mountaineer', 'sable', 'cooper', 'clubman', 'convertible', 'coupe', '2-door', '4-door', 'roadster', 'countryman', 'paceman', 'cross', 'endeavor', 'galant', 'lancer', 'mirage', 'outlander', 'phev', 'raider', 'i-miev', 'altima', 'armada', 'cube', 'frontier', 'gt-r', 'juke', 'kicks', 'leaf', 'maxima', 'murano', 'nv', 'nv200', 'pathfinder', 'quest', 'rogue', 'sentra', 'titan', 'versa', 'xterra', 'g3', 'g5', 'g6', 'g8', 'prix', 'solstice', 'vibe', '718', '911', 'spyder', 'boxster', 'cayenne', 'cayman', 'macan', 'panamera', 'taycan', 'van', 'pickup', 'promaster', 'city', '9-3', '9-4x', '9-5', '9-7x', 'astra', 'aura', 'outlook', 'sky', 'vue', 'iq', 'tc', 'xb', 'xd', 'fortwo', 'ascent', 'brz', 'forester', 'sti', 'legacy', 'outback', 'tribeca', 'equator', 'vitara', 'kizashi', 'xl7', 's', 'y', '4runner', 'fr-s', 'avalon', 'c-hr', 'camry', 'im', 'highlander', 'mirai', 'prius', 'rav4', 'sequoia', 'sienna', 'supra', 'tacoma', 'tundra', 'venza', 'hatchback', 'ia', 'arteon', 'atlas', 'beetle', 'cc', 'eos', 'alltrack', 'jetta', 'passat', 'routan', 'tiguan', 'touareg', 'c30', 'c70', 's40', 's80', 'v50', 'v70', 'xc40', 'xc60', 'xc70', 'xc90', 'q70', 'm', 'ex', 'qx50', 'qx60', 'jx', 'qx70', 'fx', 'qx80', 'qx56', 'es', 'es350', 'gx', 'gx460', 'hs', 'hs250h', 'lx', 'lx570', 'mkx', 'nautilus' ...

# %%
# join the list of brands with a | delimiter, creating a RegEx pattern to pass through str.contains() next
brand_var = "|".join(brands)
print(brand_var)
# Out:
# acura|alfa|audi|bmw|bentley|buick|cadillac|chevrolet|chrysler|dodge|fiat|ford|gmc|genesis|honda|hummer|hyundai|infiniti|jaguar|jeep|kia|land|lexus|lincoln|maserati|mazda|mercedes-benz|mercury|mini|mitsubishi|nissan|pontiac|porsche|ram|saab|saturn|scion|smart|subaru|suzuki|tesla|toyota|volkswagen|volvo

# %%
# same process for models
model_var = "|".join(models)
print(model_var)
# Out:
# ilx|mdx|nsx|rdx|rl|rlx|tl|tlx|tsx|zdx|4c|giulia|stelvio|a3|e-tron|a4|allroad|avant|sedan|a5|a6|a7|a8|q3|q5|q7|q8|r8|tt|etron|1-series|2-series|3-series|4-series|5-series|6-series|7-series|8-series|x1|x2|x3|x4|x5|x6|x7|z4|i3|i8|bentayga|gt|spur|mulsanne|cascada|enclave|encore|gx|envision|lacrosse|lucerne|regal|verano|ats|ct4|ct5|ct6|cts|dts|elr|escalade|srx|sts|xlr|xt4|xt5|xt6|xts|avalanche|aveo|blazer|bolt|camaro|ppv|sport|express|cobalt|colorado|corvette|cruze|equinox|hhr|impala|malibu|ss|silverado|sonic|spark|suburban|tahoe|trailblazer|traverse|trax|uplander|volt|200|300|aspen|cruiser|pacifica|sebring|country|avenger|caliber|challenger|charger|dakota|dart|durango|caravan|journey|nitro|ram|viper|spider|500|500l|500x|c-max|victoria|e-series|ecosport|edge|escape|expedition|explorer|interceptor|f-series|fiesta|flex|focus|fusion|mustang|ranger|taurus|x|transit|connect|acadia|canyon|envoy|savana|sierra|terrain|torrent|yukon|xl|g70|g80|g90|gv80|accord|cr-v|cr-z|civic|fcv|crosstour|element|fcx|fit|hr-v|insight|odyssey|passport|pilot|ridgeline|s2000|h2|h3|accent|azera|elantra|equus|genesis|ioniq|kona|nexo|palisade|fe|sonata|tucson|veloster|venue|veracruz|g|q40|q50|q60|qx30|e-pace|f-pace|f-type|i-pace|xe|xf|xj|xk|cherokee|commander|compass|gladiator|liberty|patriot|renegade|wrangler|amanti|borrego|cadenza|forte|k5|k900|niro|optima|rio|rondo|sedona|seltos|sorento|soul|spectra|sportage|stinger|telluride|defender|lr4|lr2|rover|evoque|velar|ct|ct200h|gs|is|lc|lfa|ls|nx|rc|rx|sc430|ux|aviator|continental|mkc|mks|mkt|mkz|navigator|car|ghibli|granturismo|levante|quattroporte|2|3|5|6|b-series|cx-3|cx-30|cx-5|cx-7|cx-9|miata|rx-8|tribute|a-class|b-class|c-class|cl-class|cla-class|clk-class|cls-class|e-class|g-class|gla-class|glb|glc-class|glk-class|r-class|s-class|sl-class|amg|sprinter|marquis|mariner|milan|mountaineer|sable|cooper|clubman|convertible|coupe|2-door|4-door|roadster|countryman|paceman|cross|endeavor|galant|lancer|mirage|outlander|phev|raider|i-miev|altima|armada|cube|frontier|gt-r|juke|kicks|leaf|maxima|murano|nv|nv200|pathfinder|quest|rogue|sentra|titan|versa|xterra|g3|g5|g6|g8|prix|solstice|vibe|718|911|spyder|boxster|cayenne|cayman|macan|panamera|taycan|van|pickup|promaster|city|9-3|9-4x|9-5|9-7x|astra|aura|outlook|sky|vue|iq|tc|xb|xd|fortwo|ascent|brz|forester|sti|legacy|outback|tribeca|equator|vitara|kizashi|xl7|s|y|4runner|fr-s|avalon|c-hr|camry|im|highlander|mirai|prius|rav4|sequoia|sienna|supra|tacoma|tundra|venza|hatchback|ia|arteon|atlas|beetle|cc|eos|alltrack|jetta|passat|routan|tiguan|touareg|c30|c70|s40|s80|v50|v70|xc40|xc60|xc70|xc90|q70|m|ex|qx50|qx60|jx|qx70|fx|qx80|qx56|es|es350|gx|gx460|hs|hs250h|lx|lx570|mkx|nautilus|gl-class|gls-class|gle-class|m-class|metris|vito|slk-class|slc-class|eclipse|spyder|370z|350z|crosstrek|crosstrek|forenza|reno|sx4|aerio|corolla|matrix|s60|v60|s90|v90

# %%
# create DataFrame where only the cars from our car sales data are included
cars_filtered = lower_car_mov.loc[lower_car_mov.Car.str.contains(brand_var)]
cars_filtered
# Out:
#           Release  Year                             Car  \
# 0     Toy Story 3  2010      1998 chevrolet corvette c5
# 3     Toy Story 3  2010               1979 toyota truck
# 4      Iron Man 2  2010                  2010 acura zdx
# 6      Iron Man 2  2010               2008 audi a8 l d3
# 7      Iron Man 2  2010             2010 audi r8 spyder
# ...           ...   ...                             ...
# 1980  Daybreakers  2010        1997 mitsubishi diamante
# 1981  Daybreakers  2010  1978 pontiac firebird trans am
# 1984  Daybreakers  2010               2004 smart fortwo
# 1985  Daybreakers  2010             1993 toyota 4runner
# 1986  Daybreakers  2010            2006 toyota prius ii
#
#                                                     url  Stars
# 0           vehicle_369776-Chevrolet-Corvette-1998.html      3
# 3            vehicle_349573-Toyota-Truck-RN30-1979.html      2
# 4                vehicle_340464-Acura-ZDX-YB1-2010.html      2
# 6             vehicle_299564-Audi-A8-L-Typ-4E-2008.html      3
# 7        vehicle_239415-Audi-R8-Spyder-Typ-42-2010.html      3
# ...                                                 ...    ...
# 1980  vehicle_318489-Mitsubishi-Diamante-F38A-1997.html      1
# 1981  vehicle_223185-Pontiac-Firebird-Trans-Am-1978....      3
# 1984          vehicle_317791-smart-Fortwo-450-2004.html      1
# 1985       vehicle_236774-Toyota-4Runner-N130-1993.html      2
# 1986        vehicle_317792-Toyota-Prius-NHW20-2006.html      1
#
# [1640 rows x 5 columns]

# %%
cars_filtered.loc[cars_filtered.Car.str.contains(model_var)]
# Out:
#           Release  Year                             Car  \
# 0     Toy Story 3  2010      1998 chevrolet corvette c5
# 3     Toy Story 3  2010               1979 toyota truck
# 4      Iron Man 2  2010                  2010 acura zdx
# 6      Iron Man 2  2010               2008 audi a8 l d3
# 7      Iron Man 2  2010             2010 audi r8 spyder
# ...           ...   ...                             ...
# 1980  Daybreakers  2010        1997 mitsubishi diamante
# 1981  Daybreakers  2010  1978 pontiac firebird trans am
# 1984  Daybreakers  2010               2004 smart fortwo
# 1985  Daybreakers  2010             1993 toyota 4runner
# 1986  Daybreakers  2010            2006 toyota prius ii
#
#                                                     url  Stars
# 0           vehicle_369776-Chevrolet-Corvette-1998.html      3
# 3            vehicle_349573-Toyota-Truck-RN30-1979.html      2
# 4                vehicle_340464-Acura-ZDX-YB1-2010.html      2
# 6             vehicle_299564-Audi-A8-L-Typ-4E-2008.html      3
# 7        vehicle_239415-Audi-R8-Spyder-Typ-42-2010.html      3
# ...                                                 ...    ...
# 1980  vehicle_318489-Mitsubishi-Diamante-F38A-1997.html      1
# 1981  vehicle_223185-Pontiac-Firebird-Trans-Am-1978....      3
# 1984          vehicle_317791-smart-Fortwo-450-2004.html      1
# 1985       vehicle_236774-Toyota-4Runner-N130-1993.html      2
# 1986        vehicle_317792-Toyota-Prius-NHW20-2006.html      1
#
# [1594 rows x 5 columns]

# %%
lower_car_mov.loc[lower_car_mov.Car.str.contains(brand_var) & lower_car_mov.Car.str.contains(model_var)]
# Out:
#           Release  Year                             Car  \
# 0     Toy Story 3  2010      1998 chevrolet corvette c5
# 3     Toy Story 3  2010               1979 toyota truck
# 4      Iron Man 2  2010                  2010 acura zdx
# 6      Iron Man 2  2010               2008 audi a8 l d3
# 7      Iron Man 2  2010             2010 audi r8 spyder
# ...           ...   ...                             ...
# 1980  Daybreakers  2010        1997 mitsubishi diamante
# 1981  Daybreakers  2010  1978 pontiac firebird trans am
# 1984  Daybreakers  2010               2004 smart fortwo
# 1985  Daybreakers  2010             1993 toyota 4runner
# 1986  Daybreakers  2010            2006 toyota prius ii
#
#                                                     url  Stars
# 0           vehicle_369776-Chevrolet-Corvette-1998.html      3
# 3            vehicle_349573-Toyota-Truck-RN30-1979.html      2
# 4                vehicle_340464-Acura-ZDX-YB1-2010.html      2
# 6             vehicle_299564-Audi-A8-L-Typ-4E-2008.html      3
# 7        vehicle_239415-Audi-R8-Spyder-Typ-42-2010.html      3
# ...                                                 ...    ...
# 1980  vehicle_318489-Mitsubishi-Diamante-F38A-1997.html      1
# 1981  vehicle_223185-Pontiac-Firebird-Trans-Am-1978....      3
# 1984          vehicle_317791-smart-Fortwo-450-2004.html      1
# 1985       vehicle_236774-Toyota-4Runner-N130-1993.html      2
# 1986        vehicle_317792-Toyota-Prius-NHW20-2006.html      1
#
# [1594 rows x 5 columns]

# %%
# read in film data
movies = pd.read_csv('output_data/Top100_Movies_2010-2021.csv')

# %%
# create a DataFrame of only films from the top 2010 grossing films
df10 = movies.loc[movies.Year == 2010]
df10
# Out:
#     Rank                      Release         Gross Theaters   Total Gross  \
# 0      1                       Avatar  $466,141,929     3461  $749,766,139
# 1      2                  Toy Story 3  $415,004,880     4028  $415,004,880
# 2      3          Alice in Wonderland  $334,191,110     3739  $334,191,110
# 3      4                   Iron Man 2  $312,433,331     4390  $312,433,331
# 4      5   The Twilight Saga: Eclipse  $300,531,751     4468  $300,531,751
# ..   ...                          ...           ...      ...           ...
# 95    96  Scott Pilgrim vs. the World   $31,524,275     2820   $31,524,275
# 96    97            Charlie St. Cloud   $31,162,545     2725   $31,162,545
# 97    98           Love & Other Drugs   $31,099,481     2458   $32,367,005
# 98    99                Morning Glory   $30,727,814     2544   $31,011,732
# 99   100                  Daybreakers   $30,101,577     2523   $30,101,577
#
#    Release Date                          Distributor  Year
# 0        Dec 18                Twentieth Century Fox  2010
# 1        Jun 18  Walt Disney Studios Motion Pictures  2010
# 2         Mar 5  Walt Disney Studios Motion Pictures  2010
# 3         May 7                   Paramount Pictures  2010
# 4        Jun 30                 Summit Entertainment  2010
# ..          ...                                  ...   ...
# 95       Aug 13                   Universal Pictures  2010
# 96       Jul 30                   Universal Pictures  2010
# 97       Nov 24                Twentieth Century Fox  2010
# 98       Nov 10                   Paramount Pictures  2010
# 99        Jan 8                            Lionsgate  2010
#
# [100 rows x 8 columns]

# %%
# create a DataFrame that merges the car and movie data
car_mov = pd.merge(cars_filtered, df10, how="left", on="Release")
car_mov
# Out:
#           Release  Year_x                             Car  \
# 0     Toy Story 3    2010      1998 chevrolet corvette c5
# 1     Toy Story 3    2010               1979 toyota truck
# 2      Iron Man 2    2010                  2010 acura zdx
# 3      Iron Man 2    2010               2008 audi a8 l d3
# 4      Iron Man 2    2010             2010 audi r8 spyder
# ...           ...     ...                             ...
# 1635  Daybreakers    2010        1997 mitsubishi diamante
# 1636  Daybreakers    2010  1978 pontiac firebird trans am
# 1637  Daybreakers    2010               2004 smart fortwo
# 1638  Daybreakers    2010             1993 toyota 4runner
# 1639  Daybreakers    2010            2006 toyota prius ii
#
#                                                     url  Stars  Rank  \
# 0           vehicle_369776-Chevrolet-Corvette-1998.html      3     2
# 1            vehicle_349573-Toyota-Truck-RN30-1979.html      2     2
# 2                vehicle_340464-Acura-ZDX-YB1-2010.html      2     4
# 3             vehicle_299564-Audi-A8-L-Typ-4E-2008.html      3     4
# 4        vehicle_239415-Audi-R8-Spyder-Typ-42-2010.html      3     4
# ...                                                 ...    ...   ...
# 1635  vehicle_318489-Mitsubishi-Diamante-F38A-1997.html      1   100
# 1636  vehicle_223185-Pontiac-Firebird-Trans-Am-1978....      3   100
# 1637          vehicle_317791-smart-Fortwo-450-2004.html      1   100
# 1638       vehicle_236774-Toyota-4Runner-N130-1993.html      2   100
# 1639        vehicle_317792-Toyota-Prius-NHW20-2006.html      1   100
#
#              Gross Theaters   Total Gross Release Date  \
# 0     $415,004,880     4028  $415,004,880       Jun 18
# 1     $415,004,880     4028  $415,004,880       Jun 18
# 2     $312,433,331     4390  $312,433,331        May 7
# 3     $312,433,331     4390  $312,433,331        May 7
# 4     $312,433,331     4390  $312,433,331        May 7
# ...            ...      ...           ...          ...
# 1635   $30,101,577     2523   $30,101,577        Jan 8
# 1636   $30,101,577     2523   $30,101,577        Jan 8
# 1637   $30,101,577     2523   $30,101,577        Jan 8
# 1638   $30,101,577     2523   $30,101,577        Jan 8
# 1639   $30,101,577     2523   $30,101,577        Jan 8
#
#                               Distributor  Year_y
# 0     Walt Disney Studios Motion Pictures    2010
# 1     Walt Disney Studios Motion Pictures    2010
# 2                      Paramount Pictures    2010
# 3                      Paramount Pictures    2010
# 4                      Paramount Pictures    2010
# ...                                   ...     ...
# 1635                            Lionsgate    2010
# 1636                            Lionsgate    2010
# 1637                            Lionsgate    2010
# 1638                            Lionsgate    2010
# 1639                            Lionsgate    2010
#
# [1640 rows x 12 columns]

# %%
# display data for cars made in 2010 with a strong screen presence
car_mov.loc[(car_mov.Car.str.contains('2010')) & (car_mov.Stars >= 3)]
# Out:
#                               Release  Year_x  \
# 4                          Iron Man 2    2010
# 35         The Twilight Saga: Eclipse    2010
# 362                   Valentine's Day    2010
# 373                   Valentine's Day    2010
# 415                          Due Date    2010
# 424                          Due Date    2010
# 693                    Little Fockers    2010
# 783                        The A-Team    2010
# 1056               Life as We Know It    2010
# 1098  Wall Street: Money Never Sleeps    2010
#
#                                          Car  \
# 4                        2010 audi r8 spyder
# 35                           2010 volvo xc60
# 362                2010 ford transit connect
# 373                    2010 toyota prius iii
# 415   2010 land-rover range rover series iii
# 424                      2010 subaru impreza
# 693                    2010 chevrolet malibu
# 783       2010 mercedes-benz e-klasse [w212]
# 1056                  2010 triumph scrambler
# 1098                   2010 toyota prius iii
#
#                                                     url  Stars  Rank  \
# 4        vehicle_239415-Audi-R8-Spyder-Typ-42-2010.html      3     4
# 35                  vehicle_359180-Volvo-XC60-2010.html      3     5
# 362       vehicle_316137-Ford-Transit-Connect-2010.html      3    22
# 373         vehicle_316128-Toyota-Prius-ZVW30-2010.html      3    22
# 415   vehicle_325355-Land-Rover-Range-Rover-L322-201...      3    26
# 424          vehicle_325351-Subaru-Impreza-GH-2010.html      4    26
# 693           vehicle_386490-Chevrolet-Malibu-2010.html      3    37
# 783   vehicle_316899-Mercedes-Benz-E-Klasse-W212-201...      3    42
# 1056         vehicle_369804-Triumph-Scrambler-2010.html      3    64
# 1098        vehicle_368590-Toyota-Prius-ZVW30-2010.html      3    65
#
#              Gross Theaters   Total Gross Release Date            Distributor  \
# 4     $312,433,331     4390  $312,433,331        May 7     Paramount Pictures
# 35    $300,531,751     4468  $300,531,751       Jun 30   Summit Entertainment
# 362   $110,485,654     3665  $110,485,654       Feb 12           Warner Bros.
# 373   $110,485,654     3665  $110,485,654       Feb 12           Warner Bros.
# 415    $98,935,039     3365  $100,539,043        Nov 5           Warner Bros.
# 424    $98,935,039     3365  $100,539,043        Nov 5           Warner Bros.
# 693    $84,557,425     3675  $148,438,600       Dec 22     Universal Pictures
# 783    $77,222,099     3544   $77,222,099       Jun 11  Twentieth Century Fox
# 1056   $52,727,343     3150   $53,374,681        Oct 8           Warner Bros.
# 1098   $52,474,616     3597   $52,474,616       Sep 24  Twentieth Century Fox
#
#       Year_y
# 4       2010
# 35      2010
# 362     2010
# 373     2010
# 415     2010
# 424     2010
# 693     2010
# 783     2010
# 1056    2010
# 1098    2010

# %%
# create a clean DataFrame that only keeps relevant columns
clean_car_mov = car_mov[['Release', 'Car', 'Stars', 'Rank', 'Gross', 'Year_y']]

# %%
# create a list of years, as strings, to search for cars made in the decade prior to our analysis range
yrs = np.arange(2000, 2011, 1).tolist()
years = [str(x) for x in yrs]
print(years)
# Out:
# ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010']

# %%
# display cars made in the years 2000 through 2010
all_years = "|".join(years)
clean_car_mov.loc[clean_car_mov.Car.str.contains(all_years) & (clean_car_mov.Stars >= 3)][["Car","Release","Rank","Gross"]].sort_values(by='Car')
# Out:
#                                             Car  \
# 624   2000 cadillac deville stretched limousine
# 1422                   2000 ford crown victoria
# 163                    2000 ford crown victoria
# 924                  2000 porsche boxster [986]
# 525                          2001 dodge caravan
# ...                                         ...
# 424                         2010 subaru impreza
# 1098                      2010 toyota prius iii
# 373                       2010 toyota prius iii
# 1056                     2010 triumph scrambler
# 35                              2010 volvo xc60
#
#                               Release  Rank         Gross
# 624                               RED    34   $89,296,297
# 1422                    Vampires Suck    88   $36,661,504
# 163                    The Other Guys    18  $119,219,978
# 924        Why Did I Get Married Too?    55   $60,095,852
# 525                          The Town    32   $92,155,037
# ...                               ...   ...           ...
# 424                          Due Date    26   $98,935,039
# 1098  Wall Street: Money Never Sleeps    65   $52,474,616
# 373                   Valentine's Day    22  $110,485,654
# 1056               Life as We Know It    64   $52,727,343
# 35         The Twilight Saga: Eclipse     5  $300,531,751
#
# [84 rows x 4 columns]

# %%
# look at the cars made in 2000
clean_car_mov.loc[clean_car_mov.Car.str.contains('2000') & (clean_car_mov.Stars >= 3)]
# Out:
#                          Release                                        Car  \
# 163               The Other Guys                   2000 ford crown victoria
# 624                          RED  2000 cadillac deville stretched limousine
# 924   Why Did I Get Married Too?                 2000 porsche boxster [986]
# 1422               Vampires Suck                   2000 ford crown victoria
#
#       Stars  Rank         Gross  Year_y
# 163       3    18  $119,219,978    2010
# 624       3    34   $89,296,297    2010
# 924       3    55   $60,095,852    2010
# 1422      3    88   $36,661,504    2010
