# %%
# dependencies
import pandas as pd
import requests
import json
from datetime import date
from omdb_config import api_key

# %%
# export dataframe of results with today's date
today = date.today()
d_today = today.strftime("%Y_%m_%d")

# %%
# read in the data for top 100 movies
top_100df = pd.read_csv("output_data/Top100_Movies_2010-2021.csv")

# %%
# set the year of movies we are collecting data for
year = 2020

# %%
# filter DataFrame for the 100 movies in the specified year
top_100 = top_100df.loc[top_100df["Year"] == year]
# create a list of the top 100 movies to iterate through
movies = top_100["Release"].tolist()
print(movies)
# Out:
# ['Bad Boys for Life', '1917', 'Sonic the Hedgehog', 'Jumanji: The Next Level', 'Star Wars: Episode IX - The Rise of Skywalker', 'Birds of Prey', 'Dolittle', 'Little Women', 'The Invisible Man', 'The Call of the Wild', 'Onward', 'Knives Out', 'Frozen II', 'Tenet', 'Spies in Disguise', 'The Gentlemen', 'Just Mercy', 'The Croods: A New Age', 'Parasite', 'Fantasy Island', 'Uncut Gems', 'The New Mutants', 'Like a Boss', 'The Grudge', 'Unhinged', 'The Photograph', 'The War with Grandpa', 'Underwater', 'Wonder Woman 1984', 'The Turning', 'Gretel & Hansel', 'Honest Thief', 'My Hero Academia: Heroes Rising', 'Bombshell', 'The Way Back', 'Brahms: The Boy II', 'Jojo Rabbit', 'Impractical Jokers: The Movie', 'Ford v Ferrari', 'Emma.', 'Bloodshot', 'I Still Believe', 'Come Play', 'Let Him Go', 'Freaky', 'Downhill', 'Weathering with You', 'Cats', 'The Hunt', 'The Rhythm Section', 'Monster Hunter', 'A Beautiful Day in the Neighborhood', 'Hocus Pocus2020 Re-release', 'Richard Jewell', 'The SpongeBob Movie: Sponge on the Run', 'The Broken Hearts Gallery', 'Infidel', 'News of the World', 'Portrait of a Lady on Fire', 'Bill & Ted Face the Music', '2020 Oscar Nominated Short Films', 'Queen & Slim', 'The Empty Man', "My Boyfriend's Meds", 'The Last Full Measure', 'Words on Bathroom Walls', 'Star Wars: Episode V - The Empire Strikes Back2020 Re-release', 'Fatale', 'The Nightmare Before Christmas2020 Re-release', 'Ip Man 4: The Finale', 'Half Brothers', 'Elf2020 Re-release', 'The Personal History of David Copperfield', 'The Wretched', 'The Lodge', 'Joker', 'The Rental', 'Once Upon a Time... In Hollywood', 'Jurassic Park2020 Re-release', '2 Hearts', 'Promising Young Woman', 'True to the Game 2', 'Train to Busan Presents: Peninsula', 'The Assistant', 'Love and Monsters', 'Relic', 'The Tax Collector', 'The Last Shift', 'Becky', 'The Song of Names', 'All My Life', 'Mafia Inc', "National Lampoon's Christmas Vacation2020 Re-release", 'Jay and Silent Bob Reboot', 'A Hidden Life', 'Cut Throat City', 'The Goonies2020 Re-release', 'Sarileru Neekevvaru', 'Vanguard', 'Shortcut']

# %%
# create variables to store url
url = "http://www.omdbapi.com/?t="
api_key = "&apikey=" + api_key

# %%
# for loop that iterates over the movie list, performing a request for each movie...
# ...and appending the data into empty lists for a DataFrame
title = []
year_ = []
rated = []
released = []
runtime = []
genre = []
director = []
actors = []
country = []
awards = []
rotten_tom = []
metascore = []
imdb_rating = []
imdb_votes = []
imdb_id = []

for movie in movies:
    try:
        response = requests.get(url + f"{movie}" + api_key)
        data = response.json()
    except:
        print(f"For some reason, OMDdb didn't have: {movie}.")
        
    try:
        title.append(data["Title"])
    except:
        title.append("NaN")
        print(f"No Title: {movie}.")
    try:
        year_.append(data["Year"])
    except:
        year_.append("NaN")
        print(f"No Year: {movie}.")
    try:
        rated.append(data["Rated"])
    except:
        rated.append("NaN")
        print(f"No Rated: {movie}.")
    try:
        released.append(data["Released"])
    except:
        released.append("NaN")
        print(f"No Released: {movie}.")
    try:
        runtime.append(data["Runtime"])
    except:
        runtime.append("NaN")
        print(f"No Runtime: {movie}.")
    try:
        genre.append(data["Genre"])
    except:
        genre.append("NaN")
        print(f"No Genre: {movie}.")
    try:
        director.append(data["Director"])
    except:
        director.append("NaN")
        print(f"No Director: {movie}.")
    try:
        actors.append(data["Actors"])
    except:
        actors.append("NaN")
        print(f"No Actors: {movie}.")
    try:
        country.append(data["Country"])
    except:
        country.append("NaN")
        print(f"No Country: {movie}.")
    try:
        awards.append(data["Awards"])
    except:
        awards.append("NaN")
        print(f"No Awards: {movie}.")
    try:
        rotten_tom.append(data["Ratings"][1]["Value"])
    except:
        rotten_tom.append("NaN")
        print(f"No Rotten Tomatoes: {movie}.")
    try:
        metascore.append(data["Metascore"])
    except:
        metascore.append("NaN")
        print(f"No Metascore: {movie}.")
    try:
        imdb_rating.append(data["imdbRating"])
    except:
        imdb_rating.append("NaN")
        print(f"No imdbRating: {movie}.")
    try:
        imdb_votes.append(data["imdbVotes"])
    except:
        imdb_votes.append("NaN")
        print(f"No imdbVotes: {movie}.")
    try:
        imdb_id.append(data["imdbID"])
    except:
        imdb_id.append("NaN")
        print(f"No imdbID: {movie}.")
# Out:
# No Rotten Tomatoes: Gretel & Hansel.
# No Title: Hocus Pocus2020 Re-release.
# No Year: Hocus Pocus2020 Re-release.
# No Rated: Hocus Pocus2020 Re-release.
# No Released: Hocus Pocus2020 Re-release.
# No Runtime: Hocus Pocus2020 Re-release.
# No Genre: Hocus Pocus2020 Re-release.
# No Director: Hocus Pocus2020 Re-release.
# No Actors: Hocus Pocus2020 Re-release.
# No Country: Hocus Pocus2020 Re-release.
# No Awards: Hocus Pocus2020 Re-release.
# No Rotten Tomatoes: Hocus Pocus2020 Re-release.
# No Metascore: Hocus Pocus2020 Re-release.
# No imdbRating: Hocus Pocus2020 Re-release.
# No imdbVotes: Hocus Pocus2020 Re-release.
# No imdbID: Hocus Pocus2020 Re-release.
# No Rotten Tomatoes: Infidel.
# No Rotten Tomatoes: 2020 Oscar Nominated Short Films.
# No Rotten Tomatoes: The Empty Man.
# No Rotten Tomatoes: My Boyfriend's Meds.
# No Title: Star Wars: Episode V - The Empire Strikes Back2020 Re-release.
# No Year: Star Wars: Episode V - The Empire Strikes Back2020 Re-release.
# No Rated: Star Wars: Episode V - The Empire Strikes Back2020 Re-release.
# No Released: Star Wars: Episode V - The Empire Strikes Back2020 Re-release.
# No Runtime: Star Wars: Episode V - The Empire Strikes Back2020 Re-release.
# No Genre: Star Wars: Episode V - The Empire Strikes Back2020 Re-release.
# No Director: Star Wars: Episode V - The Empire Strikes Back2020 Re-release.
# No Actors: Star Wars: Episode V - The Empire Strikes Back2020 Re-release.
# No Country: Star Wars: Episode V - The Empire Strikes Back2020 Re-release.
# No Awards: Star Wars: Episode V - The Empire Strikes Back2020 Re-release.
# No Rotten Tomatoes: Star Wars: Episode V - The Empire Strikes Back2020 Re-release.
# No Metascore: Star Wars: Episode V - The Empire Strikes Back2020 Re-release.
# No imdbRating: Star Wars: Episode V - The Empire Strikes Back2020 Re-release.
# No imdbVotes: Star Wars: Episode V - The Empire Strikes Back2020 Re-release.
# No imdbID: Star Wars: Episode V - The Empire Strikes Back2020 Re-release.
# No Title: The Nightmare Before Christmas2020 Re-release.
# No Year: The Nightmare Before Christmas2020 Re-release.
# No Rated: The Nightmare Before Christmas2020 Re-release.
# No Released: The Nightmare Before Christmas2020 Re-release.
# No Runtime: The Nightmare Before Christmas2020 Re-release.
# No Genre: The Nightmare Before Christmas2020 Re-release.
# No Director: The Nightmare Before Christmas2020 Re-release.
# No Actors: The Nightmare Before Christmas2020 Re-release.
# No Country: The Nightmare Before Christmas2020 Re-release.
# No Awards: The Nightmare Before Christmas2020 Re-release.
# No Rotten Tomatoes: The Nightmare Before Christmas2020 Re-release.
# No Metascore: The Nightmare Before Christmas2020 Re-release.
# No imdbRating: The Nightmare Before Christmas2020 Re-release.
# No imdbVotes: The Nightmare Before Christmas2020 Re-release.
# No imdbID: The Nightmare Before Christmas2020 Re-release.
# No Title: Elf2020 Re-release.
# No Year: Elf2020 Re-release.
# No Rated: Elf2020 Re-release.
# No Released: Elf2020 Re-release.
# No Runtime: Elf2020 Re-release.
# No Genre: Elf2020 Re-release.
# No Director: Elf2020 Re-release.
# No Actors: Elf2020 Re-release.
# No Country: Elf2020 Re-release.
# No Awards: Elf2020 Re-release.
# No Rotten Tomatoes: Elf2020 Re-release.
# No Metascore: Elf2020 Re-release.
# No imdbRating: Elf2020 Re-release.
# No imdbVotes: Elf2020 Re-release.
# No imdbID: Elf2020 Re-release.
# No Title: Jurassic Park2020 Re-release.
# No Year: Jurassic Park2020 Re-release.
# No Rated: Jurassic Park2020 Re-release.
# No Released: Jurassic Park2020 Re-release.
# No Runtime: Jurassic Park2020 Re-release.
# No Genre: Jurassic Park2020 Re-release.
# No Director: Jurassic Park2020 Re-release.
# No Actors: Jurassic Park2020 Re-release.
# No Country: Jurassic Park2020 Re-release.
# No Awards: Jurassic Park2020 Re-release.
# No Rotten Tomatoes: Jurassic Park2020 Re-release.
# No Metascore: Jurassic Park2020 Re-release.
# No imdbRating: Jurassic Park2020 Re-release.
# No imdbVotes: Jurassic Park2020 Re-release.
# No imdbID: Jurassic Park2020 Re-release.
# No Rotten Tomatoes: True to the Game 2.
# No Rotten Tomatoes: All My Life.
# No Title: National Lampoon's Christmas Vacation2020 Re-release.
# No Year: National Lampoon's Christmas Vacation2020 Re-release.
# No Rated: National Lampoon's Christmas Vacation2020 Re-release.
# No Released: National Lampoon's Christmas Vacation2020 Re-release.
# No Runtime: National Lampoon's Christmas Vacation2020 Re-release.
# No Genre: National Lampoon's Christmas Vacation2020 Re-release.
# No Director: National Lampoon's Christmas Vacation2020 Re-release.
# No Actors: National Lampoon's Christmas Vacation2020 Re-release.
# No Country: National Lampoon's Christmas Vacation2020 Re-release.
# No Awards: National Lampoon's Christmas Vacation2020 Re-release.
# No Rotten Tomatoes: National Lampoon's Christmas Vacation2020 Re-release.
# No Metascore: National Lampoon's Christmas Vacation2020 Re-release.
# No imdbRating: National Lampoon's Christmas Vacation2020 Re-release.
# No imdbVotes: National Lampoon's Christmas Vacation2020 Re-release.
# No imdbID: National Lampoon's Christmas Vacation2020 Re-release.
# No Title: The Goonies2020 Re-release.
# No Year: The Goonies2020 Re-release.
# No Rated: The Goonies2020 Re-release.
# No Released: The Goonies2020 Re-release.
# No Runtime: The Goonies2020 Re-release.
# No Genre: The Goonies2020 Re-release.
# No Director: The Goonies2020 Re-release.
# No Actors: The Goonies2020 Re-release.
# No Country: The Goonies2020 Re-release.
# No Awards: The Goonies2020 Re-release.
# No Rotten Tomatoes: The Goonies2020 Re-release.
# No Metascore: The Goonies2020 Re-release.
# No imdbRating: The Goonies2020 Re-release.
# No imdbVotes: The Goonies2020 Re-release.
# No imdbID: The Goonies2020 Re-release.
# No Rotten Tomatoes: Sarileru Neekevvaru.

# %%
print(len(title))
# Out:
# 100

# %%
# create list of missing movies
#missing = ["Knight and Day2010 Re-release", "Percy Jackson & the Olympians: The Lightning Thief"]

# use list comprehension to remove missing movies
#movies = [movie for movie in movies if movie not in missing]

# %%
# creat DataFrame with the data collected in lists
omdb_df = pd.DataFrame({"Release": movies, "Title": title, "Year": year_,
                        "Rated": rated, "Released": released, "Runtime": runtime, "Genre": genre,
                        "Director": director, "Actors": actors, "Country": country, "Awards": awards,
                        "Rotten Tomatoes": rotten_tom, "Metascore": metascore, "IMDB": imdb_rating,
                        "IMDB Votes": imdb_votes, "IMDB id": imdb_id})
omdb_df
# Out:
#                                           Release  \
# 0                               Bad Boys for Life
# 1                                            1917
# 2                              Sonic the Hedgehog
# 3                         Jumanji: The Next Level
# 4   Star Wars: Episode IX - The Rise of Skywalker
# ..                                            ...
# 95                                Cut Throat City
# 96                     The Goonies2020 Re-release
# 97                            Sarileru Neekevvaru
# 98                                       Vanguard
# 99                                       Shortcut
#
#                                             Title  Year      Rated  \
# 0                               Bad Boys for Life  2020          R
# 1                                            1917  2019          R
# 2                              Sonic the Hedgehog  2020         PG
# 3                         Jumanji: The Next Level  2019      PG-13
# 4   Star Wars: Episode IX - The Rise of Skywalker  2019      PG-13
# ..                                            ...   ...        ...
# 95                                Cut Throat City  2020          R
# 96                                            NaN   NaN        NaN
# 97                            Sarileru Neekevvaru  2020  Not Rated
# 98                                       Vanguard  2020      PG-13
# 99                                       Shortcut  2020          R
#
#        Released  Runtime                                Genre  \
# 0   17 Jan 2020  124 min      Action, Comedy, Crime, Thriller
# 1   10 Jan 2020  119 min                 Drama, Thriller, War
# 2   14 Feb 2020   99 min    Action, Adventure, Comedy, Sci-Fi
# 3   13 Dec 2019  123 min   Action, Adventure, Comedy, Fantasy
# 4   20 Dec 2019  141 min   Action, Adventure, Fantasy, Sci-Fi
# ..          ...      ...                                  ...
# 95  21 Aug 2020  123 min       Action, Crime, Drama, Thriller
# 96          NaN      NaN                                  NaN
# 97  10 Jan 2020  169 min                Action, Comedy, Drama
# 98  20 Nov 2020  107 min  Action, Adventure, Comedy, Thriller
# 99  25 Sep 2020   80 min           Adventure, Fantasy, Horror
#
#                        Director  \
# 0   Adil El Arbi, Bilall Fallah
# 1                    Sam Mendes
# 2                   Jeff Fowler
# 3                   Jake Kasdan
# 4                   J.J. Abrams
# ..                          ...
# 95                          RZA
# 96                          NaN
# 97                Anil Ravipudi
# 98                 Stanley Tong
# 99              Alessio Liguori
#
#                                                Actors  \
# 0   Will Smith, Martin Lawrence, Vanessa Hudgens, ...
# 1   Dean-Charles Chapman, George MacKay, Daniel Ma...
# 2   Ben Schwartz, James Marsden, Jim Carrey, Tika ...
# 3   Dwayne Johnson, Kevin Hart, Jack Black, Karen ...
# 4   Carrie Fisher, Mark Hamill, Adam Driver, Daisy...
# ..                                                ...
# 95  Shameik Moore, Demetrius Shipp Jr., Denzel Whi...
# 96                                                NaN
# 97  Mahesh Babu, Rashmika Mandanna, Vijayshanti, P...
# 98          Jackie Chan, Yang Yang, Lun Ai, Miya Muqi
# 99  Jack Kane, Zander Emlano, Zak Sutcliffe, Sophi...
#
#                                  Country  \
# 0                            USA, Mexico
# 1   USA, UK, India, Spain, Canada, China
# 2                     USA, Japan, Canada
# 3                                    USA
# 4                                    USA
# ..                                   ...
# 95                                   USA
# 96                                   NaN
# 97                                 India
# 98                                 China
# 99                        Italy, Germany
#
#                                                Awards Rotten Tomatoes  \
# 0                            2 wins & 14 nominations.             77%
# 1   Won 3 Oscars. Another 127 wins & 198 nominations.             89%
# 2                             3 wins & 9 nominations.             63%
# 3                             1 win & 10 nominations.             71%
# 4   Nominated for 3 Oscars. Another 9 wins & 39 no...             51%
# ..                                                ...             ...
# 95                                                N/A          67/100
# 96                                                NaN             NaN
# 97                                                N/A             NaN
# 98                              1 win & 1 nomination.          34/100
# 99                                                N/A          26/100
#
#    Metascore IMDB IMDB Votes     IMDB id
# 0         59  6.6    133,505   tt1502397
# 1         78  8.3    442,036   tt8579674
# 2         47  6.5     92,987   tt3794354
# 3         58  6.6    192,270   tt7975244
# 4         53  6.6    378,434   tt2527338
# ..       ...  ...        ...         ...
# 95        67  4.9      1,584   tt3547306
# 96       NaN  NaN        NaN         NaN
# 97       N/A  6.0      5,364  tt10773090
# 98        34  4.7      3,126   tt9695722
# 99        26  3.9        617   tt8960138
#
# [100 rows x 16 columns]

# %%
# filter out the rows that are mostly NaN, using above intel
clean_omdb_df = omdb_df.loc[(omdb_df["Release"] != "Hocus Pocus2020 Re-release")\
                            & (omdb_df["Release"] != "Star Wars: Episode V - The Empire Strikes Back2020 Re-release")\
                            & (omdb_df["Release"] != "The Nightmare Before Christmas2020 Re-release")\
                            & (omdb_df["Release"] != "Elf2020 Re-release")\
                            & (omdb_df["Release"] != "Jurassic Park2020 Re-release")\
                            & (omdb_df["Release"] != "National Lampoon's Christmas Vacation2020 Re-release")\
                            & (omdb_df["Release"] != "The Goonies2020 Re-release")]
clean_omdb_df
# Out:
#                                           Release  \
# 0                               Bad Boys for Life
# 1                                            1917
# 2                              Sonic the Hedgehog
# 3                         Jumanji: The Next Level
# 4   Star Wars: Episode IX - The Rise of Skywalker
# ..                                            ...
# 94                                  A Hidden Life
# 95                                Cut Throat City
# 97                            Sarileru Neekevvaru
# 98                                       Vanguard
# 99                                       Shortcut
#
#                                             Title  Year      Rated  \
# 0                               Bad Boys for Life  2020          R
# 1                                            1917  2019          R
# 2                              Sonic the Hedgehog  2020         PG
# 3                         Jumanji: The Next Level  2019      PG-13
# 4   Star Wars: Episode IX - The Rise of Skywalker  2019      PG-13
# ..                                            ...   ...        ...
# 94                                  A Hidden Life  2019      PG-13
# 95                                Cut Throat City  2020          R
# 97                            Sarileru Neekevvaru  2020  Not Rated
# 98                                       Vanguard  2020      PG-13
# 99                                       Shortcut  2020          R
#
#        Released  Runtime                                Genre  \
# 0   17 Jan 2020  124 min      Action, Comedy, Crime, Thriller
# 1   10 Jan 2020  119 min                 Drama, Thriller, War
# 2   14 Feb 2020   99 min    Action, Adventure, Comedy, Sci-Fi
# 3   13 Dec 2019  123 min   Action, Adventure, Comedy, Fantasy
# 4   20 Dec 2019  141 min   Action, Adventure, Fantasy, Sci-Fi
# ..          ...      ...                                  ...
# 94  17 Jan 2020  174 min       Biography, Drama, Romance, War
# 95  21 Aug 2020  123 min       Action, Crime, Drama, Thriller
# 97  10 Jan 2020  169 min                Action, Comedy, Drama
# 98  20 Nov 2020  107 min  Action, Adventure, Comedy, Thriller
# 99  25 Sep 2020   80 min           Adventure, Fantasy, Horror
#
#                        Director  \
# 0   Adil El Arbi, Bilall Fallah
# 1                    Sam Mendes
# 2                   Jeff Fowler
# 3                   Jake Kasdan
# 4                   J.J. Abrams
# ..                          ...
# 94              Terrence Malick
# 95                          RZA
# 97                Anil Ravipudi
# 98                 Stanley Tong
# 99              Alessio Liguori
#
#                                                Actors  \
# 0   Will Smith, Martin Lawrence, Vanessa Hudgens, ...
# 1   Dean-Charles Chapman, George MacKay, Daniel Ma...
# 2   Ben Schwartz, James Marsden, Jim Carrey, Tika ...
# 3   Dwayne Johnson, Kevin Hart, Jack Black, Karen ...
# 4   Carrie Fisher, Mark Hamill, Adam Driver, Daisy...
# ..                                                ...
# 94  August Diehl, Valerie Pachner, Maria Simon, Ka...
# 95  Shameik Moore, Demetrius Shipp Jr., Denzel Whi...
# 97  Mahesh Babu, Rashmika Mandanna, Vijayshanti, P...
# 98          Jackie Chan, Yang Yang, Lun Ai, Miya Muqi
# 99  Jack Kane, Zander Emlano, Zak Sutcliffe, Sophi...
#
#                                  Country  \
# 0                            USA, Mexico
# 1   USA, UK, India, Spain, Canada, China
# 2                     USA, Japan, Canada
# 3                                    USA
# 4                                    USA
# ..                                   ...
# 94                      USA, UK, Germany
# 95                                   USA
# 97                                 India
# 98                                 China
# 99                        Italy, Germany
#
#                                                Awards Rotten Tomatoes  \
# 0                            2 wins & 14 nominations.             77%
# 1   Won 3 Oscars. Another 127 wins & 198 nominations.             89%
# 2                             3 wins & 9 nominations.             63%
# 3                             1 win & 10 nominations.             71%
# 4   Nominated for 3 Oscars. Another 9 wins & 39 no...             51%
# ..                                                ...             ...
# 94                           9 wins & 30 nominations.             81%
# 95                                                N/A          67/100
# 97                                                N/A             NaN
# 98                              1 win & 1 nomination.          34/100
# 99                                                N/A          26/100
#
#    Metascore IMDB IMDB Votes     IMDB id
# 0         59  6.6    133,505   tt1502397
# 1         78  8.3    442,036   tt8579674
# 2         47  6.5     92,987   tt3794354
# 3         58  6.6    192,270   tt7975244
# 4         53  6.6    378,434   tt2527338
# ..       ...  ...        ...         ...
# 94        78  7.4     19,103   tt5827916
# 95        67  4.9      1,584   tt3547306
# 97       N/A  6.0      5,364  tt10773090
# 98        34  4.7      3,126   tt9695722
# 99        26  3.9        617   tt8960138
#
# [93 rows x 16 columns]

# %%
# drop row by index
#clean_omdb_df = omdb_df.drop(1)
#clean_omdb_df

# %%
# create reference column to identify the top 100 films list they originated from
clean_omdb_df["Top100 Year"] = f"{year}"
# Out:
# <ipython-input-12-40862eee28c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_omdb_df["Top100 Year"] = f"{year}"

# %%
#export as csv for use elsewhere
clean_omdb_df.to_csv(f"output_data/raw/movie info/{d_today}_{year}_OMDb_Movie_details.csv", index=False, header=True)

# %%
clean_omdb_df
# Out:
#                                           Release  \
# 0                               Bad Boys for Life
# 1                                            1917
# 2                              Sonic the Hedgehog
# 3                         Jumanji: The Next Level
# 4   Star Wars: Episode IX - The Rise of Skywalker
# ..                                            ...
# 94                                  A Hidden Life
# 95                                Cut Throat City
# 97                            Sarileru Neekevvaru
# 98                                       Vanguard
# 99                                       Shortcut
#
#                                             Title  Year      Rated  \
# 0                               Bad Boys for Life  2020          R
# 1                                            1917  2019          R
# 2                              Sonic the Hedgehog  2020         PG
# 3                         Jumanji: The Next Level  2019      PG-13
# 4   Star Wars: Episode IX - The Rise of Skywalker  2019      PG-13
# ..                                            ...   ...        ...
# 94                                  A Hidden Life  2019      PG-13
# 95                                Cut Throat City  2020          R
# 97                            Sarileru Neekevvaru  2020  Not Rated
# 98                                       Vanguard  2020      PG-13
# 99                                       Shortcut  2020          R
#
#        Released  Runtime                                Genre  \
# 0   17 Jan 2020  124 min      Action, Comedy, Crime, Thriller
# 1   10 Jan 2020  119 min                 Drama, Thriller, War
# 2   14 Feb 2020   99 min    Action, Adventure, Comedy, Sci-Fi
# 3   13 Dec 2019  123 min   Action, Adventure, Comedy, Fantasy
# 4   20 Dec 2019  141 min   Action, Adventure, Fantasy, Sci-Fi
# ..          ...      ...                                  ...
# 94  17 Jan 2020  174 min       Biography, Drama, Romance, War
# 95  21 Aug 2020  123 min       Action, Crime, Drama, Thriller
# 97  10 Jan 2020  169 min                Action, Comedy, Drama
# 98  20 Nov 2020  107 min  Action, Adventure, Comedy, Thriller
# 99  25 Sep 2020   80 min           Adventure, Fantasy, Horror
#
#                        Director  \
# 0   Adil El Arbi, Bilall Fallah
# 1                    Sam Mendes
# 2                   Jeff Fowler
# 3                   Jake Kasdan
# 4                   J.J. Abrams
# ..                          ...
# 94              Terrence Malick
# 95                          RZA
# 97                Anil Ravipudi
# 98                 Stanley Tong
# 99              Alessio Liguori
#
#                                                Actors  \
# 0   Will Smith, Martin Lawrence, Vanessa Hudgens, ...
# 1   Dean-Charles Chapman, George MacKay, Daniel Ma...
# 2   Ben Schwartz, James Marsden, Jim Carrey, Tika ...
# 3   Dwayne Johnson, Kevin Hart, Jack Black, Karen ...
# 4   Carrie Fisher, Mark Hamill, Adam Driver, Daisy...
# ..                                                ...
# 94  August Diehl, Valerie Pachner, Maria Simon, Ka...
# 95  Shameik Moore, Demetrius Shipp Jr., Denzel Whi...
# 97  Mahesh Babu, Rashmika Mandanna, Vijayshanti, P...
# 98          Jackie Chan, Yang Yang, Lun Ai, Miya Muqi
# 99  Jack Kane, Zander Emlano, Zak Sutcliffe, Sophi...
#
#                                  Country  \
# 0                            USA, Mexico
# 1   USA, UK, India, Spain, Canada, China
# 2                     USA, Japan, Canada
# 3                                    USA
# 4                                    USA
# ..                                   ...
# 94                      USA, UK, Germany
# 95                                   USA
# 97                                 India
# 98                                 China
# 99                        Italy, Germany
#
#                                                Awards Rotten Tomatoes  \
# 0                            2 wins & 14 nominations.             77%
# 1   Won 3 Oscars. Another 127 wins & 198 nominations.             89%
# 2                             3 wins & 9 nominations.             63%
# 3                             1 win & 10 nominations.             71%
# 4   Nominated for 3 Oscars. Another 9 wins & 39 no...             51%
# ..                                                ...             ...
# 94                           9 wins & 30 nominations.             81%
# 95                                                N/A          67/100
# 97                                                N/A             NaN
# 98                              1 win & 1 nomination.          34/100
# 99                                                N/A          26/100
#
#    Metascore IMDB IMDB Votes     IMDB id Top100 Year
# 0         59  6.6    133,505   tt1502397        2020
# 1         78  8.3    442,036   tt8579674        2020
# 2         47  6.5     92,987   tt3794354        2020
# 3         58  6.6    192,270   tt7975244        2020
# 4         53  6.6    378,434   tt2527338        2020
# ..       ...  ...        ...         ...         ...
# 94        78  7.4     19,103   tt5827916        2020
# 95        67  4.9      1,584   tt3547306        2020
# 97       N/A  6.0      5,364  tt10773090        2020
# 98        34  4.7      3,126   tt9695722        2020
# 99        26  3.9        617   tt8960138        2020
#
# [93 rows x 17 columns]
