# %%
# dependencies
import pandas as pd
import time
from datetime import date
from bs4 import BeautifulSoup as bs
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager

# %%
# export dataframe of results with today's date
today = date.today()
d_today = today.strftime("%Y_%m_%d")

# %% [markdown]
# ## Preparation for Scrape Function

# %%
top_100df = pd.read_csv("output_data/Top100_Movies_2010-2021.csv")

# %%
# create list of years
years = top_100df["Year"].unique().tolist()
print(years)
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %%
# use a dictionary to create multiple empty lists to store each  year's top 100 movies
obj = {}
for year in years:
    obj[year] = []
print(obj)
# Out:
# {2010: [], 2011: [], 2012: [], 2013: [], 2014: [], 2015: [], 2016: [], 2017: [], 2018: [], 2019: [], 2020: [], 2021: []}

# %%
# set the year of movies we are scraping data for; each year is done individually for quality control
scrape_year = 2012

# %%
# fill dictionary with lists of the top 100 movies per year, display a sample year
for year in obj:
    top_100 = top_100df.loc[top_100df["Year"] == year]
    obj[year] = top_100["Release"].tolist()
print(obj[scrape_year])
# Out:
# ['The Avengers', 'The Dark Knight Rises', 'The Hunger Games', 'Skyfall', 'The Twilight Saga: Breaking Dawn - Part 2', 'The Amazing Spider-Man', 'Brave', 'The Hobbit: An Unexpected Journey', 'Ted', "Madagascar 3: Europe's Most Wanted", 'The Lorax', 'Men in Black 3', 'Wreck-It Ralph', 'Ice Age: Continental Drift', 'Snow White and the Huntsman', 'Hotel Transylvania', 'Taken 2', '21 Jump Street', 'Lincoln', 'Prometheus', 'Safe House', 'The Vow', 'Magic Mike', 'The Bourne Legacy', 'Argo', 'Journey 2: The Mysterious Island', 'Flight', 'Think Like a Man', 'Rise of the Guardians', 'Mission: Impossible - Ghost Protocol', 'The Campaign', 'Life of Pi', 'The Expendables 2', 'Wrath of the Titans', 'Dark Shadows', 'John Carter', 'Les Misérables', 'Act of Valor', 'Django Unchained', 'Contraband', 'Looper', "Madea's Witness Protection", 'Battleship', 'Mirror Mirror', 'Chronicle', 'Pitch Perfect', 'Hope Springs', 'Sherlock Holmes: A Game of Shadows', 'Underworld: Awakening', 'The Lucky One', 'The Dictator', 'Total Recall', 'Titanic2012 3D Release', 'American Reunion', 'ParaNorman', 'This Means War', 'Project X', 'The Woman in Black', 'Paranormal Activity 4', 'The Devil Inside', 'The Girl with the Dragon Tattoo', 'The Odd Life of Timothy Green', 'Ghost Rider: Spirit of Vengeance', 'The Grey', 'Red Tails', 'The Possession', 'Diary of a Wimpy Kid: Dog Days', 'Sinister', 'Beauty and the Beast2012 3D Release', 'Jack Reacher', 'Savages', 'The Best Exotic Marigold Hotel', 'Moonrise Kingdom', 'Alvin and the Chipmunks: Chipwrecked', 'The Three Stooges', 'The Descendants', 'Here Comes the Boom', 'War Horse', 'Red Dawn', 'Star Wars: Episode I - The Phantom Menace2012 3D Release', 'Resident Evil: Retribution', 'The Cabin in the Woods', "What to Expect When You're Expecting", 'Finding Nemo2012 3D Release', 'End of Watch', 'The Artist', 'This Is 40', 'We Bought a Zoo', 'Rock of Ages', 'Abraham Lincoln: Vampire Hunter', 'Lawless', "That's My Boy", 'Trouble with the Curve', 'The Watch', 'Step Up Revolution', 'Good Deeds', 'Frankenweenie', 'Parental Guidance', 'The Adventures of Tintin', "2016: Obama's America"]

# %% [markdown]
# ## Scrape Function Executed

# %%
# setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 88.0.4324
# [WDM] - Get LATEST driver version for 88.0.4324
# [WDM] - Driver [C:\Users\stuhu\.wdm\drivers\chromedriver\win32\88.0.4324.96\chromedriver.exe] found in cache

# %%
url = "https://www.imcdb.org/"
browser.visit(url)

# %%
def car_mov(titles):
    movie_dict = {}
    for title in titles:
        movie_dict[title] = []
    for title in titles:
                
        print(f"Processing {title}...")
        
        browser.find_by_css('input').fill(title)
        time.sleep(1)
        browser.find_by_value('Search').click()
        time.sleep(5)
    
        html = browser.html
        soup = bs(html, 'html.parser')
    
        results = soup.find_all('div', class_='ThumbnailBox')
        if len(results) != 0:
            good = 1
        else:
            good = 0
            try:
                browser.links.find_by_text(title).click()
                time.sleep(5)
            except:
                print("No data for the movie.")
                good = 0
                continue
        
        if good == 1:
            good2 = 1
        else:
            html = browser.html
            soup = bs(html, 'html.parser')
            results = soup.find_all('div', class_='ThumbnailBox')
            if len(results) != 0:
                good2 = 1
            else:
                good2 = 0
                print("Not good at all: no car data.")
                continue
        
        if good2 == 1:
            print("Car data collected.")
            count = 0
            for result in results:
                try:
                    x = result.find('span', class_='Stars')
                    y = len(x)
                    z = result.find('a')['href']
                    info_string = result.text
                    count += 1
                    movie_dict[title].append([count, info_string, z, y])
                except:
                    y = 'Nan'
                    z = result.find('a')['href']
                    info_string = result.text
                    count += 1
                    movie_dict[title].append([count, info_string, z, y])
        else:
            pass
    browser.quit()
    print("Scraping completed.")
    return movie_dict

# %%
# create our dictionary of car data
top_year = obj[scrape_year]
top_yearcars = car_mov(top_year)
# Out:
# Processing The Avengers...
# Car data collected.
# Processing The Dark Knight Rises...
# Car data collected.
# Processing The Hunger Games...
# Car data collected.
# Processing Skyfall...
# Car data collected.
# Processing The Twilight Saga: Breaking Dawn - Part 2...
# Car data collected.
# Processing The Amazing Spider-Man...
# Car data collected.
# Processing Brave...
# Car data collected.
# Processing The Hobbit: An Unexpected Journey...
# No data for the movie.
# Processing Ted...
# No data for the movie.
# Processing Madagascar 3: Europe's Most Wanted...
# Car data collected.
# Processing The Lorax...
# No data for the movie.
# Processing Men in Black 3...
# Car data collected.
# Processing Wreck-It Ralph...
# Car data collected.
# Processing Ice Age: Continental Drift...
# No data for the movie.
# Processing Snow White and the Huntsman...
# No data for the movie.
# Processing Hotel Transylvania...
# Car data collected.
# Processing Taken 2...
# Car data collected.
# Processing 21 Jump Street...
# Car data collected.
# Processing Lincoln...
# No data for the movie.
# Processing Prometheus...
# Car data collected.
# Processing Safe House...
# Car data collected.
# Processing The Vow...
# Car data collected.
# Processing Magic Mike...
# Car data collected.
# Processing The Bourne Legacy...
# Car data collected.
# Processing Argo...
# Car data collected.
# Processing Journey 2: The Mysterious Island...
# Car data collected.
# Processing Flight...
# Car data collected.
# Processing Think Like a Man...
# Car data collected.
# Processing Rise of the Guardians...
# Car data collected.
# Processing Mission: Impossible - Ghost Protocol...
# Car data collected.
# Processing The Campaign...
# Car data collected.
# Processing Life of Pi...
# Car data collected.
# Processing The Expendables 2...
# Car data collected.
# Processing Wrath of the Titans...
# No data for the movie.
# Processing Dark Shadows...
# Car data collected.
# Processing John Carter...
# Car data collected.
# Processing Les Misérables...
# Car data collected.
# Processing Act of Valor...
# Car data collected.
# Processing Django Unchained...
# No data for the movie.
# Processing Contraband...
# Car data collected.
# Processing Looper...
# Car data collected.
# Processing Madea's Witness Protection...
# Car data collected.
# Processing Battleship...
# Car data collected.
# Processing Mirror Mirror...
# Car data collected.
# Processing Chronicle...
# Car data collected.
# Processing Pitch Perfect...
# Car data collected.
# Processing Hope Springs...
# Car data collected.
# Processing Sherlock Holmes: A Game of Shadows...
# Car data collected.
# Processing Underworld: Awakening...
# Car data collected.
# Processing The Lucky One...
# Car data collected.
# Processing The Dictator...
# Car data collected.
# Processing Total Recall...
# Car data collected.
# Processing Titanic2012 3D Release...
# No data for the movie.
# Processing American Reunion...
# Car data collected.
# Processing ParaNorman...
# No data for the movie.
# Processing This Means War...
# Car data collected.
# Processing Project X...
# Car data collected.
# Processing The Woman in Black...
# Car data collected.
# Processing Paranormal Activity 4...
# Car data collected.
# Processing The Devil Inside...
# Car data collected.
# Processing The Girl with the Dragon Tattoo...
# Car data collected.
# Processing The Odd Life of Timothy Green...
# Car data collected.
# Processing Ghost Rider: Spirit of Vengeance...
# Car data collected.
# Processing The Grey...
# Car data collected.
# Processing Red Tails...
# Car data collected.
# Processing The Possession...
# Car data collected.
# Processing Diary of a Wimpy Kid: Dog Days...
# Car data collected.
# Processing Sinister...
# Car data collected.
# Processing Beauty and the Beast2012 3D Release...
# No data for the movie.
# Processing Jack Reacher...
# Car data collected.
# Processing Savages...
# Car data collected.
# Processing The Best Exotic Marigold Hotel...
# Car data collected.
# Processing Moonrise Kingdom...
# Car data collected.
# Processing Alvin and the Chipmunks: Chipwrecked...
# No data for the movie.
# Processing The Three Stooges...
# Car data collected.
# Processing The Descendants...
# Car data collected.
# Processing Here Comes the Boom...
# Car data collected.
# Processing War Horse...
# Car data collected.
# Processing Red Dawn...
# Car data collected.
# Processing Star Wars: Episode I - The Phantom Menace2012 3D Release...
# No data for the movie.
# Processing Resident Evil: Retribution...
# Car data collected.
# Processing The Cabin in the Woods...
# Car data collected.
# Processing What to Expect When You're Expecting...
# Car data collected.
# Processing Finding Nemo2012 3D Release...
# No data for the movie.
# Processing End of Watch...
# Car data collected.
# Processing The Artist...
# Car data collected.
# Processing This Is 40...
# Car data collected.
# Processing We Bought a Zoo...
# Car data collected.
# Processing Rock of Ages...
# Car data collected.
# Processing Abraham Lincoln: Vampire Hunter...
# No data for the movie.
# Processing Lawless...
# Car data collected.
# Processing That's My Boy...
# Car data collected.
# Processing Trouble with the Curve...
# Car data collected.
# Processing The Watch...
# Car data collected.
# Processing Step Up Revolution...
# Car data collected.
# Processing Good Deeds...
# Car data collected.
# Processing Frankenweenie...
# Car data collected.
# Processing Parental Guidance...
# Car data collected.
# Processing The Adventures of Tintin...
# Car data collected.
# Processing 2016: Obama's America...
# No data for the movie.
# Scraping completed.

# %%
# verification
print(top_yearcars)
# Out:
# {'The Avengers': [[1, '1965 AC 428 Spider  Ep. 7.11+', 'vehicle_13910-AC-428-Spider-CF1-1965.html', 3], [2, '1954 AC Ace  Ep. 7.32', 'vehicle_285618-AC-Ace-1954.html', 1], [3, '1960 AC Greyhound  Ep. 2.09', 'vehicle_221947-AC-Greyhound-1960.html', 3], [4, '1959 AEC Mandator MkV  Ep. 4.17', 'vehicle_258229-AEC-Mandator-1959.html', 1], [5, 'AEC Regal  Ep. 7.18', 'vehicle_304972-AEC-Regal.html', 1], [6, 'AEC Regal  Ep. 7.18', 'vehicle_304973-AEC-Regal.html', 1], [7, 'AEC Regal III  Ep. 7.18', 'vehicle_304968-AEC-Regal-III.html', 1], [8, '1953 AEC Regal IV RF  Ep. 4.17', 'vehicle_258220-AEC-Regal-IV-RF-1953.html', 1], [9, '1954 AEC Regal IV RF  Ep. 4.17', 'vehicle_258219-AEC-Regal-IV-RF-1954.html', 1], [10, '1951 AEC Regent III  Ep. 4.25', 'vehicle_259839-AEC-Regent-III-1951.html', 2], [11, '1964 AEC Reliance  Ep. 7.12', 'vehicle_287327-AEC-Reliance-1964.html', 1], [12, 'AEC RT  Ep. 4.04', 'vehicle_252697-AEC-RT.html', 1], [13, '1964 Alfa Romeo Giulia Sprint GT  Ep. 7.12', 'vehicle_287325-Alfa-Romeo-Giulia-Sprint-GT-10502-1964.html', 1], [14, '1965 Alfa Romeo Giulia Sprint GTC  Ep. 7.23', 'vehicle_309822-Alfa-Romeo-Giulia-Sprint-GTC-10525-1965.html', 1], [15, '1968 Alfa Romeo Spider 1300 Junior  Ep. 7.23', 'vehicle_309821-Alfa-Romeo-Spider-1300-Junior-10592-1968.html', 1], [16, 'Alvis FV 601 Saladin Series II  Ep. 4.22', 'vehicle_259348-Alvis-FV-601-Saladin.html', 2], [17, '1952 Alvis FV 603 Saracen Series II  Ep. 6.08', 'vehicle_283836-Alvis-FV-603-Saracen-1952.html', 4], [18, '1958 Alvis Salamander Crash Tender  Ep. 4.09', 'vehicle_254640-Alvis-Salamander-Crash-Tender-1958.html', 1], [19, '1937 Alvis Speed 25 SB  Ep. 2.11', 'vehicle_224100-Alvis-Speed-25-SB-14384-1937.html', 3], [20, '1966 Alvis TF 21 3-Litre Series III  Ep. 6.02', 'vehicle_280937-Alvis-TF-21-3-Litre-1966.html', 3], [21, '1965 Amphicar Model 770  Ep. 4.05', 'vehicle_252722-Amphicar-Model-770-1965.html', 3], [22, '1955 Ariel Huntmaster 650  Ep. 2.01', 'vehicle_222867-Ariel-Huntmaster-650-1955.html', 3], [23, '1960 Ariel Leader  Ep. 5.10', 'vehicle_262819-Ariel-Leader-1960.html', 1], [24, '1960 Aston Martin DB4 MkII  Ep. 4.18', 'vehicle_258300-Aston-Martin-DB4-1960.html', 1], [25, '1967 Aston Martin DBS Vantage  Ep. 7.05', 'vehicle_285455-Aston-Martin-DBS-Vantage-5001-R-1967.html', 3], [26, '1947 Atkinson L745  Ep. 2.18', 'vehicle_222860-Atkinson-L745-1947.html', 1], [27, '1967 Audi Super 90  Ep. 7.22', 'vehicle_318586-Audi-Super-90-F103-1967.html', 3], [28, '1964 Austin 1100 MkI  Ep. 7.29', 'vehicle_340390-Austin-1100-ADO16-1964.html', 1], [29, '1939 Austin 12/4 Taxi  Ep. 4.04', 'vehicle_252703-Austin-12-4-Taxi-1939.html', 1], [30, '1931 Austin 16/6 Burnham Saloon  Ep. 5.05', 'vehicle_261734-Austin-16-6-Burnham-Saloon-1931.html', 2], [31, '1965 Austin 1800 MkI  Ep. 5.06', 'vehicle_261738-Austin-1800-ADO17-1965.html', 2], [32, '1966 Austin 1800 MkI  Ep. 5.05', 'vehicle_261720-Austin-1800-ADO17-1966.html', 4], [33, '1968 Austin 3-Litre  Ep. 7.25', 'vehicle_98620-Austin-3-Litre-ADO61-1968.html', 3], [34, '1968 Austin 3-Litre  Ep. 7.14', 'vehicle_299992-Austin-3-Litre-ADO61-1968.html', 3], [35, '1955 Austin 3-Ton  Ep. 4.17', 'vehicle_258228-Austin-3-Ton-FE-1955.html', 1], [36, '1955 Austin 3-Ton  Ep. 6.04', 'vehicle_282376-Austin-3-Ton-FE-1955.html', 2], [37, '1963 Austin A110 Westminster MkI  Ep. 6.08', 'vehicle_283821-Austin-A110-Westminster-ADO53-1963.html', 2], [38, '1963 Austin A110 Westminster MkI  Ep. 7.17', 'vehicle_294529-Austin-A110-Westminster-ADO53-1963.html', 2], [39, '1948 Austin A125 Sheerline  Ep. 7.17', 'vehicle_294533-Austin-A125-Sheerline-DS1-1948.html', 3], [40, '1958 Austin A152 Ambulance  Ep. 2.19', 'vehicle_231262-Austin-A152-Ambulance-1958.html', 2], [41, '1956 Austin A152 Omnivan  Ep. 4.21', 'vehicle_259341-Austin-A152-Omnivan-1956.html', 1], [42, '1952 Austin A30  Ep. 2.15', 'vehicle_228637-Austin-A30-AS3-1952.html', 1], [43, '1957 Austin A35  Ep. 4.10', 'vehicle_254876-Austin-A35-A2S5-1957.html', 1], [44, '1957 Austin A35 Van  Ep. 4.10', 'v ...

# %% [markdown]
# ## Export/Import Scraped Data for backup

# %%
print(len(top_yearcars))
# Out:
# 100

# %%
# writing dictionary to text file
try:
    file_dict = open(f"top_{scrape_year}cars.txt", 'wt')
    file_dict.write(str(top_yearcars))
    file_dict.close()
except: 
    print("Unable to write to file")
# Out:
# Unable to write to file

# %%
# Unable to write a file? Try this instead, otherwise skip this
file_dict = open(f"top_{scrape_year}cars.txt", 'wt', encoding="utf-8")
file_dict.write(str(top_yearcars))
file_dict.close()

# %%
import ast

# %%
# read dictionary from text file back
file = open(f"top_{scrape_year}cars.txt", "r")
contents = file.read()
data = ast.literal_eval(contents)
file.close()

# %% [markdown]
# ## Scrape Missing Data Manually

# %%
# setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 88.0.4324
# [WDM] - Get LATEST driver version for 88.0.4324
# [WDM] - Driver [C:\Users\stuhu\.wdm\drivers\chromedriver\win32\88.0.4324.96\chromedriver.exe] found in cache

# %%
url = "https://www.imcdb.org/"
browser.visit(url)

# %% [markdown]
# ### Restart Manual Scrape Here:

# %%
# function to scrape data for a single film
def cars_manual(movie):
    print(f"Processing {movie}...")
    missing = f"{movie}"
    miss_dict = {}
    miss_dict[missing] = []

    html = browser.html
    soup = bs(html, 'html.parser')
    
    results = soup.find_all('div', class_='ThumbnailBox')
    if len(results) != 0:
        good = 1
    else:
        good = 0
        try:
            browser.links.find_by_text(missing).click()
            time.sleep(5)
        except:
            print("No data for the movie.")
            good = 0
        
    if good == 1:
        good2 = 1
    else:
        html = browser.html
        soup = bs(html, 'html.parser')
        results = soup.find_all('div', class_='ThumbnailBox')
        if len(results) != 0:
            good2 = 1
        else:
            good2 = 0
            print("Not good at all: no car data.")

    if good2 == 1:
        print("Data collected.")
        count = 0
        for result in results:
            try:
                x = result.find('span', class_='Stars')
                y = len(x)
                z = result.find('a')['href']
                info_string = result.text
                count += 1
                miss_dict[missing].append([count, info_string, z, y])
            except:
                y = 'Nan'
                z = result.find('a')['href']
                info_string = result.text
                count += 1
                miss_dict[missing].append([count, info_string, z, y])
    else:
        pass
    return miss_dict

# %%
# function to delete a single film's car data from our dictionary
def delete_data(movie):
    # remove data if no substitute can be manually found
    del top_yearcars[movie]

# %%
# while loop to manually update or delete films that were not scraped properly
answer = "yes"
while answer == "yes":
    decision = input("Do we want to update or delete data?: ").lower()
    if decision == "update":
        title = input("Title of the movie (exact upper and lower cases):")
        new_dict = cars_manual(title)
        # use update method to update value of errant key/title data
        top_yearcars.update(new_dict)
        # verification
        print(f"First car: {top_yearcars[title][0]}")
        print(f"Last car: {top_yearcars[title][-1]}")
        # outgoing exit option
        answer = input("Do we still have a movie to update? (yes/no): ").lower()
    elif decision == "delete":
        title = input("Title of the movie (exact upper and lower cases):")
        delete_data(title)
        answer = input("Do we still have a movie to update? (yes/no): ").lower()
    else:
        answer = "no"
print("Manual updates completed.")
# Out:
# Do we want to update or delete data?: update
# Title of the movie (exact upper and lower cases):The Avengers
# Processing The Avengers...
# Data collected.
# First car: [1, '2010 Acura MDX ', 'vehicle_840237-Acura-MDX-YD2-2010.html', 'Nan']
# Last car: [68, '1998 Volvo V70 XC Cross Country ', 'vehicle_525935-Volvo-V70-XC-Cross-Country-1998.html', 1]
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: update
# Title of the movie (exact upper and lower cases):The Amazing Spider-Man
# Processing The Amazing Spider-Man...
# Data collected.
# First car: [1, '2010 Aston Martin Rapide ', 'vehicle_501908-Aston-Martin-Rapide-2010.html', 1]
# Last car: [58, 'Westward Go-4 Interceptor ', 'vehicle_553150-Westward-Go-4-Interceptor.html', 1]
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: update
# Title of the movie (exact upper and lower cases):Brave
# Processing Brave...
# Data collected.
# First car: [1, '1979 Toyota Truck ', 'vehicle_743204-Toyota-Truck-RN30-1979.html', 1]
# Last car: [1, '1979 Toyota Truck ', 'vehicle_743204-Toyota-Truck-RN30-1979.html', 1]
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: update
# Title of the movie (exact upper and lower cases):Ted
# Processing Ted...
# Data collected.
# First car: [1, '1997 Buick Century ', 'vehicle_547730-Buick-Century-1997.html', 1]
# Last car: [38, '1992 Volvo 240 ', 'vehicle_515860-Volvo-240-245-1992.html', 3]
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: delete
# Title of the movie (exact upper and lower cases):Wreck-It Ralph
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: delete
# Title of the movie (exact upper and lower cases):Hotel Transylvania
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: update
# Title of the movie (exact upper and lower cases):21 Jump Street
# Processing 21 Jump Street...
# Data collected.
# First car: [1, '1999 BMW 328i [E46] ', 'vehicle_499123-BMW-328i-E46-1999.html', 1]
# Last car: [64, '2004 Volkswagen Passat Wagon B5 [Typ 3BG] ', 'vehicle_504030-Volkswagen-Passat-Wagon-Typ-3BG-2004.html', 1]
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: update
# Title of the movie (exact upper and lower cases):Safe House
# Processing Safe House...
# Data collected.
# First car: [1, '1998 Audi A3 ', 'vehicle_479514-Audi-A3-Typ-8L-1998.html', 1]
# Last car: [95, 'Volkswagen Transporter [Typ 2 / T5] ', 'vehicle_518725-Volkswagen-Transporter-Typ-2-T5.html', 1]
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: update
# Title of the movie (exact upper and lower cases):Argo
# Processing Argo...
# Data collected.
# First car: [1, '1972 AMC Matador ', 'vehicle_516089-AMC-Matador-1972.html', 3]
# Last car: [57, '1973 Volkswagen Transporter [Typ 2 / T2] ', 'vehicle_539615-Volkswagen-Transporter-Typ-2-T2-1973.html', 3]
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: update
# Title of the movie (exact upper and lower cases):Flight
# Processing Flight...
# Data collected.
# First car: [1, '2006 Buick LaCrosse ', 'vehicle_568186-Buick-LaCrosse-2006.html', 4]
# Last car: [19, '2007 Volvo XC90 ', 'vehicle_568423-Volvo-XC90-2007.html', 1]
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: update
# Title of the movie (exact upper and lower cases):Dark Shadows
# Processing Dark Shadows...
# Data collected.
# First car: [1, 'Caterpillar ', 'vehicle_528900-Caterpillar.html', 2]
# Last car: [18, '1964 Volkswagen Campmobile [Typ 2 / T1] ', 'vehicle_500384-Volkswagen-Campmobile-Typ-2-T1-1964.html', 2]
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: delete
# Title of the movie (exact upper and lower cases):John Carter
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: delete
# Title of the movie (exact upper and lower cases):Les Misérables
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: delete
# Title of the movie (exact upper and lower cases):Mirror Mirror
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: update
# Title of the movie (exact upper and lower cases):Hope Springs
# Processing Hope Springs...
# Data collected.
# First car: [1, '2005 Buick LeSabre ', 'vehicle_550030-Buick-LeSabre-GMX220-2005.html', 1]
# Last car: [20, '1991 Volvo 940 ', 'vehicle_550068-Volvo-940-944-1991.html', 1]
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: update
# Title of the movie (exact upper and lower cases):Total Recall
# Processing Total Recall...
# Data collected.
# First car: [1, '2012 Chrysler 200 ', 'vehicle_548263-Chrysler-200-2012.html', 1]
# Last car: [9, 'Volkswagen Jetta A4 [Typ 1J] ', 'vehicle_573967-Volkswagen-Jetta-Typ-1J.html', 1]
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: update
# Title of the movie (exact upper and lower cases):Project X
# Processing Project X...
# Data collected.
# First car: [1, '1992 Acura Integra ', 'vehicle_518557-Acura-Integra-DA9-1992.html', 1]
# Last car: [26, '2009 Volkswagen Tiguan I [Typ 5N] ', 'vehicle_519490-Volkswagen-Tiguan-Typ-5N-2009.html', 1]
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: update
# Title of the movie (exact upper and lower cases):The Woman in Black
# Processing The Woman in Black...
# Data collected.
# First car: [1, '1912 Fiat Tipo 1 ', 'vehicle_490409-Fiat-Tipo-1-1912.html', 1]
# Last car: [2, "1913 Rolls-Royce 40/50 h.p. 'Silver Ghost' ", 'vehicle_490410-Rolls-Royce-40-50-hp--Silver-Ghost--2500E-1913.html', 4]
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: update
# Title of the movie (exact upper and lower cases):The Three Stooges
# Processing The Three Stooges...
# Data collected.
# First car: [1, '1968 Chevrolet Impala ', 'vehicle_514769-Chevrolet-Impala-1968.html', 2]
# Last car: [17, 'Yamaha G11 ', 'vehicle_514775-Yamaha-G11.html', 2]
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: update
# Title of the movie (exact upper and lower cases):Red Dawn
# Processing Red Dawn...
# Data collected.
# First car: [1, 'AM General HMMWV M1025 ', 'vehicle_252975-AM-General-HMMWV-M1025.html', 4]
# Last car: [38, '1986 Volvo 240 ', 'vehicle_574737-Volvo-240-244-1986.html', 1]
# Do we still have a movie to update? (yes/no): yes
# Do we want to update or delete data?: update
# Title of the movie (exact upper and lower cases):Frankenweenie
# Processing Frankenweenie...
# Data collected.
# First car: [1, '1964 Chevrolet Impala ', 'vehicle_571974-Chevrolet-Impala-1964.html', 2]
# Last car: [10, 'unknown ', 'vehicle_571564.html', 2]
# Do we still have a movie to update? (yes/no): no
# Manual updates completed.

# %%
browser.quit()

# %% [markdown]
# ## Export Data as CSV

# %%
print(top_yearcars)
# Out:
# {'The Avengers': [[1, '2010 Acura MDX ', 'vehicle_840237-Acura-MDX-YD2-2010.html', 'Nan'], [2, '2010 Acura MDX ', 'vehicle_1235723-Acura-MDX-YD2-2010.html', 'Nan'], [3, '2012 Acura MDX ', 'vehicle_525889-Acura-MDX-YD2-2012.html', 1], [4, '2012 Acura NSX Roadster Concept ', 'vehicle_525885-Acura-NSX-Roadster-Concept-2012.html', 2], [5, '2013 Acura RDX ', 'vehicle_525890-Acura-RDX-TB4-2013.html', 1], [6, '2010 Acura TL ', 'vehicle_525924-Acura-TL-UA8-2010.html', 1], [7, '2012 Acura TL ', 'vehicle_525891-Acura-TL-UA8-2012.html', 2], [8, 'AM General HMMWV ', 'vehicle_525911-AM-General-HMMWV.html', 2], [9, 'AM General HMMWV ', 'vehicle_525912-AM-General-HMMWV.html', 1], [10, 'AM General M-35 ', 'vehicle_1235724-AM-General-M-35.html', 'Nan'], [11, '2011 BMW 5 [F10] ', 'vehicle_525886-BMW-5-F10-2011.html', 1], [12, '1997 Buick Century ', 'vehicle_1235728-Buick-Century-1997.html', 'Nan'], [13, '2003 Chevrolet Cavalier ', 'vehicle_825415-Chevrolet-Cavalier-GM-J-2003.html', 'Nan'], [14, '2000 Chevrolet Impala ', 'vehicle_525913-Chevrolet-Impala-GMX210-2000.html', 1], [15, '2001 Chevrolet Venture ', 'vehicle_525933-Chevrolet-Venture-GMT200-2001.html', 1], [16, '2004 Chrysler Sebring ', 'vehicle_525893-Chrysler-Sebring-JR-2004.html', 1], [17, '2001 Dodge Caravan ', 'vehicle_1235731-Dodge-Caravan-RS-2001.html', 'Nan'], [18, '2005 Dodge Magnum ', 'vehicle_525917-Dodge-Magnum-LX-2005.html', 1], [19, '2003 Dodge Stratus ', 'vehicle_825417-Dodge-Stratus-JR-2003.html', 'Nan'], [20, '1975 Fiat 126 ', 'vehicle_542779-Fiat-126-126A-1975.html', 1], [21, 'Flyer D 900 ', 'vehicle_916109-Flyer-D-900.html', 2], [22, '1957 Ford C-Series ', 'vehicle_1235732-Ford-C-Series-1957.html', 'Nan'], [23, '1993 Ford Crown Victoria ', 'vehicle_525898-Ford-Crown-Victoria-1993.html', 1], [24, '1999 Ford Crown Victoria ', 'vehicle_525896-Ford-Crown-Victoria-1999.html', 1], [25, '2001 Ford Crown Victoria ', 'vehicle_525899-Ford-Crown-Victoria-P71-2001.html', 1], [26, '2001 Ford Crown Victoria ', 'vehicle_525900-Ford-Crown-Victoria-P71-2001.html', 1], [27, '2005 Ford Escape ', 'vehicle_525925-Ford-Escape-U204-2005.html', 1], [28, '1998 Ford Explorer ', 'vehicle_525904-Ford-Explorer-UN150-1998.html', 1], [29, '2002 Ford Explorer ', 'vehicle_825419-Ford-Explorer-U152-2002.html', 'Nan'], [30, '2005 Ford Focus ', 'vehicle_525905-Ford-Focus-2005.html', 1], [31, '2000 Ford Taurus ', 'vehicle_525923-Ford-Taurus-D186-2000.html', 1], [32, '2005 Ford Taurus ', 'vehicle_525922-Ford-Taurus-D186-2005.html', 1], [33, '1979 GMC RTS ', 'vehicle_525928-GMC-RTS-1979.html', 1], [34, '1979 GMC RTS ', 'vehicle_525929-GMC-RTS-1979.html', 1], [35, 'Harley-Davidson Softail Slim ', 'vehicle_525926-Harley-Davidson-Softail-Slim.html', 2], [36, 'Harley-Davidson WLA 45 ', 'vehicle_825414-Harley-Davidson-WLA-45.html', 'Nan'], [37, '2005 Honda Accord ', 'vehicle_525888-Honda-Accord-CM-2005.html', 1], [38, '2009 Hummer H3T ', 'vehicle_525909-Hummer-H3T-GMT745-2009.html', 3], [39, 'Jeep Grand Cherokee ', 'vehicle_1235721-Jeep-Grand-Cherokee-WJ.html', 'Nan'], [40, '2010 Jeep J8 ', 'vehicle_525937-Jeep-J8-JK-2010.html', 3], [41, 'Land-Rover Range Rover Series II ', 'vehicle_1235722-Land-Rover-Range-Rover-P38a.html', 'Nan'], [42, '1990 Lexus LS 400 ', 'vehicle_525916-Lexus-LS-400-UCF10-1990.html', 1], [43, '1995 Lincoln Continental ', 'vehicle_916111-Lincoln-Continental-1995.html', 1], [44, '2003 Lincoln LS ', 'vehicle_916112-Lincoln-LS-2003.html', 1], [45, '2000 Mazda 626 ', 'vehicle_525930-Mazda-626-GF-2000.html', 1], [46, '2000 Mazda 626 ', 'vehicle_826148-Mazda-626-GF-2000.html', 'Nan'], [47, '2002 Mazda Protegé ', 'vehicle_825416-Mazda-Protege-BJ-2002.html', 'Nan'], [48, 'Mercedes-Benz E-Klasse [W211] ', 'vehicle_525901-Mercedes-Benz-E-Klasse-W211.html', 1], [49, '1996 Mercedes-Benz E-Klasse [W210] ', 'vehicle_525902-Mercedes-Benz-E-Klasse-W210-1996.html', 1], [50, '2010 Mercedes-Benz E-Klasse [W212] ', 'vehicle_525903-Mercedes-Benz-E-Klasse-W212-2010.html', 1], [51, '2009 Mercedes-Benz ML [W164] ',  ...

# %%
# create dataframe of data for each vehicle, with movie and movie year included
title = []
year = []
auto = []
link = []
stars = []
for movie in top_year:
    try:
        cars = top_yearcars[movie]
        for car in cars:
            title.append(movie)
            year.append(scrape_year)
            auto.append(car[1])
            link.append(car[2])
            stars.append(car[3])
    except:
        print(f"No cars for the movie, {movie}.")
# Out:
# No cars for the movie, Wreck-It Ralph.
# No cars for the movie, Hotel Transylvania.
# No cars for the movie, John Carter.
# No cars for the movie, Les Misérables.
# No cars for the movie, Mirror Mirror.

# %%
top_year_df = pd.DataFrame({"Release": title, "Year": year, "Car": auto, "url": link, "Stars": stars})

# %%
top_year_df
# Out:
#                        Release  Year                               Car  \
# 0                 The Avengers  2012                   2010 Acura MDX
# 1                 The Avengers  2012                   2010 Acura MDX
# 2                 The Avengers  2012                   2012 Acura MDX
# 3                 The Avengers  2012  2012 Acura NSX Roadster Concept
# 4                 The Avengers  2012                   2013 Acura RDX
# ...                        ...   ...                               ...
# 2038  The Adventures of Tintin  2012           Rolls-Royce Phantom II
# 2039  The Adventures of Tintin  2012                 1955 Triumph TR2
# 2040  The Adventures of Tintin  2012      Vickers-Armstrong Centurion
# 2041  The Adventures of Tintin  2012                1940 Volvo LV 125
# 2042  The Adventures of Tintin  2012            1942 Willys MB 'Jeep'
#
#                                                     url Stars
# 0                vehicle_840237-Acura-MDX-YD2-2010.html   Nan
# 1               vehicle_1235723-Acura-MDX-YD2-2010.html   Nan
# 2                vehicle_525889-Acura-MDX-YD2-2012.html     1
# 3     vehicle_525885-Acura-NSX-Roadster-Concept-2012...     2
# 4                vehicle_525890-Acura-RDX-TB4-2013.html     1
# ...                                                 ...   ...
# 2038         vehicle_445293-Rolls-Royce-Phantom-II.html     3
# 2039               vehicle_483886-Triumph-TR2-1955.html     3
# 2040    vehicle_483889-Vickers-Armstrong-Centurion.html     1
# 2041              vehicle_445298-Volvo-LV-125-1940.html     2
# 2042          vehicle_445296-Willys-MB--Jeep--1942.html     3
#
# [2043 rows x 5 columns]

# %%
#export as csv for use elsewhere
top_year_df.to_csv(f"output_data/{d_today}_{scrape_year}Cars.csv", index=False, header=True)
