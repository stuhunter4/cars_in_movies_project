# %%
import pandas as pd
import numpy as np
import math

# %%
# read in all of the car sales datasets
clean_2010 = pd.read_csv("output_data/raw/clean_cars_2010.csv")
clean_2011 = pd.read_csv("output_data/raw/clean_cars_2011.csv")
clean_2012 = pd.read_csv("output_data/raw/clean_cars_2012.csv")
clean_2013 = pd.read_csv("output_data/raw/clean_cars_2013.csv")
clean_2014 = pd.read_csv("output_data/raw/clean_cars_2014.csv")

clean_2015 = pd.read_csv("output_data/raw/clean_cars_2015.csv")
clean_2016 = pd.read_csv("output_data/raw/clean_cars_2016.csv")
clean_2017 = pd.read_csv("output_data/raw/clean_cars_2017.csv")
clean_2018 = pd.read_csv("output_data/raw/clean_cars_2018.csv")
clean_2019 = pd.read_csv("output_data/raw/clean_cars_2019.csv")
clean_2020 = pd.read_csv("output_data/raw/clean_cars_2020.csv")

# %% [markdown]
# # Assemble datasets

# %%
# Remove columns for '% Change...'
clean_2010 = clean_2010.drop(['% Change 2010'], axis = 1)
clean_2011 = clean_2011.drop(['% Change 2011'], axis = 1)
clean_2012 = clean_2012.drop(['% Change 2012'], axis = 1)
clean_2013 = clean_2013.drop(['% Change 2013'], axis = 1)
clean_2014 = clean_2014.drop(['% Change 2014'], axis = 1)

clean_2015 = clean_2015.drop(['% Change 2015'], axis = 1)
clean_2016 = clean_2016.drop(['% Change 2016'], axis = 1)
clean_2017 = clean_2017.drop(['% Change 2017'], axis = 1)
clean_2018 = clean_2018.drop(['% Change 2018'], axis = 1)
clean_2019 = clean_2019.drop(['% Change 2019'], axis = 1)
clean_2020 = clean_2020.drop(['% Change 2020'], axis = 1)

# %% [markdown]
# ### First Merge

# %%
# first merge with a full outer join to keep all vehicle data from both years
merge10_11 = pd.merge(clean_2010, clean_2011, how="outer", on="Vehicle")

# %%
# create new column for '2010 Year End' that compares our two lists and keeps only the data
merge10_11["2010 Year End"] = ""

for index, row in merge10_11.iterrows():
    if row[1] == row[4]:
        merge10_11["2010 Year End"][index] = merge10_11["2010 Year End_x"][index]
    else:
        if math.isnan(row[1]):
            merge10_11["2010 Year End"][index] = merge10_11["2010 Year End_y"][index]
        else:
            merge10_11["2010 Year End"][index] = merge10_11["2010 Year End_x"][index]
# Out:
# <ipython-input-5-6e523412dc8f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge10_11["2010 Year End"][index] = merge10_11["2010 Year End_x"][index]
# <ipython-input-5-6e523412dc8f>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge10_11["2010 Year End"][index] = merge10_11["2010 Year End_x"][index]
# <ipython-input-5-6e523412dc8f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# drop the redundant columns now that data has been merged into a single column
merge10_11 = merge10_11.drop(['2010 Year End_x', '2010 Year End_y'], axis = 1)

# %%
merge10_11
# Out:
#                   Vehicle  2009 Year End  2011 Year End 2010 Year End
# 0               Acura MDX        31178.0        43271.0         47210
# 1               Acura RDX        10153.0        15196.0         14975
# 2                Acura RL         2043.0         1096.0          2037
# 3                Acura TL        33620.0        31237.0         34049
# 4               Acura TSX        28650.0        30935.0         32076
# ..                    ...            ...            ...           ...
# 306            Suzuki SX4            NaN        12519.0         11606
# 307         Suzuki Verona            NaN            1.0             0
# 308  Toyota Prius/Prius V            NaN       136463.0        140928
# 309     Volkswagen Beetle            NaN         6468.0         16537
# 310       Volkswagen Golf            NaN        34706.0         28286
#
# [311 rows x 4 columns]

# %% [markdown]
# ### Repeat Operations for Multiple Combinations

# %%
merge_12 = pd.merge(merge10_11, clean_2012, how="outer", on="Vehicle")

# %%
# same iteration and conditionals as above to combine data from two columns...
# ...each column with its own missing elements relative to the other
merge_12["2011 Year End"] = ""

for index, row in merge_12.iterrows():
    if row[2] == row[5]:
        merge_12["2011 Year End"][index] = merge_12["2011 Year End_x"][index]
    else:
        if math.isnan(row[2]):
            merge_12["2011 Year End"][index] = merge_12["2011 Year End_y"][index]
        else:
            merge_12["2011 Year End"][index] = merge_12["2011 Year End_x"][index]
# Out:
# <ipython-input-9-8524c06fec8e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_12["2011 Year End"][index] = merge_12["2011 Year End_x"][index]
# <ipython-input-9-8524c06fec8e>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_12["2011 Year End"][index] = merge_12["2011 Year End_x"][index]
# <ipython-input-9-8524c06fec8e>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
merge_12 = merge_12.drop(['2011 Year End_x', '2011 Year End_y'], axis = 1)

# %%
merge_12
# Out:
#                          Vehicle  2009 Year End 2010 Year End  2012 Year End  \
# 0                      Acura MDX        31178.0         47210        50854.0
# 1                      Acura RDX        10153.0         14975        29520.0
# 2                       Acura RL         2043.0          2037          379.0
# 3                       Acura TL        33620.0         34049        33572.0
# 4                      Acura TSX        28650.0         32076        28865.0
# ..                           ...            ...           ...            ...
# 365            Volkswagen Golf R            NaN           NaN         3894.0
# 366       Volkswagen Jetta Sedan            NaN           NaN       146478.0
# 367  Volkswagen Jetta SportWagen            NaN           NaN        23946.0
# 368      Volkswagen Passat Sedan            NaN           NaN       117023.0
# 369      Volkswagen Passat Wagon            NaN           NaN            0.0
#
#     2011 Year End
# 0           43271
# ...

# %%
# third merge, adding the year 2013 to the great DataFrame being assembled
merge_13 = pd.merge(merge_12, clean_2013, how="outer", on="Vehicle")

# %%
merge_13["2012 Year End"] = ""

for index, row in merge_13.iterrows():
    if row[3] == row[6]:
        merge_13["2012 Year End"][index] = merge_13["2012 Year End_x"][index]
    else:
        if math.isnan(row[3]):
            merge_13["2012 Year End"][index] = merge_13["2012 Year End_y"][index]
        else:
            merge_13["2012 Year End"][index] = merge_13["2012 Year End_x"][index]
# Out:
# <ipython-input-13-fff2d3bb2496>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_13["2012 Year End"][index] = merge_13["2012 Year End_x"][index]
# <ipython-input-13-fff2d3bb2496>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_13["2012 Year End"][index] = merge_13["2012 Year End_x"][index]
# <ipython-input-13-fff2d3bb2496>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
merge_13 = merge_13.drop(['2012 Year End_x', '2012 Year End_y'], axis = 1)

# %%
merge_13
# Out:
#                            Vehicle  2009 Year End 2010 Year End 2011 Year End  \
# 0                        Acura MDX        31178.0         47210         43271
# 1                        Acura RDX        10153.0         14975         15196
# 2                         Acura RL         2043.0          2037          1096
# 3                         Acura TL        33620.0         34049         31237
# 4                        Acura TSX        28650.0         32076         30935
# ..                             ...            ...           ...           ...
# 421               Volkswagen GTI *            NaN           NaN           NaN
# 422              Volkswagen Golf *            NaN           NaN           NaN
# 423            Volkswagen Golf R *            NaN           NaN           NaN
# 424       Volkswagen Jetta Sedan *            NaN           NaN           NaN
# 425  Volkswagen Jetta Sportwagen *            NaN           NaN           NaN
#
#      2013 Year End 2012 Year End
# ...

# %%
# fourth merge, adding 2014 data
merge_14 = pd.merge(merge_13, clean_2014, how="outer", on="Vehicle")

# %%
merge_14["2013 Year End"] = ""

for index, row in merge_14.iterrows():
    if row[4] == row[7]:
        merge_14["2013 Year End"][index] = merge_14["2013 Year End_x"][index]
    else:
        if math.isnan(row[4]):
            merge_14["2013 Year End"][index] = merge_14["2013 Year End_y"][index]
        else:
            merge_14["2013 Year End"][index] = merge_14["2013 Year End_x"][index]

merge_14 = merge_14.drop(['2013 Year End_x', '2013 Year End_y'], axis = 1)
# Out:
# <ipython-input-17-6d66ec90dfda>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_14["2013 Year End"][index] = merge_14["2013 Year End_x"][index]
# <ipython-input-17-6d66ec90dfda>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_14["2013 Year End"][index] = merge_14["2013 Year End_y"][index]
# <ipython-input-17-6d66ec90dfda>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
merge_14
# Out:
#                            Vehicle  2009 Year End 2010 Year End 2011 Year End  \
# 0                        Acura MDX        31178.0         47210         43271
# 1                        Acura RDX        10153.0         14975         15196
# 2                         Acura RL         2043.0          2037          1096
# 3                         Acura TL        33620.0         34049         31237
# 4                        Acura TSX        28650.0         32076         30935
# ..                             ...            ...           ...           ...
# 471       Subaru Impreza WRX/STi *            NaN           NaN           NaN
# 472          Volkswagen Golf GTI *            NaN           NaN           NaN
# 473  Volkswagen Jetta SportWagen *            NaN           NaN           NaN
# 474            Volkswagen e-Golf *            NaN           NaN           NaN
# 475                      Volvo V60            NaN           NaN           NaN
#
# ...
